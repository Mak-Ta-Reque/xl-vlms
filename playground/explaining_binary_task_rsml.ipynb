# %% [markdown]
# # Local expmnation of noun phrases of VLM
# ### Step 1: Generate the concept matix for noun phrases for (crop, concept pair)
# ### Step 2: Run an inference with an image or without an image. get all the embedding of the noun phrases
# ### Step 3: Select one embedding corresponds to the noun phrase of step 2
# ### Step 4: Project the embedding to the concept matrix and get the corresponding images

# %% [markdown]
# ## Generate Concept matrix

# %%
import torch
import os
import random

# %%
# Data dir
data_path = "/mnt/abka03/xlvlm_data/coco_cc0_plus" # Where the raw data exist with class names as a directory # use """" for d in *\ *; do mv "$d" "${d// /_}"; done "" remove space from the class names
cropped_data_path = "/mnt/abka03/xlvlm_data/coco_cc0_plus_cropped/train" #This path will be created to save the concept crops and crops will be stored


#Output dir

output_dir = "/mnt/abka03/concept_extraction_result/rsml/gemma3n/MCoX/SNMF/mscoco"

# automatically create train and val path inside output_dir
train_output_dir = f"{output_dir}/train"
val_output_dir = f"{output_dir}/val" 
# create the directories if they do not exist

os.makedirs(train_output_dir, exist_ok=True)
os.makedirs(val_output_dir, exist_ok=True)

# inside each of this directory create concept, features directories
concept_train_dir = f"{train_output_dir}/concept"
features_train_dir = f"{train_output_dir}/features"
concept_val_dir = f"{val_output_dir}/concept"
features_val_dir = f"{val_output_dir}/features"
# create the directories if they do not exist

os.makedirs(concept_train_dir, exist_ok=True)
os.makedirs(features_train_dir, exist_ok=True)
os.makedirs(concept_val_dir, exist_ok=True)
os.makedirs(features_val_dir, exist_ok=True)


# use """" for d in *\ *; do mv "$d" "${d// /_}"; done "" remove space from the class names

# %%
#Model id from hugingface
model_card = "Qwen/Qwen2.5-VL-7B-Instruct"
#save_the model first in the hugging face path
hugging_face_path = "/mnt/abka03/huggingface/hub/hub" # please load it foirst other wise could throw an error

# %%
# Running one time sufficient
training_data_path = f"{data_path}/train"
# create a random crops of trainging data
# !python   ../preprocessing/random_crops.py \
  --input_root $training_data_path \
  --output_root $cropped_data_path \
  --patch_size 200 \
  --patches_per_image 20 \
  --max_overlap 0.5
# Out:
# 13269.02s - pydevd: Sending message related to process being replaced timed-out after 5 seconds

# %%
#Set huggingface_path 
# !export HF_HOME=/mnt/abka03/huggingface/hub


# Get the feature for one image 

# Multiple choice quiestions correct choice concept or Something else
concept_example = "bear" 
# Prompt: 

test_image_dir = f"{data_path}/val/{concept_example}"


# randomly chose one image fom  test_image_path

test_image_path = f"{test_image_dir}/{random.choice(os.listdir(test_image_dir))}"
print("Test image is: ", test_image_path)

# !cd ../ && python src/save_features.py \
    --model_name $"{model_card}" \
    --dataset_name "image" \
    --data_dir $"{test_image_path}" \
    --hook_name "save_hidden_states_sentence" \
    --modules_to_hook "model.language_model.norm" \
    --save_dir $"{val_output_dir}" \
    --save_filename "qween2_5" \
    --generation_mode \
    --save_only_generated_tokens \
    --slice_prediction \
    --token_of_interest $"{concept_example}"\
    --prompt_template "cgdl" \
    --concept $"{concept_example}" \
    --exact_match_modules_to_hook \
    --cache_dir "/mnt/abka03/xl-vlms/cache"
# Out:
# 13358.67s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Test image is:  /mnt/abka03/xlvlm_data/coco_cc0_plus/val/bear/573391.jpg
# 13364.00s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# [nltk_data] Downloading package words to /home/abka03/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# 2025-08-22 16:06:24,494 - INFO - Loading model: Qwen/Qwen2.5-VL-7B-Instruct
# 2025-08-22 16:06:24,494 - INFO - Arguments:
# 2025-08-22 16:06:24,494 - INFO - seed: 0
# 2025-08-22 16:06:24,494 - INFO - model_name_or_path: Qwen/Qwen2.5-VL-7B-Instruct
# 2025-08-22 16:06:24,494 - INFO - processor_name: None
# 2025-08-22 16:06:24,494 - INFO - local_files_only: False
# 2025-08-22 16:06:24,494 - INFO - cache_dir: /mnt/abka03/xl-vlms/cache
# 2025-08-22 16:06:24,495 - INFO - prompt_template: cgdl
# 2025-08-22 16:06:24,495 - INFO - prompt: Describe the image in detail.
# 2025-08-22 16:06:24,495 - INFO - data_dir: /mnt/abka03/xlvlm_data/coco_cc0_plus/val/bear/573391.jpg
# 2025-08-22 16:06:24,495 - INFO - annotation_file: annotations.json
# 2025-08-22 16:06:24,495 - INFO - questions_file: annotations.json
# 2025-08-22 16:06:24,495 - INFO - answer_type_to_answer: None
# 2025-08-22 16:06:24,495 - INFO - split: train
# 2025-08-22 16:06:24,495 - INFO - dataset_size: -1
# 2025-08-22 16:06:24,495 - INFO - dataset_name: image
# 2025-08-22 16:06:24,495 - INFO - batch_size: 1
# 2025-08-22 16:06:24,495 - INFO - hook_names: ['save_hidden_states_sentence']
# 2025-08-22 16:06:24,495 - INFO - modules_to_hook: [['model.language_model.norm']]
# 2025-08-22 16:06:24,495 - INFO - exact_match_modules_to_hook: True
# 2025-08-22 16:06:24,495 - INFO - hook_postprocessing_name: save_hidden_states
# 2025-08-22 16:06:24,495 - INFO - token_idx: None
# 2025-08-22 16:06:24,495 - INFO - token_start_end_idx: None
# 2025-08-22 16:06:24,495 - INFO - save_dir: /mnt/abka03/concept_extraction_result/rsml/gemma3n/MCoX/SNMF/mscoco/val
# 2025-08-22 16:06:24,495 - INFO - save_filename: qween2_5
# 2025-08-22 16:06:24,495 - INFO - save_analysis: True
# 2025-08-22 16:06:24,495 - INFO - features_path: None
# 2025-08-22 16:06:24,495 - INFO - analysis_saving_path: results/analysis.pth
# 2025-08-22 16:06:24,495 - INFO - analysis_name: decompose_activations
# 2025-08-22 16:06:24,495 - INFO - feature_key: hidden_states
# 2025-08-22 16:06:24,495 - INFO - module_to_decompose: None
# 2025-08-22 16:06:24,495 - INFO - decomposition_extract_pos: None
# 2025-08-22 16:06:24,495 - INFO - decomposition_method: None
# 2025-08-22 16:06:24,495 - INFO - num_concepts: None
# 2025-08-22 16:06:24,495 - INFO - dl_max_iter: 12000
# 2025-08-22 16:06:24,495 - INFO - num_grounded_text_tokens: 5
# 2025-08-22 16:06:24,495 - INFO - pre_num_top_tokens: 20
# 2025-08-22 16:06:24,495 - INFO - num_most_activating_samples: 3
# 2025-08-22 16:06:24,495 - INFO - generation_mode: True
# 2025-08-22 16:06:24,495 - INFO - max_new_tokens: 50
# 2025-08-22 16:06:24,495 - INFO - token_of_interest_num_samples: -1
# 2025-08-22 16:06:24,495 - INFO - select_token_of_interest_samples: False
# 2025-08-22 16:06:24,495 - INFO - allow_different_variations_of_token_of_interest: False
# 2025-08-22 16:06:24,495 - INFO - token_of_interest: bear
# 2025-08-22 16:06:24,495 - INFO - tokens_of_interest: None
# 2025-08-22 16:06:24,495 - INFO - token_of_interest_key: response
# 2025-08-22 16:06:24,495 - INFO - token_of_interest_class: None
# 2025-08-22 16:06:24,495 - INFO - token_of_interest_idx: None
# 2025-08-22 16:06:24,495 - INFO - token_of_interest_start_token: 0
# 2025-08-22 16:06:24,495 - INFO - end_special_tokens:
# 2025-08-22 16:06:24,495 - INFO - save_only_generated_tokens: True
# 2025-08-22 16:06:24,495 - INFO - load_matched_features: False
# 2025-08-22 16:06:24,495 - INFO - steering_method: shift_of_means
# 2025-08-22 16:06:24,496 - INFO - steering_alpha: 1
# 2025-08-22 16:06:24,496 - INFO - category_of_interest:
# 2025-08-22 16:06:24,496 - INFO - base_features_key: hidden_states
# 2025-08-22 16:06:24,496 - INFO - shift_vector_path:
# 2025-08-22 16:06:24,496 - INFO - shift_vector_key: steering_vector
# 2025-08-22 16:06:24,496 - INFO - start_prompt_token_idx_steering: 0
# 2025-08-22 16:06:24,496 - INFO - use_random_grounding_words: False
# 2025-08-22 16:06:24,496 - INFO - captioning_metrics: ['CIDEr']
# 2025-08-22 16:06:24,496 - INFO - predictions_token_of_interest: None
# 2025-08-22 16:06:24,496 - INFO - targets_token_of_interest: None
# 2025-08-22 16:06:24,496 - INFO - save_predictions: False
# 2025-08-22 16:06:24,496 - INFO - predictions_path: None
# 2025-08-22 16:06:24,496 - INFO - origin_model_analysis_path: None
# 2025-08-22 16:06:24,496 - INFO - origin_model_feature_path: None
# 2025-08-22 16:06:24,496 - INFO - dest_model_analysis_path: None
# 2025-08-22 16:06:24,496 - INFO - dest_model_feature_path: None
# 2025-08-22 16:06:24,496 - INFO - visualize_concepts: False
# 2025-08-22 16:06:24,496 - INFO - compute_recovery_metrics: False
# 2025-08-22 16:06:24,496 - INFO - compute_stat_shift_vectors: False
# 2025-08-22 16:06:24,496 - INFO - select_samples_from_ids: False
# 2025-08-22 16:06:24,496 - INFO - path_to_samples_ids: None
# 2025-08-22 16:06:24,496 - INFO - slice_prediction: True
# 2025-08-22 16:06:24,496 - INFO - post_process_hidden: False
# 2025-08-22 16:06:24,496 - INFO - concept: bear
# /mnt/abka03/.conda/envs/rsml3/lib/python3.9/site-packages/transformers/models/auto/modeling_auto.py:2199: FutureWarning: The class `AutoModelForVision2Seq` is deprecated and will be removed in v5.0. Please use `AutoModelForImageTextToText` instead.
#   warnings.warn(
# Loading checkpoint shards: 100%|██████████████████| 5/5 [00:02<00:00,  1.82it/s]
# The image processor of type `Qwen2VLImageProcessor` is now loaded as a fast processor by default, even if the model checkpoint was saved with a slow processor. This is a breaking change and may produce slightly different outputs. To continue using the slow processor, instantiate this class with `use_fast=False`. Note that this behavior will be extended to all models in a future release.
# You have video processor config saved in `preprocessor.json` file which is deprecated. Video processor configs should be saved in their own `video_preprocessor.json` file. You can rename the file or load and save the processor back which renames it automatically. Loading from `preprocessor.json` will be removed in v5.0.
# 2025-08-22 16:06:30,170 - INFO - Successfully loaded Qwen/Qwen2.5-VL-7B-Instruct, device: cuda
# 2025-08-22 16:06:30,171 - INFO - Apply save_hidden_states_sentence to hooked_modules: ['model.language_model.norm']
# 2025-08-22 16:06:30,171 - INFO - Successfully loaded image
# 2025-08-22 16:06:30,171 - INFO - Reading dataset: image of size: 1
# 2025-08-22 16:06:31,097 - INFO - Saving data to: /mnt/abka03/concept_extraction_result/rsml/gemma3n/MCoX/SNMF/mscoco/val/features/save_hidden_states_sentence_qween2_5.pth

# %%
# Project the image to the concept and explain 
prediction_path = f"{features_val_dir}/save_hidden_states_sentence_qween2_5.pth"

import sys

script_path = "/mnt/abka03/Projects/xl-vlms/src"
if script_path not in sys.path:
    sys.path.append(script_path)

from analysis.feature_decomposition import get_feature_matrix
module_name ="model.language_model.norm"
token_idx = None
output = torch.load(prediction_path)


absolute_features = output["hidden_states"]

feat_matrix = get_feature_matrix(
            absolute_features,
            module_name=module_name,
            token_idx=token_idx,
        )



phrase_and_text_prediction = output["model_predictions"]
phrases = [out[0].split("@")[0] for out in phrase_and_text_prediction]
print("Model predcition is: ", output["model_predictions"][0][0].split("@")[0])
print("Phrases are: ", phrases)

test_image_file_name = output["image"]
# Out:
# Model predcition is:  bear
# Phrases are:  ['bear']

# %%
import subprocess

# Define the concept you want to pass


# Run the script with the concept as argument
subprocess.run(
    ["scripts/run_feature_gen_cgdl.sh", model_card, cropped_data_path, train_output_dir, hugging_face_path ],
    cwd='/mnt/abka03/Projects/xl-vlms', 
    check=True
)
# Out:
# [0/10] Processing: airplane (Token: airplane, Concept: "airplane")
# [nltk_data] Downloading package words to /home/abka03/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# 2025-08-22 16:06:35,922 - INFO - Loading model: Qwen/Qwen2.5-VL-7B-Instruct
# 2025-08-22 16:06:35,922 - INFO - Arguments:
# 2025-08-22 16:06:35,922 - INFO - seed: 0
# 2025-08-22 16:06:35,922 - INFO - model_name_or_path: Qwen/Qwen2.5-VL-7B-Instruct
# 2025-08-22 16:06:35,922 - INFO - processor_name: None
# 2025-08-22 16:06:35,922 - INFO - local_files_only: False
# 2025-08-22 16:06:35,923 - INFO - cache_dir: None
# 2025-08-22 16:06:35,923 - INFO - prompt_template: cgdl
# 2025-08-22 16:06:35,923 - INFO - prompt: Describe the image in detail.
# 2025-08-22 16:06:35,923 - INFO - data_dir: /mnt/abka03/xlvlm_data/coco_cc0_plus_cropped/train/airplane/
# 2025-08-22 16:06:35,923 - INFO - annotation_file: annotations.json
# 2025-08-22 16:06:35,923 - INFO - questions_file: annotations.json
# 2025-08-22 16:06:35,923 - INFO - answer_type_to_answer: None
# 2025-08-22 16:06:35,923 - INFO - split: train
# 2025-08-22 16:06:35,923 - INFO - dataset_size: 120
# 2025-08-22 16:06:35,923 - INFO - dataset_name: image
# 2025-08-22 16:06:35,923 - INFO - batch_size: 1
# 2025-08-22 16:06:35,923 - INFO - hook_names: ['save_hidden_states_sentence']
# 2025-08-22 16:06:35,923 - INFO - modules_to_hook: [['model.language_model.norm']]
# 2025-08-22 16:06:35,923 - INFO - exact_match_modules_to_hook: True
# 2025-08-22 16:06:35,923 - INFO - hook_postprocessing_name: save_hidden_states
# 2025-08-22 16:06:35,923 - INFO - token_idx: None
# 2025-08-22 16:06:35,923 - INFO - token_start_end_idx: None
# 2025-08-22 16:06:35,923 - INFO - save_dir: /mnt/abka03/concept_extraction_result/rsml/gemma3n/MCoX/SNMF/mscoco/train
# 2025-08-22 16:06:35,923 - INFO - save_filename: qwen2_patched_image_airplane_token_of_interest_concept_generation_split_train
# 2025-08-22 16:06:35,923 - INFO - save_analysis: True
# 2025-08-22 16:06:35,923 - INFO - features_path: None
# 2025-08-22 16:06:35,923 - INFO - analysis_saving_path: results/analysis.pth
# 2025-08-22 16:06:35,923 - INFO - analysis_name: decompose_activations
# 2025-08-22 16:06:35,923 - INFO - feature_key: hidden_states
# 2025-08-22 16:06:35,923 - INFO - module_to_decompose: None
# 2025-08-22 16:06:35,923 - INFO - decomposition_extract_pos: None
# 2025-08-22 16:06:35,923 - INFO - decomposition_method: None
# 2025-08-22 16:06:35,923 - INFO - num_concepts: None
# 2025-08-22 16:06:35,923 - INFO - dl_max_iter: 12000
# 2025-08-22 16:06:35,923 - INFO - num_grounded_text_tokens: 5
# 2025-08-22 16:06:35,923 - INFO - pre_num_top_tokens: 20
# 2025-08-22 16:06:35,923 - INFO - num_most_activating_samples: 3
# 2025-08-22 16:06:35,923 - INFO - generation_mode: True
# 2025-08-22 16:06:35,923 - INFO - max_new_tokens: 50
# 2025-08-22 16:06:35,923 - INFO - token_of_interest_num_samples: -1
# 2025-08-22 16:06:35,923 - INFO - select_token_of_interest_samples: False
# 2025-08-22 16:06:35,923 - INFO - allow_different_variations_of_token_of_interest: False
# 2025-08-22 16:06:35,923 - INFO - token_of_interest: None
# 2025-08-22 16:06:35,923 - INFO - tokens_of_interest: None
# 2025-08-22 16:06:35,923 - INFO - token_of_interest_key: response
# 2025-08-22 16:06:35,923 - INFO - token_of_interest_class: None
# 2025-08-22 16:06:35,923 - INFO - token_of_interest_idx: None
# 2025-08-22 16:06:35,923 - INFO - token_of_interest_start_token: 0
# 2025-08-22 16:06:35,923 - INFO - end_special_tokens:
# 2025-08-22 16:06:35,923 - INFO - save_only_generated_tokens: True
# 2025-08-22 16:06:35,923 - INFO - load_matched_features: False
# 2025-08-22 16:06:35,923 - INFO - steering_method: shift_of_means
# 2025-08-22 16:06:35,924 - INFO - steering_alpha: 1
# 2025-08-22 16:06:35,924 - INFO - category_of_interest:
# 2025-08-22 16:06:35,924 - INFO - base_features_key: hidden_states
# 2025-08-22 16:06:35,924 - INFO - shift_vector_path:
# 2025-08-22 16:06:35,924 - INFO - shift_vector_key: steering_vector
# 2025-08-22 16:06:35,924 - INFO - start_prompt_token_idx_steering: 0
# 2025-08-22 16:06:35,924 - INFO - use_random_grounding_words: False
# 2025-08-22 16:06:35,924 - INFO - captioning_metrics: ['CIDEr']
# 2025-08-22 16:06:35,924 - INFO - predictions_token_of_interest: None
# 2025-08-22 16:06:35,924 - INFO - targets_token_of_interest: None
# 2025-08-22 16:06:35,924 - INFO - save_predictions: False
# 2025-08-22 16:06:35,924 - INFO - predictions_path: None
# 2025-08-22 16:06:35,924 - INFO - origin_model_analysis_path: None
# 2025-08-22 16:06:35,924 - INFO - origin_model_feature_path: None
# 2025-08-22 16:06:35,924 - INFO - dest_model_analysis_path: None
# 2025-08-22 16:06:35,924 - INFO - dest_model_feature_path: None
# 2025-08-22 16:06:35,924 - INFO - visualize_concepts: False
# 2025-08-22 16:06:35,924 - INFO - compute_recovery_metrics: False
# 2025-08-22 16:06:35,924 - INFO - compute_stat_shift_vectors: False
# 2025-08-22 16:06:35,924 - INFO - select_samples_from_ids: False
# 2025-08-22 16:06:35,924 - INFO - path_to_samples_ids: None
# 2025-08-22 16:06:35,924 - INFO - slice_prediction: True
# 2025-08-22 16:06:35,924 - INFO - post_process_hidden: False
# 2025-08-22 16:06:35,924 - INFO - concept: airplane
# /mnt/abka03/.conda/envs/rsml3/lib/python3.9/site-packages/transformers/models/auto/modeling_auto.py:2199: FutureWarning: The class `AutoModelForVision2Seq` is deprecated and will be removed in v5.0. Please use `AutoModelForImageTextToText` instead.
#   warnings.warn(
# Loading checkpoint shards: 100%|██████████| 5/5 [00:02<00:00,  1.82it/s]
# The image processor of type `Qwen2VLImageProcessor` is now loaded as a fast processor by default, even if the model checkpoint was saved with a slow processor. This is a breaking change and may produce slightly different outputs. To continue using the slow processor, instantiate this class with `use_fast=False`. Note that this behavior will be extended to all models in a future release.
# You have video processor config saved in `preprocessor.json` file which is deprecated. Video processor configs should be saved in their own `video_preprocessor.json` file. You can rename the file or load and save the processor back which renames it automatically. Loading from `preprocessor.json` will be removed in v5.0.
# 2025-08-22 16:06:41,447 - INFO - Successfully loaded Qwen/Qwen2.5-VL-7B-Instruct, device: cuda
# 2025-08-22 16:06:41,448 - INFO - Apply save_hidden_states_sentence to hooked_modules: ['model.language_model.norm']
# 2025-08-22 16:06:41,449 - INFO - Successfully loaded image
# 2025-08-22 16:06:41,449 - INFO - Reading dataset: image of size: 120
# 2025-08-22 16:06:52,892 - INFO - Iteration: 99/120,  Estimated time left: 0.04 mins
# 2025-08-22 16:06:55,090 - INFO - Saving data to: /mnt/abka03/concept_extraction_result/rsml/gemma3n/MCoX/SNMF/mscoco/train/features/save_hidden_states_sentence_qwen2_patched_image_airplane_token_of_interest_concept_generation_split_train.pth
# [1/10] Processing: apple (Token: apple, Concept: "apple")
# [nltk_data] Downloading package words to /home/abka03/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# 2025-08-22 16:06:59,777 - INFO - Loading model: Qwen/Qwen2.5-VL-7B-Instruct
# 2025-08-22 16:06:59,777 - INFO - Arguments:
# 2025-08-22 16:06:59,777 - INFO - seed: 0
# 2025-08-22 16:06:59,777 - INFO - model_name_or_path: Qwen/Qwen2.5-VL-7B-Instruct
# 2025-08-22 16:06:59,777 - INFO - processor_name: None
# 2025-08-22 16:06:59,777 - INFO - local_files_only: False
# 2025-08-22 16:06:59,777 - INFO - cache_dir: None
# 2025-08-22 16:06:59,777 - INFO - prompt_template: cgdl
# 2025-08-22 16:06:59,777 - INFO - prompt: Describe the image in detail.
# 2025-08-22 16:06:59,777 - INFO - data_dir: /mnt/abka03/xlvlm_data/coco_cc0_plus_cropped/train/apple/
# 2025-08-22 16:06:59,777 - INFO - annotation_file: annotations.json
# 2025-08-22 16:06:59,777 - INFO - questions_file: annotations.json
# 2025-08-22 16:06:59,777 - INFO - answer_type_to_answer: None
# 2025-08-22 16:06:59,777 - INFO - split: train
# 2025-08-22 16:06:59,777 - INFO - dataset_size: 120
# 2025-08-22 16:06:59,777 - INFO - dataset_name: image
# 2025-08-22 16:06:59,777 - INFO - batch_size: 1
# 2025-08-22 16:06:59,777 - INFO - hook_names: ['save_hidden_states_sentence']
# 2025-08-22 16:06:59,777 - INFO - modules_to_hook: [['model.language_model.norm']]
# 2025-08-22 16:06:59,777 - INFO - exact_match_modules_to_hook: True
# 2025-08-22 16:06:59,777 - INFO - hook_postprocessing_name: save_hidden_states
# 2025-08-22 16:06:59,777 - INFO - token_idx: None
# 2025-08-22 16:06:59,777 - INFO - token_start_end_idx: None
# 2025-08-22 16:06:59,777 - INFO - save_dir: /mnt/abka03/concept_extraction_result/rsml/gemma3n/MCoX/SNMF/mscoco/train
# 2025-08-22 16:06:59,777 - INFO - save_filename: qwen2_patched_image_apple_token_of_interest_concept_generation_split_train
# 2025-08-22 16:06:59,777 - INFO - save_analysis: True
# 2025-08-22 16:06:59,777 - INFO - features_path: None
# 2025-08-22 16:06:59,777 - INFO - analysis_saving_path: results/analysis.pth
# 2025-08-22 16:06:59,778 - INFO - analysis_name: decompose_activations
# 2025-08-22 16:06:59,778 - INFO - feature_key: hidden_states
# 2025-08-22 16:06:59,778 - INFO - module_to_decompose: None
# 2025-08-22 16:06:59,778 - INFO - decomposition_extract_pos: None
# 2025-08-22 16:06:59,778 - INFO - decomposition_method: None
# 2025-08-22 16:06:59,778 - INFO - num_concepts: None
# 2025-08-22 16:06:59,778 - INFO - dl_max_iter: 12000
# 2025-08-22 16:06:59,778 - INFO - num_grounded_text_tokens: 5
# 2025-08-22 16:06:59,778 - INFO - pre_num_top_tokens: 20
# 2025-08-22 16:06:59,778 - INFO - num_most_activating_samples: 3
# 2025-08-22 16:06:59,778 - INFO - generation_mode: True
# 2025-08-22 16:06:59,778 - INFO - max_new_tokens: 50
# 2025-08-22 16:06:59,778 - INFO - token_of_interest_num_samples: -1
# 2025-08-22 16:06:59,778 - INFO - select_token_of_interest_samples: False
# 2025-08-22 16:06:59,778 - INFO - allow_different_variations_of_token_of_interest: False
# 2025-08-22 16:06:59,778 - INFO - token_of_interest: None
# 2025-08-22 16:06:59,778 - INFO - tokens_of_interest: None
# 2025-08-22 16:06:59,778 - INFO - token_of_interest_key: response
# 2025-08-22 16:06:59,778 - INFO - token_of_interest_class: None
# 2025-08-22 16:06:59,778 - INFO - token_of_interest_idx: None
# 2025-08-22 16:06:59,778 - INFO - token_of_interest_start_token: 0
# 2025-08-22 16:06:59,778 - INFO - end_special_tokens:
# 2025-08-22 16:06:59,778 - INFO - save_only_generated_tokens: True
# 2025-08-22 16:06:59,778 - INFO - load_matched_features: False
# 2025-08-22 16:06:59,778 - INFO - steering_method: shift_of_means
# 2025-08-22 16:06:59,778 - INFO - steering_alpha: 1
# 2025-08-22 16:06:59,778 - INFO - category_of_interest:
# 2025-08-22 16:06:59,778 - INFO - base_features_key: hidden_states
# 2025-08-22 16:06:59,778 - INFO - shift_vector_path:
# 2025-08-22 16:06:59,778 - INFO - shift_vector_key: steering_vector
# 2025-08-22 16:06:59,778 - INFO - start_prompt_token_idx_steering: 0
# 2025-08-22 16:06:59,778 - INFO - use_random_grounding_words: False
# 2025-08-22 16:06:59,778 - INFO - captioning_metrics: ['CIDEr']
# 2025-08-22 16:06:59,778 - INFO - predictions_token_of_interest: None
# 2025-08-22 16:06:59,778 - INFO - targets_token_of_interest: None
# 2025-08-22 16:06:59,778 - INFO - save_predictions: False
# 2025-08-22 16:06:59,778 - INFO - predictions_path: None
# 2025-08-22 16:06:59,778 - INFO - origin_model_analysis_path: None
# 2025-08-22 16:06:59,778 - INFO - origin_model_feature_path: None
# 2025-08-22 16:06:59,778 - INFO - dest_model_analysis_path: None
# 2025-08-22 16:06:59,778 - INFO - dest_model_feature_path: None
# 2025-08-22 16:06:59,778 - INFO - visualize_concepts: False
# 2025-08-22 16:06:59,778 - INFO - compute_recovery_metrics: False
# 2025-08-22 16:06:59,778 - INFO - compute_stat_shift_vectors: False
# 2025-08-22 16:06:59,778 - INFO - select_samples_from_ids: False
# 2025-08-22 16:06:59,778 - INFO - path_to_samples_ids: None
# 2025-08-22 16:06:59,778 - INFO - slice_prediction: True
# 2025-08-22 16:06:59,778 - INFO - post_process_hidden: False
# 2025-08-22 16:06:59,778 - INFO - concept: apple
# /mnt/abka03/.conda/envs/rsml3/lib/python3.9/site-packages/transformers/models/auto/modeling_auto.py:2199: FutureWarning: The class `AutoModelForVision2Seq` is deprecated and will be removed in v5.0. Please use `AutoModelForImageTextToText` instead.
#   warnings.warn(
# Loading checkpoint shards: 100%|██████████| 5/5 [00:02<00:00,  1.83it/s]
# The image processor of type `Qwen2VLImageProcessor` is now loaded as a fast processor by default, even if the model checkpoint was saved with a slow processor. This is a breaking change and may produce slightly different outputs. To continue using the slow processor, instantiate this class with `use_fast=False`. Note that this behavior will be extended to all models in a future release.
# You have video processor config saved in `preprocessor.json` file which is deprecated. Video processor configs should be saved in their own `video_preprocessor.json` file. You can rename the file or load and save the processor back which renames it automatically. Loading from `preprocessor.json` will be removed in v5.0.
# 2025-08-22 16:07:05,330 - INFO - Successfully loaded Qwen/Qwen2.5-VL-7B-Instruct, device: cuda
# 2025-08-22 16:07:05,330 - INFO - Apply save_hidden_states_sentence to hooked_modules: ['model.language_model.norm']
# 2025-08-22 16:07:05,331 - INFO - Successfully loaded image
# 2025-08-22 16:07:05,331 - INFO - Reading dataset: image of size: 120
# 2025-08-22 16:07:15,984 - INFO - Iteration: 99/120,  Estimated time left: 0.04 mins
# 2025-08-22 16:07:17,974 - INFO - Saving data to: /mnt/abka03/concept_extraction_result/rsml/gemma3n/MCoX/SNMF/mscoco/train/features/save_hidden_states_sentence_qwen2_patched_image_apple_token_of_interest_concept_generation_split_train.pth
# [2/10] Processing: backpack (Token: backpack, Concept: "backpack")
# [nltk_data] Downloading package words to /home/abka03/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# 2025-08-22 16:07:22,712 - INFO - Loading model: Qwen/Qwen2.5-VL-7B-Instruct
# 2025-08-22 16:07:22,712 - INFO - Arguments:
# 2025-08-22 16:07:22,712 - INFO - seed: 0
# 2025-08-22 16:07:22,712 - INFO - model_name_or_path: Qwen/Qwen2.5-VL-7B-Instruct
# 2025-08-22 16:07:22,712 - INFO - processor_name: None
# 2025-08-22 16:07:22,712 - INFO - local_files_only: False
# 2025-08-22 16:07:22,712 - INFO - cache_dir: None
# 2025-08-22 16:07:22,712 - INFO - prompt_template: cgdl
# 2025-08-22 16:07:22,712 - INFO - prompt: Describe the image in detail.
# 2025-08-22 16:07:22,712 - INFO - data_dir: /mnt/abka03/xlvlm_data/coco_cc0_plus_cropped/train/backpack/
# 2025-08-22 16:07:22,712 - INFO - annotation_file: annotations.json
# 2025-08-22 16:07:22,712 - INFO - questions_file: annotations.json
# 2025-08-22 16:07:22,712 - INFO - answer_type_to_answer: None
# 2025-08-22 16:07:22,712 - INFO - split: train
# 2025-08-22 16:07:22,712 - INFO - dataset_size: 120
# 2025-08-22 16:07:22,712 - INFO - dataset_name: image
# 2025-08-22 16:07:22,712 - INFO - batch_size: 1
# 2025-08-22 16:07:22,712 - INFO - hook_names: ['save_hidden_states_sentence']
# 2025-08-22 16:07:22,712 - INFO - modules_to_hook: [['model.language_model.norm']]
# 2025-08-22 16:07:22,712 - INFO - exact_match_modules_to_hook: True
# 2025-08-22 16:07:22,712 - INFO - hook_postprocessing_name: save_hidden_states
# 2025-08-22 16:07:22,712 - INFO - token_idx: None
# 2025-08-22 16:07:22,712 - INFO - token_start_end_idx: None
# 2025-08-22 16:07:22,712 - INFO - save_dir: /mnt/abka03/concept_extraction_result/rsml/gemma3n/MCoX/SNMF/mscoco/train
# 2025-08-22 16:07:22,713 - INFO - save_filename: qwen2_patched_image_backpack_token_of_interest_concept_generation_split_train
# 2025-08-22 16:07:22,713 - INFO - save_analysis: True
# 2025-08-22 16:07:22,713 - INFO - features_path: None
# 2025-08-22 16:07:22,713 - INFO - analysis_saving_path: results/analysis.pth
# 2025-08-22 16:07:22,713 - INFO - analysis_name: decompose_activations
# 2025-08-22 16:07:22,713 - INFO - feature_key: hidden_states
# 2025-08-22 16:07:22,713 - INFO - module_to_decompose: None
# 2025-08-22 16:07:22,713 - INFO - decomposition_extract_pos: None
# 2025-08-22 16:07:22,713 - INFO - decomposition_method: None
# 2025-08-22 16:07:22,713 - INFO - num_concepts: None
# 2025-08-22 16:07:22,713 - INFO - dl_max_iter: 12000
# 2025-08-22 16:07:22,713 - INFO - num_grounded_text_tokens: 5
# 2025-08-22 16:07:22,713 - INFO - pre_num_top_tokens: 20
# 2025-08-22 16:07:22,713 - INFO - num_most_activating_samples: 3
# 2025-08-22 16:07:22,713 - INFO - generation_mode: True
# 2025-08-22 16:07:22,713 - INFO - max_new_tokens: 50
# 2025-08-22 16:07:22,713 - INFO - token_of_interest_num_samples: -1
# 2025-08-22 16:07:22,713 - INFO - select_token_of_interest_samples: False
# 2025-08-22 16:07:22,713 - INFO - allow_different_variations_of_token_of_interest: False
# 2025-08-22 16:07:22,713 - INFO - token_of_interest: None
# 2025-08-22 16:07:22,713 - INFO - tokens_of_interest: None
# 2025-08-22 16:07:22,713 - INFO - token_of_interest_key: response
# 2025-08-22 16:07:22,713 - INFO - token_of_interest_class: None
# 2025-08-22 16:07:22,713 - INFO - token_of_interest_idx: None
# 2025-08-22 16:07:22,713 - INFO - token_of_interest_start_token: 0
# 2025-08-22 16:07:22,713 - INFO - end_special_tokens:
# 2025-08-22 16:07:22,713 - INFO - save_only_generated_tokens: True
# 2025-08-22 16:07:22,713 - INFO - load_matched_features: False
# 2025-08-22 16:07:22,713 - INFO - steering_method: shift_of_means
# 2025-08-22 16:07:22,713 - INFO - steering_alpha: 1
# 2025-08-22 16:07:22,713 - INFO - category_of_interest:
# 2025-08-22 16:07:22,713 - INFO - base_features_key: hidden_states
# 2025-08-22 16:07:22,713 - INFO - shift_vector_path:
# 2025-08-22 16:07:22,713 - INFO - shift_vector_key: steering_vector
# 2025-08-22 16:07:22,713 - INFO - start_prompt_token_idx_steering: 0
# 2025-08-22 16:07:22,713 - INFO - use_random_grounding_words: False
# 2025-08-22 16:07:22,713 - INFO - captioning_metrics: ['CIDEr']
# 2025-08-22 16:07:22,713 - INFO - predictions_token_of_interest: None
# 2025-08-22 16:07:22,713 - INFO - targets_token_of_interest: None
# 2025-08-22 16:07:22,713 - INFO - save_predictions: False
# 2025-08-22 16:07:22,713 - INFO - predictions_path: None
# 2025-08-22 16:07:22,713 - INFO - origin_model_analysis_path: None
# 2025-08-22 16:07:22,713 - INFO - origin_model_feature_path: None
# 2025-08-22 16:07:22,713 - INFO - dest_model_analysis_path: None
# 2025-08-22 16:07:22,713 - INFO - dest_model_feature_path: None
# 2025-08-22 16:07:22,713 - INFO - visualize_concepts: False
# 2025-08-22 16:07:22,713 - INFO - compute_recovery_metrics: False
# 2025-08-22 16:07:22,713 - INFO - compute_stat_shift_vectors: False
# 2025-08-22 16:07:22,713 - INFO - select_samples_from_ids: False
# 2025-08-22 16:07:22,714 - INFO - path_to_samples_ids: None
# 2025-08-22 16:07:22,714 - INFO - slice_prediction: True
# 2025-08-22 16:07:22,714 - INFO - post_process_hidden: False
# 2025-08-22 16:07:22,714 - INFO - concept: backpack
# /mnt/abka03/.conda/envs/rsml3/lib/python3.9/site-packages/transformers/models/auto/modeling_auto.py:2199: FutureWarning: The class `AutoModelForVision2Seq` is deprecated and will be removed in v5.0. Please use `AutoModelForImageTextToText` instead.
#   warnings.warn(
# Loading checkpoint shards: 100%|██████████| 5/5 [00:02<00:00,  1.81it/s]
# The image processor of type `Qwen2VLImageProcessor` is now loaded as a fast processor by default, even if the model checkpoint was saved with a slow processor. This is a breaking change and may produce slightly different outputs. To continue using the slow processor, instantiate this class with `use_fast=False`. Note that this behavior will be extended to all models in a future release.
# You have video processor config saved in `preprocessor.json` file which is deprecated. Video processor configs should be saved in their own `video_preprocessor.json` file. You can rename the file or load and save the processor back which renames it automatically. Loading from `preprocessor.json` will be removed in v5.0.
# 2025-08-22 16:07:28,267 - INFO - Successfully loaded Qwen/Qwen2.5-VL-7B-Instruct, device: cuda
# 2025-08-22 16:07:28,268 - INFO - Apply save_hidden_states_sentence to hooked_modules: ['model.language_model.norm']
# 2025-08-22 16:07:28,269 - INFO - Successfully loaded image
# 2025-08-22 16:07:28,269 - INFO - Reading dataset: image of size: 120
# 2025-08-22 16:07:40,000 - INFO - Iteration: 99/120,  Estimated time left: 0.04 mins
# 2025-08-22 16:07:42,212 - INFO - Saving data to: /mnt/abka03/concept_extraction_result/rsml/gemma3n/MCoX/SNMF/mscoco/train/features/save_hidden_states_sentence_qwen2_patched_image_backpack_token_of_interest_concept_generation_split_train.pth
# [3/10] Processing: banana (Token: banana, Concept: "banana")
# [nltk_data] Downloading package words to /home/abka03/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# 2025-08-22 16:07:46,962 - INFO - Loading model: Qwen/Qwen2.5-VL-7B-Instruct
# 2025-08-22 16:07:46,962 - INFO - Arguments:
# 2025-08-22 16:07:46,962 - INFO - seed: 0
# 2025-08-22 16:07:46,962 - INFO - model_name_or_path: Qwen/Qwen2.5-VL-7B-Instruct
# 2025-08-22 16:07:46,962 - INFO - processor_name: None
# 2025-08-22 16:07:46,962 - INFO - local_files_only: False
# 2025-08-22 16:07:46,962 - INFO - cache_dir: None
# 2025-08-22 16:07:46,962 - INFO - prompt_template: cgdl
# 2025-08-22 16:07:46,962 - INFO - prompt: Describe the image in detail.
# 2025-08-22 16:07:46,962 - INFO - data_dir: /mnt/abka03/xlvlm_data/coco_cc0_plus_cropped/train/banana/
# 2025-08-22 16:07:46,962 - INFO - annotation_file: annotations.json
# 2025-08-22 16:07:46,962 - INFO - questions_file: annotations.json
# 2025-08-22 16:07:46,962 - INFO - answer_type_to_answer: None
# 2025-08-22 16:07:46,962 - INFO - split: train
# 2025-08-22 16:07:46,962 - INFO - dataset_size: 120
# 2025-08-22 16:07:46,962 - INFO - dataset_name: image
# 2025-08-22 16:07:46,962 - INFO - batch_size: 1
# 2025-08-22 16:07:46,962 - INFO - hook_names: ['save_hidden_states_sentence']
# 2025-08-22 16:07:46,962 - INFO - modules_to_hook: [['model.language_model.norm']]
# 2025-08-22 16:07:46,962 - INFO - exact_match_modules_to_hook: True
# 2025-08-22 16:07:46,962 - INFO - hook_postprocessing_name: save_hidden_states
# 2025-08-22 16:07:46,963 - INFO - token_idx: None
# 2025-08-22 16:07:46,963 - INFO - token_start_end_idx: None
# 2025-08-22 16:07:46,963 - INFO - save_dir: /mnt/abka03/concept_extraction_result/rsml/gemma3n/MCoX/SNMF/mscoco/train
# 2025-08-22 16:07:46,963 - INFO - save_filename: qwen2_patched_image_banana_token_of_interest_concept_generation_split_train
# 2025-08-22 16:07:46,963 - INFO - save_analysis: True
# 2025-08-22 16:07:46,963 - INFO - features_path: None
# 2025-08-22 16:07:46,963 - INFO - analysis_saving_path: results/analysis.pth
# 2025-08-22 16:07:46,963 - INFO - analysis_name: decompose_activations
# 2025-08-22 16:07:46,963 - INFO - feature_key: hidden_states
# 2025-08-22 16:07:46,963 - INFO - module_to_decompose: None
# 2025-08-22 16:07:46,963 - INFO - decomposition_extract_pos: None
# 2025-08-22 16:07:46,963 - INFO - decomposition_method: None
# 2025-08-22 16:07:46,963 - INFO - num_concepts: None
# 2025-08-22 16:07:46,963 - INFO - dl_max_iter: 12000
# 2025-08-22 16:07:46,963 - INFO - num_grounded_text_tokens: 5
# 2025-08-22 16:07:46,963 - INFO - pre_num_top_tokens: 20
# 2025-08-22 16:07:46,963 - INFO - num_most_activating_samples: 3
# 2025-08-22 16:07:46,963 - INFO - generation_mode: True
# 2025-08-22 16:07:46,963 - INFO - max_new_tokens: 50
# 2025-08-22 16:07:46,963 - INFO - token_of_interest_num_samples: -1
# 2025-08-22 16:07:46,963 - INFO - select_token_of_interest_samples: False
# 2025-08-22 16:07:46,963 - INFO - allow_different_variations_of_token_of_interest: False
# 2025-08-22 16:07:46,963 - INFO - token_of_interest: None
# 2025-08-22 16:07:46,963 - INFO - tokens_of_interest: None
# 2025-08-22 16:07:46,963 - INFO - token_of_interest_key: response
# 2025-08-22 16:07:46,963 - INFO - token_of_interest_class: None
# 2025-08-22 16:07:46,963 - INFO - token_of_interest_idx: None
# 2025-08-22 16:07:46,963 - INFO - token_of_interest_start_token: 0
# 2025-08-22 16:07:46,963 - INFO - end_special_tokens:
# 2025-08-22 16:07:46,963 - INFO - save_only_generated_tokens: True
# 2025-08-22 16:07:46,963 - INFO - load_matched_features: False
# 2025-08-22 16:07:46,963 - INFO - steering_method: shift_of_means
# 2025-08-22 16:07:46,963 - INFO - steering_alpha: 1
# 2025-08-22 16:07:46,963 - INFO - category_of_interest:
# 2025-08-22 16:07:46,963 - INFO - base_features_key: hidden_states
# 2025-08-22 16:07:46,963 - INFO - shift_vector_path:
# 2025-08-22 16:07:46,963 - INFO - shift_vector_key: steering_vector
# 2025-08-22 16:07:46,963 - INFO - start_prompt_token_idx_steering: 0
# 2025-08-22 16:07:46,963 - INFO - use_random_grounding_words: False
# 2025-08-22 16:07:46,963 - INFO - captioning_metrics: ['CIDEr']
# 2025-08-22 16:07:46,963 - INFO - predictions_token_of_interest: None
# 2025-08-22 16:07:46,963 - INFO - targets_token_of_interest: None
# 2025-08-22 16:07:46,963 - INFO - save_predictions: False
# 2025-08-22 16:07:46,963 - INFO - predictions_path: None
# 2025-08-22 16:07:46,963 - INFO - origin_model_analysis_path: None
# 2025-08-22 16:07:46,963 - INFO - origin_model_feature_path: None
# 2025-08-22 16:07:46,963 - INFO - dest_model_analysis_path: None
# 2025-08-22 16:07:46,963 - INFO - dest_model_feature_path: None
# 2025-08-22 16:07:46,963 - INFO - visualize_concepts: False
# 2025-08-22 16:07:46,963 - INFO - compute_recovery_metrics: False
# 2025-08-22 16:07:46,963 - INFO - compute_stat_shift_vectors: False
# 2025-08-22 16:07:46,963 - INFO - select_samples_from_ids: False
# 2025-08-22 16:07:46,963 - INFO - path_to_samples_ids: None
# 2025-08-22 16:07:46,964 - INFO - slice_prediction: True
# 2025-08-22 16:07:46,964 - INFO - post_process_hidden: False
# 2025-08-22 16:07:46,964 - INFO - concept: banana
# /mnt/abka03/.conda/envs/rsml3/lib/python3.9/site-packages/transformers/models/auto/modeling_auto.py:2199: FutureWarning: The class `AutoModelForVision2Seq` is deprecated and will be removed in v5.0. Please use `AutoModelForImageTextToText` instead.
#   warnings.warn(
# Loading checkpoint shards: 100%|██████████| 5/5 [00:02<00:00,  1.82it/s]
# The image processor of type `Qwen2VLImageProcessor` is now loaded as a fast processor by default, even if the model checkpoint was saved with a slow processor. This is a breaking change and may produce slightly different outputs. To continue using the slow processor, instantiate this class with `use_fast=False`. Note that this behavior will be extended to all models in a future release.
# You have video processor config saved in `preprocessor.json` file which is deprecated. Video processor configs should be saved in their own `video_preprocessor.json` file. You can rename the file or load and save the processor back which renames it automatically. Loading from `preprocessor.json` will be removed in v5.0.
# 2025-08-22 16:07:52,576 - INFO - Successfully loaded Qwen/Qwen2.5-VL-7B-Instruct, device: cuda
# 2025-08-22 16:07:52,577 - INFO - Apply save_hidden_states_sentence to hooked_modules: ['model.language_model.norm']
# 2025-08-22 16:07:52,577 - INFO - Successfully loaded image
# 2025-08-22 16:07:52,577 - INFO - Reading dataset: image of size: 120
# 2025-08-22 16:08:03,146 - INFO - Iteration: 99/120,  Estimated time left: 0.04 mins
# 2025-08-22 16:08:05,139 - INFO - Saving data to: /mnt/abka03/concept_extraction_result/rsml/gemma3n/MCoX/SNMF/mscoco/train/features/save_hidden_states_sentence_qwen2_patched_image_banana_token_of_interest_concept_generation_split_train.pth
# [4/10] Processing: baseball_bat (Token: bat, Concept: "baseball bat")
# [nltk_data] Downloading package words to /home/abka03/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# 2025-08-22 16:08:09,836 - INFO - Loading model: Qwen/Qwen2.5-VL-7B-Instruct
# 2025-08-22 16:08:09,837 - INFO - Arguments:
# 2025-08-22 16:08:09,837 - INFO - seed: 0
# 2025-08-22 16:08:09,837 - INFO - model_name_or_path: Qwen/Qwen2.5-VL-7B-Instruct
# 2025-08-22 16:08:09,837 - INFO - processor_name: None
# 2025-08-22 16:08:09,837 - INFO - local_files_only: False
# 2025-08-22 16:08:09,837 - INFO - cache_dir: None
# 2025-08-22 16:08:09,837 - INFO - prompt_template: cgdl
# 2025-08-22 16:08:09,837 - INFO - prompt: Describe the image in detail.
# 2025-08-22 16:08:09,837 - INFO - data_dir: /mnt/abka03/xlvlm_data/coco_cc0_plus_cropped/train/baseball_bat/
# 2025-08-22 16:08:09,837 - INFO - annotation_file: annotations.json
# 2025-08-22 16:08:09,837 - INFO - questions_file: annotations.json
# 2025-08-22 16:08:09,837 - INFO - answer_type_to_answer: None
# 2025-08-22 16:08:09,837 - INFO - split: train
# 2025-08-22 16:08:09,837 - INFO - dataset_size: 120
# 2025-08-22 16:08:09,837 - INFO - dataset_name: image
# 2025-08-22 16:08:09,837 - INFO - batch_size: 1
# 2025-08-22 16:08:09,837 - INFO - hook_names: ['save_hidden_states_sentence']
# 2025-08-22 16:08:09,837 - INFO - modules_to_hook: [['model.language_model.norm']]
# 2025-08-22 16:08:09,837 - INFO - exact_match_modules_to_hook: True
# 2025-08-22 16:08:09,837 - INFO - hook_postprocessing_name: save_hidden_states
# 2025-08-22 16:08:09,837 - INFO - token_idx: None
# 2025-08-22 16:08:09,837 - INFO - token_start_end_idx: None
# 2025-08-22 16:08:09,837 - INFO - save_dir: /mnt/abka03/concept_extraction_result/rsml/gemma3n/MCoX/SNMF/mscoco/train
# 2025-08-22 16:08:09,837 - INFO - save_filename: qwen2_patched_image_baseball_bat_token_of_interest_concept_generation_split_train
# 2025-08-22 16:08:09,837 - INFO - save_analysis: True
# 2025-08-22 16:08:09,837 - INFO - features_path: None
# 2025-08-22 16:08:09,837 - INFO - analysis_saving_path: results/analysis.pth
# 2025-08-22 16:08:09,837 - INFO - analysis_name: decompose_activations
# 2025-08-22 16:08:09,837 - INFO - feature_key: hidden_states
# 2025-08-22 16:08:09,837 - INFO - module_to_decompose: None
# 2025-08-22 16:08:09,837 - INFO - decomposition_extract_pos: None
# 2025-08-22 16:08:09,837 - INFO - decomposition_method: None
# 2025-08-22 16:08:09,837 - INFO - num_concepts: None
# 2025-08-22 16:08:09,837 - INFO - dl_max_iter: 12000
# 2025-08-22 16:08:09,837 - INFO - num_grounded_text_tokens: 5
# 2025-08-22 16:08:09,837 - INFO - pre_num_top_tokens: 20
# 2025-08-22 16:08:09,837 - INFO - num_most_activating_samples: 3
# 2025-08-22 16:08:09,837 - INFO - generation_mode: True
# 2025-08-22 16:08:09,837 - INFO - max_new_tokens: 50
# 2025-08-22 16:08:09,837 - INFO - token_of_interest_num_samples: -1
# 2025-08-22 16:08:09,837 - INFO - select_token_of_interest_samples: False
# 2025-08-22 16:08:09,837 - INFO - allow_different_variations_of_token_of_interest: False
# 2025-08-22 16:08:09,837 - INFO - token_of_interest: None
# 2025-08-22 16:08:09,837 - INFO - tokens_of_interest: None
# 2025-08-22 16:08:09,837 - INFO - token_of_interest_key: response
# 2025-08-22 16:08:09,837 - INFO - token_of_interest_class: None
# 2025-08-22 16:08:09,837 - INFO - token_of_interest_idx: None
# 2025-08-22 16:08:09,838 - INFO - token_of_interest_start_token: 0
# 2025-08-22 16:08:09,838 - INFO - end_special_tokens:
# 2025-08-22 16:08:09,838 - INFO - save_only_generated_tokens: True
# 2025-08-22 16:08:09,838 - INFO - load_matched_features: False
# 2025-08-22 16:08:09,838 - INFO - steering_method: shift_of_means
# 2025-08-22 16:08:09,838 - INFO - steering_alpha: 1
# 2025-08-22 16:08:09,838 - INFO - category_of_interest:
# 2025-08-22 16:08:09,838 - INFO - base_features_key: hidden_states
# 2025-08-22 16:08:09,838 - INFO - shift_vector_path:
# 2025-08-22 16:08:09,838 - INFO - shift_vector_key: steering_vector
# 2025-08-22 16:08:09,838 - INFO - start_prompt_token_idx_steering: 0
# 2025-08-22 16:08:09,838 - INFO - use_random_grounding_words: False
# 2025-08-22 16:08:09,838 - INFO - captioning_metrics: ['CIDEr']
# 2025-08-22 16:08:09,838 - INFO - predictions_token_of_interest: None
# 2025-08-22 16:08:09,838 - INFO - targets_token_of_interest: None
# 2025-08-22 16:08:09,838 - INFO - save_predictions: False
# 2025-08-22 16:08:09,838 - INFO - predictions_path: None
# 2025-08-22 16:08:09,838 - INFO - origin_model_analysis_path: None
# 2025-08-22 16:08:09,838 - INFO - origin_model_feature_path: None
# 2025-08-22 16:08:09,838 - INFO - dest_model_analysis_path: None
# 2025-08-22 16:08:09,838 - INFO - dest_model_feature_path: None
# 2025-08-22 16:08:09,838 - INFO - visualize_concepts: False
# 2025-08-22 16:08:09,838 - INFO - compute_recovery_metrics: False
# 2025-08-22 16:08:09,838 - INFO - compute_stat_shift_vectors: False
# 2025-08-22 16:08:09,838 - INFO - select_samples_from_ids: False
# 2025-08-22 16:08:09,838 - INFO - path_to_samples_ids: None
# 2025-08-22 16:08:09,838 - INFO - slice_prediction: True
# 2025-08-22 16:08:09,838 - INFO - post_process_hidden: False
# 2025-08-22 16:08:09,838 - INFO - concept: baseball bat
# /mnt/abka03/.conda/envs/rsml3/lib/python3.9/site-packages/transformers/models/auto/modeling_auto.py:2199: FutureWarning: The class `AutoModelForVision2Seq` is deprecated and will be removed in v5.0. Please use `AutoModelForImageTextToText` instead.
#   warnings.warn(
# Loading checkpoint shards: 100%|██████████| 5/5 [00:02<00:00,  1.80it/s]
# The image processor of type `Qwen2VLImageProcessor` is now loaded as a fast processor by default, even if the model checkpoint was saved with a slow processor. This is a breaking change and may produce slightly different outputs. To continue using the slow processor, instantiate this class with `use_fast=False`. Note that this behavior will be extended to all models in a future release.
# You have video processor config saved in `preprocessor.json` file which is deprecated. Video processor configs should be saved in their own `video_preprocessor.json` file. You can rename the file or load and save the processor back which renames it automatically. Loading from `preprocessor.json` will be removed in v5.0.
# 2025-08-22 16:08:15,361 - INFO - Successfully loaded Qwen/Qwen2.5-VL-7B-Instruct, device: cuda
# 2025-08-22 16:08:15,362 - INFO - Apply save_hidden_states_sentence to hooked_modules: ['model.language_model.norm']
# 2025-08-22 16:08:15,362 - INFO - Successfully loaded image
# 2025-08-22 16:08:15,362 - INFO - Reading dataset: image of size: 120
# 2025-08-22 16:08:28,072 - INFO - Iteration: 99/120,  Estimated time left: 0.04 mins
# 2025-08-22 16:08:30,378 - INFO - Saving data to: /mnt/abka03/concept_extraction_result/rsml/gemma3n/MCoX/SNMF/mscoco/train/features/save_hidden_states_sentence_qwen2_patched_image_baseball_bat_token_of_interest_concept_generation_split_train.pth
# [5/10] Processing: baseball_glove (Token: glove, Concept: "baseball glove")
# [nltk_data] Downloading package words to /home/abka03/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# 2025-08-22 16:08:35,080 - INFO - Loading model: Qwen/Qwen2.5-VL-7B-Instruct
# 2025-08-22 16:08:35,080 - INFO - Arguments:
# 2025-08-22 16:08:35,080 - INFO - seed: 0
# 2025-08-22 16:08:35,080 - INFO - model_name_or_path: Qwen/Qwen2.5-VL-7B-Instruct
# 2025-08-22 16:08:35,080 - INFO - processor_name: None
# 2025-08-22 16:08:35,080 - INFO - local_files_only: False
# 2025-08-22 16:08:35,080 - INFO - cache_dir: None
# 2025-08-22 16:08:35,080 - INFO - prompt_template: cgdl
# 2025-08-22 16:08:35,080 - INFO - prompt: Describe the image in detail.
# 2025-08-22 16:08:35,080 - INFO - data_dir: /mnt/abka03/xlvlm_data/coco_cc0_plus_cropped/train/baseball_glove/
# 2025-08-22 16:08:35,080 - INFO - annotation_file: annotations.json
# 2025-08-22 16:08:35,080 - INFO - questions_file: annotations.json
# 2025-08-22 16:08:35,080 - INFO - answer_type_to_answer: None
# 2025-08-22 16:08:35,080 - INFO - split: train
# 2025-08-22 16:08:35,080 - INFO - dataset_size: 120
# 2025-08-22 16:08:35,080 - INFO - dataset_name: image
# 2025-08-22 16:08:35,080 - INFO - batch_size: 1
# 2025-08-22 16:08:35,080 - INFO - hook_names: ['save_hidden_states_sentence']
# 2025-08-22 16:08:35,080 - INFO - modules_to_hook: [['model.language_model.norm']]
# 2025-08-22 16:08:35,081 - INFO - exact_match_modules_to_hook: True
# 2025-08-22 16:08:35,081 - INFO - hook_postprocessing_name: save_hidden_states
# 2025-08-22 16:08:35,081 - INFO - token_idx: None
# 2025-08-22 16:08:35,081 - INFO - token_start_end_idx: None
# 2025-08-22 16:08:35,081 - INFO - save_dir: /mnt/abka03/concept_extraction_result/rsml/gemma3n/MCoX/SNMF/mscoco/train
# 2025-08-22 16:08:35,081 - INFO - save_filename: qwen2_patched_image_baseball_glove_token_of_interest_concept_generation_split_train
# 2025-08-22 16:08:35,081 - INFO - save_analysis: True
# 2025-08-22 16:08:35,081 - INFO - features_path: None
# 2025-08-22 16:08:35,081 - INFO - analysis_saving_path: results/analysis.pth
# 2025-08-22 16:08:35,081 - INFO - analysis_name: decompose_activations
# 2025-08-22 16:08:35,081 - INFO - feature_key: hidden_states
# 2025-08-22 16:08:35,081 - INFO - module_to_decompose: None
# 2025-08-22 16:08:35,081 - INFO - decomposition_extract_pos: None
# 2025-08-22 16:08:35,081 - INFO - decomposition_method: None
# 2025-08-22 16:08:35,081 - INFO - num_concepts: None
# 2025-08-22 16:08:35,081 - INFO - dl_max_iter: 12000
# 2025-08-22 16:08:35,081 - INFO - num_grounded_text_tokens: 5
# 2025-08-22 16:08:35,081 - INFO - pre_num_top_tokens: 20
# 2025-08-22 16:08:35,081 - INFO - num_most_activating_samples: 3
# 2025-08-22 16:08:35,081 - INFO - generation_mode: True
# 2025-08-22 16:08:35,081 - INFO - max_new_tokens: 50
# 2025-08-22 16:08:35,081 - INFO - token_of_interest_num_samples: -1
# 2025-08-22 16:08:35,081 - INFO - select_token_of_interest_samples: False
# 2025-08-22 16:08:35,081 - INFO - allow_different_variations_of_token_of_interest: False
# 2025-08-22 16:08:35,081 - INFO - token_of_interest: None
# 2025-08-22 16:08:35,081 - INFO - tokens_of_interest: None
# 2025-08-22 16:08:35,081 - INFO - token_of_interest_key: response
# 2025-08-22 16:08:35,081 - INFO - token_of_interest_class: None
# 2025-08-22 16:08:35,081 - INFO - token_of_interest_idx: None
# 2025-08-22 16:08:35,081 - INFO - token_of_interest_start_token: 0
# 2025-08-22 16:08:35,081 - INFO - end_special_tokens:
# 2025-08-22 16:08:35,081 - INFO - save_only_generated_tokens: True
# 2025-08-22 16:08:35,081 - INFO - load_matched_features: False
# 2025-08-22 16:08:35,081 - INFO - steering_method: shift_of_means
# 2025-08-22 16:08:35,081 - INFO - steering_alpha: 1
# 2025-08-22 16:08:35,081 - INFO - category_of_interest:
# 2025-08-22 16:08:35,081 - INFO - base_features_key: hidden_states
# 2025-08-22 16:08:35,081 - INFO - shift_vector_path:
# 2025-08-22 16:08:35,081 - INFO - shift_vector_key: steering_vector
# 2025-08-22 16:08:35,081 - INFO - start_prompt_token_idx_steering: 0
# 2025-08-22 16:08:35,081 - INFO - use_random_grounding_words: False
# 2025-08-22 16:08:35,081 - INFO - captioning_metrics: ['CIDEr']
# 2025-08-22 16:08:35,081 - INFO - predictions_token_of_interest: None
# 2025-08-22 16:08:35,081 - INFO - targets_token_of_interest: None
# 2025-08-22 16:08:35,081 - INFO - save_predictions: False
# 2025-08-22 16:08:35,081 - INFO - predictions_path: None
# 2025-08-22 16:08:35,081 - INFO - origin_model_analysis_path: None
# 2025-08-22 16:08:35,082 - INFO - origin_model_feature_path: None
# 2025-08-22 16:08:35,082 - INFO - dest_model_analysis_path: None
# 2025-08-22 16:08:35,082 - INFO - dest_model_feature_path: None
# 2025-08-22 16:08:35,082 - INFO - visualize_concepts: False
# 2025-08-22 16:08:35,082 - INFO - compute_recovery_metrics: False
# 2025-08-22 16:08:35,082 - INFO - compute_stat_shift_vectors: False
# 2025-08-22 16:08:35,082 - INFO - select_samples_from_ids: False
# 2025-08-22 16:08:35,082 - INFO - path_to_samples_ids: None
# 2025-08-22 16:08:35,082 - INFO - slice_prediction: True
# 2025-08-22 16:08:35,082 - INFO - post_process_hidden: False
# 2025-08-22 16:08:35,082 - INFO - concept: baseball glove
# /mnt/abka03/.conda/envs/rsml3/lib/python3.9/site-packages/transformers/models/auto/modeling_auto.py:2199: FutureWarning: The class `AutoModelForVision2Seq` is deprecated and will be removed in v5.0. Please use `AutoModelForImageTextToText` instead.
#   warnings.warn(
# Loading checkpoint shards: 100%|██████████| 5/5 [00:02<00:00,  1.83it/s]
# The image processor of type `Qwen2VLImageProcessor` is now loaded as a fast processor by default, even if the model checkpoint was saved with a slow processor. This is a breaking change and may produce slightly different outputs. To continue using the slow processor, instantiate this class with `use_fast=False`. Note that this behavior will be extended to all models in a future release.
# You have video processor config saved in `preprocessor.json` file which is deprecated. Video processor configs should be saved in their own `video_preprocessor.json` file. You can rename the file or load and save the processor back which renames it automatically. Loading from `preprocessor.json` will be removed in v5.0.
# 2025-08-22 16:08:40,534 - INFO - Successfully loaded Qwen/Qwen2.5-VL-7B-Instruct, device: cuda
# 2025-08-22 16:08:40,535 - INFO - Apply save_hidden_states_sentence to hooked_modules: ['model.language_model.norm']
# 2025-08-22 16:08:40,536 - INFO - Successfully loaded image
# 2025-08-22 16:08:40,536 - INFO - Reading dataset: image of size: 120
# 2025-08-22 16:08:53,067 - INFO - Iteration: 99/120,  Estimated time left: 0.04 mins
# 2025-08-22 16:08:55,489 - INFO - Saving data to: /mnt/abka03/concept_extraction_result/rsml/gemma3n/MCoX/SNMF/mscoco/train/features/save_hidden_states_sentence_qwen2_patched_image_baseball_glove_token_of_interest_concept_generation_split_train.pth
# [6/10] Processing: bear (Token: bear, Concept: "bear")
# [nltk_data] Downloading package words to /home/abka03/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# 2025-08-22 16:09:00,231 - INFO - Loading model: Qwen/Qwen2.5-VL-7B-Instruct
# 2025-08-22 16:09:00,231 - INFO - Arguments:
# 2025-08-22 16:09:00,231 - INFO - seed: 0
# 2025-08-22 16:09:00,231 - INFO - model_name_or_path: Qwen/Qwen2.5-VL-7B-Instruct
# 2025-08-22 16:09:00,231 - INFO - processor_name: None
# 2025-08-22 16:09:00,231 - INFO - local_files_only: False
# 2025-08-22 16:09:00,231 - INFO - cache_dir: None
# 2025-08-22 16:09:00,231 - INFO - prompt_template: cgdl
# 2025-08-22 16:09:00,231 - INFO - prompt: Describe the image in detail.
# 2025-08-22 16:09:00,231 - INFO - data_dir: /mnt/abka03/xlvlm_data/coco_cc0_plus_cropped/train/bear/
# 2025-08-22 16:09:00,231 - INFO - annotation_file: annotations.json
# 2025-08-22 16:09:00,231 - INFO - questions_file: annotations.json
# 2025-08-22 16:09:00,231 - INFO - answer_type_to_answer: None
# 2025-08-22 16:09:00,231 - INFO - split: train
# 2025-08-22 16:09:00,231 - INFO - dataset_size: 120
# 2025-08-22 16:09:00,231 - INFO - dataset_name: image
# 2025-08-22 16:09:00,231 - INFO - batch_size: 1
# 2025-08-22 16:09:00,232 - INFO - hook_names: ['save_hidden_states_sentence']
# 2025-08-22 16:09:00,232 - INFO - modules_to_hook: [['model.language_model.norm']]
# 2025-08-22 16:09:00,232 - INFO - exact_match_modules_to_hook: True
# 2025-08-22 16:09:00,232 - INFO - hook_postprocessing_name: save_hidden_states
# 2025-08-22 16:09:00,232 - INFO - token_idx: None
# 2025-08-22 16:09:00,232 - INFO - token_start_end_idx: None
# 2025-08-22 16:09:00,232 - INFO - save_dir: /mnt/abka03/concept_extraction_result/rsml/gemma3n/MCoX/SNMF/mscoco/train
# 2025-08-22 16:09:00,232 - INFO - save_filename: qwen2_patched_image_bear_token_of_interest_concept_generation_split_train
# 2025-08-22 16:09:00,232 - INFO - save_analysis: True
# 2025-08-22 16:09:00,232 - INFO - features_path: None
# 2025-08-22 16:09:00,232 - INFO - analysis_saving_path: results/analysis.pth
# 2025-08-22 16:09:00,232 - INFO - analysis_name: decompose_activations
# 2025-08-22 16:09:00,232 - INFO - feature_key: hidden_states
# 2025-08-22 16:09:00,232 - INFO - module_to_decompose: None
# 2025-08-22 16:09:00,232 - INFO - decomposition_extract_pos: None
# 2025-08-22 16:09:00,232 - INFO - decomposition_method: None
# 2025-08-22 16:09:00,232 - INFO - num_concepts: None
# 2025-08-22 16:09:00,232 - INFO - dl_max_iter: 12000
# 2025-08-22 16:09:00,232 - INFO - num_grounded_text_tokens: 5
# 2025-08-22 16:09:00,232 - INFO - pre_num_top_tokens: 20
# 2025-08-22 16:09:00,232 - INFO - num_most_activating_samples: 3
# 2025-08-22 16:09:00,232 - INFO - generation_mode: True
# 2025-08-22 16:09:00,232 - INFO - max_new_tokens: 50
# 2025-08-22 16:09:00,232 - INFO - token_of_interest_num_samples: -1
# 2025-08-22 16:09:00,232 - INFO - select_token_of_interest_samples: False
# 2025-08-22 16:09:00,232 - INFO - allow_different_variations_of_token_of_interest: False
# 2025-08-22 16:09:00,232 - INFO - token_of_interest: None
# 2025-08-22 16:09:00,232 - INFO - tokens_of_interest: None
# 2025-08-22 16:09:00,232 - INFO - token_of_interest_key: response
# 2025-08-22 16:09:00,232 - INFO - token_of_interest_class: None
# 2025-08-22 16:09:00,232 - INFO - token_of_interest_idx: None
# 2025-08-22 16:09:00,232 - INFO - token_of_interest_start_token: 0
# 2025-08-22 16:09:00,232 - INFO - end_special_tokens:
# 2025-08-22 16:09:00,232 - INFO - save_only_generated_tokens: True
# 2025-08-22 16:09:00,232 - INFO - load_matched_features: False
# 2025-08-22 16:09:00,232 - INFO - steering_method: shift_of_means
# 2025-08-22 16:09:00,232 - INFO - steering_alpha: 1
# 2025-08-22 16:09:00,232 - INFO - category_of_interest:
# 2025-08-22 16:09:00,232 - INFO - base_features_key: hidden_states
# 2025-08-22 16:09:00,232 - INFO - shift_vector_path:
# 2025-08-22 16:09:00,232 - INFO - shift_vector_key: steering_vector
# 2025-08-22 16:09:00,232 - INFO - start_prompt_token_idx_steering: 0
# 2025-08-22 16:09:00,232 - INFO - use_random_grounding_words: False
# 2025-08-22 16:09:00,232 - INFO - captioning_metrics: ['CIDEr']
# 2025-08-22 16:09:00,232 - INFO - predictions_token_of_interest: None
# 2025-08-22 16:09:00,232 - INFO - targets_token_of_interest: None
# 2025-08-22 16:09:00,232 - INFO - save_predictions: False
# 2025-08-22 16:09:00,232 - INFO - predictions_path: None
# 2025-08-22 16:09:00,232 - INFO - origin_model_analysis_path: None
# 2025-08-22 16:09:00,232 - INFO - origin_model_feature_path: None
# 2025-08-22 16:09:00,232 - INFO - dest_model_analysis_path: None
# 2025-08-22 16:09:00,232 - INFO - dest_model_feature_path: None
# 2025-08-22 16:09:00,233 - INFO - visualize_concepts: False
# 2025-08-22 16:09:00,233 - INFO - compute_recovery_metrics: False
# 2025-08-22 16:09:00,233 - INFO - compute_stat_shift_vectors: False
# 2025-08-22 16:09:00,233 - INFO - select_samples_from_ids: False
# 2025-08-22 16:09:00,233 - INFO - path_to_samples_ids: None
# 2025-08-22 16:09:00,233 - INFO - slice_prediction: True
# 2025-08-22 16:09:00,233 - INFO - post_process_hidden: False
# 2025-08-22 16:09:00,233 - INFO - concept: bear
# /mnt/abka03/.conda/envs/rsml3/lib/python3.9/site-packages/transformers/models/auto/modeling_auto.py:2199: FutureWarning: The class `AutoModelForVision2Seq` is deprecated and will be removed in v5.0. Please use `AutoModelForImageTextToText` instead.
#   warnings.warn(
# Loading checkpoint shards: 100%|██████████| 5/5 [00:02<00:00,  1.82it/s]
# The image processor of type `Qwen2VLImageProcessor` is now loaded as a fast processor by default, even if the model checkpoint was saved with a slow processor. This is a breaking change and may produce slightly different outputs. To continue using the slow processor, instantiate this class with `use_fast=False`. Note that this behavior will be extended to all models in a future release.
# You have video processor config saved in `preprocessor.json` file which is deprecated. Video processor configs should be saved in their own `video_preprocessor.json` file. You can rename the file or load and save the processor back which renames it automatically. Loading from `preprocessor.json` will be removed in v5.0.
# 2025-08-22 16:09:05,770 - INFO - Successfully loaded Qwen/Qwen2.5-VL-7B-Instruct, device: cuda
# 2025-08-22 16:09:05,770 - INFO - Apply save_hidden_states_sentence to hooked_modules: ['model.language_model.norm']
# 2025-08-22 16:09:05,771 - INFO - Successfully loaded image
# 2025-08-22 16:09:05,771 - INFO - Reading dataset: image of size: 120
# 2025-08-22 16:09:15,952 - INFO - Iteration: 99/120,  Estimated time left: 0.04 mins
# 2025-08-22 16:09:17,853 - INFO - Saving data to: /mnt/abka03/concept_extraction_result/rsml/gemma3n/MCoX/SNMF/mscoco/train/features/save_hidden_states_sentence_qwen2_patched_image_bear_token_of_interest_concept_generation_split_train.pth
# [7/10] Processing: bed (Token: bed, Concept: "bed")
# [nltk_data] Downloading package words to /home/abka03/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# 2025-08-22 16:09:22,602 - INFO - Loading model: Qwen/Qwen2.5-VL-7B-Instruct
# 2025-08-22 16:09:22,603 - INFO - Arguments:
# 2025-08-22 16:09:22,603 - INFO - seed: 0
# 2025-08-22 16:09:22,603 - INFO - model_name_or_path: Qwen/Qwen2.5-VL-7B-Instruct
# 2025-08-22 16:09:22,603 - INFO - processor_name: None
# ...
# 2025-08-22 16:09:22,604 - INFO - compute_stat_shift_vectors: False
# 2025-08-22 16:09:22,604 - INFO - select_samples_from_ids: False
# 2025-08-22 16:09:22,604 - INFO - path_to_samples_ids: None
# 2025-08-22 16:09:22,604 - INFO - slice_prediction: True
# 2025-08-22 16:09:22,604 - INFO - post_process_hidden: False
# 2025-08-22 16:09:22,604 - INFO - concept: bed
# /mnt/abka03/.conda/envs/rsml3/lib/python3.9/site-packages/transformers/models/auto/modeling_auto.py:2199: FutureWarning: The class `AutoModelForVision2Seq` is deprecated and will be removed in v5.0. Please use `AutoModelForImageTextToText` instead.
#   warnings.warn(
# Loading checkpoint shards: 100%|██████████| 5/5 [00:02<00:00,  1.80it/s]
# The image processor of type `Qwen2VLImageProcessor` is now loaded as a fast processor by default, even if the model checkpoint was saved with a slow processor. This is a breaking change and may produce slightly different outputs. To continue using the slow processor, instantiate this class with `use_fast=False`. Note that this behavior will be extended to all models in a future release.
# You have video processor config saved in `preprocessor.json` file which is deprecated. Video processor configs should be saved in their own `video_preprocessor.json` file. You can rename the file or load and save the processor back which renames it automatically. Loading from `preprocessor.json` will be removed in v5.0.
# 2025-08-22 16:09:28,047 - INFO - Successfully loaded Qwen/Qwen2.5-VL-7B-Instruct, device: cuda
# 2025-08-22 16:09:28,048 - INFO - Apply save_hidden_states_sentence to hooked_modules: ['model.language_model.norm']
# 2025-08-22 16:09:28,048 - INFO - Successfully loaded image
# 2025-08-22 16:09:28,049 - INFO - Reading dataset: image of size: 120
# 2025-08-22 16:09:38,544 - INFO - Iteration: 99/120,  Estimated time left: 0.04 mins
# 2025-08-22 16:09:40,569 - INFO - Saving data to: /mnt/abka03/concept_extraction_result/rsml/gemma3n/MCoX/SNMF/mscoco/train/features/save_hidden_states_sentence_qwen2_patched_image_bed_token_of_interest_concept_generation_split_train.pth
# [8/10] Processing: bench (Token: bench, Concept: "bench")
# [nltk_data] Downloading package words to /home/abka03/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# 2025-08-22 16:09:45,265 - INFO - Loading model: Qwen/Qwen2.5-VL-7B-Instruct
# 2025-08-22 16:09:45,265 - INFO - Arguments:
# 2025-08-22 16:09:45,265 - INFO - seed: 0
# 2025-08-22 16:09:45,265 - INFO - model_name_or_path: Qwen/Qwen2.5-VL-7B-Instruct
# 2025-08-22 16:09:45,265 - INFO - processor_name: None
# 2025-08-22 16:09:45,265 - INFO - local_files_only: False
# 2025-08-22 16:09:45,265 - INFO - cache_dir: None
# 2025-08-22 16:09:45,265 - INFO - prompt_template: cgdl
# 2025-08-22 16:09:45,265 - INFO - prompt: Describe the image in detail.
# 2025-08-22 16:09:45,265 - INFO - data_dir: /mnt/abka03/xlvlm_data/coco_cc0_plus_cropped/train/bench/
# 2025-08-22 16:09:45,265 - INFO - annotation_file: annotations.json
# 2025-08-22 16:09:45,265 - INFO - questions_file: annotations.json
# 2025-08-22 16:09:45,265 - INFO - answer_type_to_answer: None
# 2025-08-22 16:09:45,265 - INFO - split: train
# 2025-08-22 16:09:45,265 - INFO - dataset_size: 120
# 2025-08-22 16:09:45,265 - INFO - dataset_name: image
# 2025-08-22 16:09:45,265 - INFO - batch_size: 1
# 2025-08-22 16:09:45,265 - INFO - hook_names: ['save_hidden_states_sentence']
# 2025-08-22 16:09:45,265 - INFO - modules_to_hook: [['model.language_model.norm']]
# 2025-08-22 16:09:45,265 - INFO - exact_match_modules_to_hook: True
# 2025-08-22 16:09:45,265 - INFO - hook_postprocessing_name: save_hidden_states
# 2025-08-22 16:09:45,265 - INFO - token_idx: None
# 2025-08-22 16:09:45,265 - INFO - token_start_end_idx: None
# 2025-08-22 16:09:45,265 - INFO - save_dir: /mnt/abka03/concept_extraction_result/rsml/gemma3n/MCoX/SNMF/mscoco/train
# 2025-08-22 16:09:45,265 - INFO - save_filename: qwen2_patched_image_bench_token_of_interest_concept_generation_split_train
# 2025-08-22 16:09:45,266 - INFO - save_analysis: True
# 2025-08-22 16:09:45,266 - INFO - features_path: None
# 2025-08-22 16:09:45,266 - INFO - analysis_saving_path: results/analysis.pth
# 2025-08-22 16:09:45,266 - INFO - analysis_name: decompose_activations
# 2025-08-22 16:09:45,266 - INFO - feature_key: hidden_states
# 2025-08-22 16:09:45,266 - INFO - module_to_decompose: None
# 2025-08-22 16:09:45,266 - INFO - decomposition_extract_pos: None
# 2025-08-22 16:09:45,266 - INFO - decomposition_method: None
# 2025-08-22 16:09:45,266 - INFO - num_concepts: None
# 2025-08-22 16:09:45,266 - INFO - dl_max_iter: 12000
# 2025-08-22 16:09:45,266 - INFO - num_grounded_text_tokens: 5
# 2025-08-22 16:09:45,266 - INFO - pre_num_top_tokens: 20
# 2025-08-22 16:09:45,266 - INFO - num_most_activating_samples: 3
# 2025-08-22 16:09:45,266 - INFO - generation_mode: True
# 2025-08-22 16:09:45,266 - INFO - max_new_tokens: 50
# 2025-08-22 16:09:45,266 - INFO - token_of_interest_num_samples: -1
# 2025-08-22 16:09:45,266 - INFO - select_token_of_interest_samples: False
# 2025-08-22 16:09:45,266 - INFO - allow_different_variations_of_token_of_interest: False
# 2025-08-22 16:09:45,266 - INFO - token_of_interest: None
# 2025-08-22 16:09:45,266 - INFO - tokens_of_interest: None
# 2025-08-22 16:09:45,266 - INFO - token_of_interest_key: response
# 2025-08-22 16:09:45,266 - INFO - token_of_interest_class: None
# 2025-08-22 16:09:45,266 - INFO - token_of_interest_idx: None
# 2025-08-22 16:09:45,266 - INFO - token_of_interest_start_token: 0
# 2025-08-22 16:09:45,266 - INFO - end_special_tokens:
# 2025-08-22 16:09:45,266 - INFO - save_only_generated_tokens: True
# 2025-08-22 16:09:45,266 - INFO - load_matched_features: False
# 2025-08-22 16:09:45,266 - INFO - steering_method: shift_of_means
# 2025-08-22 16:09:45,266 - INFO - steering_alpha: 1
# 2025-08-22 16:09:45,266 - INFO - category_of_interest:
# 2025-08-22 16:09:45,266 - INFO - base_features_key: hidden_states
# 2025-08-22 16:09:45,266 - INFO - shift_vector_path:
# 2025-08-22 16:09:45,266 - INFO - shift_vector_key: steering_vector
# 2025-08-22 16:09:45,266 - INFO - start_prompt_token_idx_steering: 0
# 2025-08-22 16:09:45,266 - INFO - use_random_grounding_words: False
# 2025-08-22 16:09:45,266 - INFO - captioning_metrics: ['CIDEr']
# 2025-08-22 16:09:45,266 - INFO - predictions_token_of_interest: None
# 2025-08-22 16:09:45,266 - INFO - targets_token_of_interest: None
# 2025-08-22 16:09:45,266 - INFO - save_predictions: False
# 2025-08-22 16:09:45,266 - INFO - predictions_path: None
# 2025-08-22 16:09:45,266 - INFO - origin_model_analysis_path: None
# 2025-08-22 16:09:45,266 - INFO - origin_model_feature_path: None
# 2025-08-22 16:09:45,266 - INFO - dest_model_analysis_path: None
# 2025-08-22 16:09:45,266 - INFO - dest_model_feature_path: None
# 2025-08-22 16:09:45,266 - INFO - visualize_concepts: False
# 2025-08-22 16:09:45,266 - INFO - compute_recovery_metrics: False
# 2025-08-22 16:09:45,266 - INFO - compute_stat_shift_vectors: False
# 2025-08-22 16:09:45,266 - INFO - select_samples_from_ids: False
# 2025-08-22 16:09:45,266 - INFO - path_to_samples_ids: None
# 2025-08-22 16:09:45,267 - INFO - slice_prediction: True
# 2025-08-22 16:09:45,267 - INFO - post_process_hidden: False
# 2025-08-22 16:09:45,267 - INFO - concept: bench
# /mnt/abka03/.conda/envs/rsml3/lib/python3.9/site-packages/transformers/models/auto/modeling_auto.py:2199: FutureWarning: The class `AutoModelForVision2Seq` is deprecated and will be removed in v5.0. Please use `AutoModelForImageTextToText` instead.
#   warnings.warn(
# Loading checkpoint shards: 100%|██████████| 5/5 [00:02<00:00,  1.80it/s]
# The image processor of type `Qwen2VLImageProcessor` is now loaded as a fast processor by default, even if the model checkpoint was saved with a slow processor. This is a breaking change and may produce slightly different outputs. To continue using the slow processor, instantiate this class with `use_fast=False`. Note that this behavior will be extended to all models in a future release.
# You have video processor config saved in `preprocessor.json` file which is deprecated. Video processor configs should be saved in their own `video_preprocessor.json` file. You can rename the file or load and save the processor back which renames it automatically. Loading from `preprocessor.json` will be removed in v5.0.
# 2025-08-22 16:09:50,690 - INFO - Successfully loaded Qwen/Qwen2.5-VL-7B-Instruct, device: cuda
# 2025-08-22 16:09:50,690 - INFO - Apply save_hidden_states_sentence to hooked_modules: ['model.language_model.norm']
# 2025-08-22 16:09:50,691 - INFO - Successfully loaded image
# 2025-08-22 16:09:50,691 - INFO - Reading dataset: image of size: 120
# 2025-08-22 16:10:01,092 - INFO - Iteration: 99/120,  Estimated time left: 0.04 mins
# 2025-08-22 16:10:03,037 - INFO - Saving data to: /mnt/abka03/concept_extraction_result/rsml/gemma3n/MCoX/SNMF/mscoco/train/features/save_hidden_states_sentence_qwen2_patched_image_bench_token_of_interest_concept_generation_split_train.pth
# [9/10] Processing: bicycle (Token: bicycle, Concept: "bicycle")
# [nltk_data] Downloading package words to /home/abka03/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# 2025-08-22 16:10:07,833 - INFO - Loading model: Qwen/Qwen2.5-VL-7B-Instruct
# 2025-08-22 16:10:07,834 - INFO - Arguments:
# 2025-08-22 16:10:07,834 - INFO - seed: 0
# 2025-08-22 16:10:07,834 - INFO - model_name_or_path: Qwen/Qwen2.5-VL-7B-Instruct
# 2025-08-22 16:10:07,834 - INFO - processor_name: None
# 2025-08-22 16:10:07,834 - INFO - local_files_only: False
# 2025-08-22 16:10:07,834 - INFO - cache_dir: None
# 2025-08-22 16:10:07,834 - INFO - prompt_template: cgdl
# 2025-08-22 16:10:07,834 - INFO - prompt: Describe the image in detail.
# 2025-08-22 16:10:07,834 - INFO - data_dir: /mnt/abka03/xlvlm_data/coco_cc0_plus_cropped/train/bicycle/
# 2025-08-22 16:10:07,834 - INFO - annotation_file: annotations.json
# 2025-08-22 16:10:07,834 - INFO - questions_file: annotations.json
# 2025-08-22 16:10:07,834 - INFO - answer_type_to_answer: None
# 2025-08-22 16:10:07,834 - INFO - split: train
# 2025-08-22 16:10:07,834 - INFO - dataset_size: 120
# 2025-08-22 16:10:07,834 - INFO - dataset_name: image
# 2025-08-22 16:10:07,834 - INFO - batch_size: 1
# 2025-08-22 16:10:07,834 - INFO - hook_names: ['save_hidden_states_sentence']
# 2025-08-22 16:10:07,834 - INFO - modules_to_hook: [['model.language_model.norm']]
# 2025-08-22 16:10:07,834 - INFO - exact_match_modules_to_hook: True
# 2025-08-22 16:10:07,834 - INFO - hook_postprocessing_name: save_hidden_states
# 2025-08-22 16:10:07,834 - INFO - token_idx: None
# 2025-08-22 16:10:07,834 - INFO - token_start_end_idx: None
# 2025-08-22 16:10:07,834 - INFO - save_dir: /mnt/abka03/concept_extraction_result/rsml/gemma3n/MCoX/SNMF/mscoco/train
# 2025-08-22 16:10:07,834 - INFO - save_filename: qwen2_patched_image_bicycle_token_of_interest_concept_generation_split_train
# 2025-08-22 16:10:07,834 - INFO - save_analysis: True
# 2025-08-22 16:10:07,834 - INFO - features_path: None
# 2025-08-22 16:10:07,834 - INFO - analysis_saving_path: results/analysis.pth
# 2025-08-22 16:10:07,834 - INFO - analysis_name: decompose_activations
# 2025-08-22 16:10:07,834 - INFO - feature_key: hidden_states
# 2025-08-22 16:10:07,834 - INFO - module_to_decompose: None
# 2025-08-22 16:10:07,834 - INFO - decomposition_extract_pos: None
# 2025-08-22 16:10:07,834 - INFO - decomposition_method: None
# 2025-08-22 16:10:07,834 - INFO - num_concepts: None
# 2025-08-22 16:10:07,834 - INFO - dl_max_iter: 12000
# 2025-08-22 16:10:07,834 - INFO - num_grounded_text_tokens: 5
# 2025-08-22 16:10:07,834 - INFO - pre_num_top_tokens: 20
# 2025-08-22 16:10:07,834 - INFO - num_most_activating_samples: 3
# 2025-08-22 16:10:07,834 - INFO - generation_mode: True
# 2025-08-22 16:10:07,834 - INFO - max_new_tokens: 50
# 2025-08-22 16:10:07,834 - INFO - token_of_interest_num_samples: -1
# 2025-08-22 16:10:07,834 - INFO - select_token_of_interest_samples: False
# 2025-08-22 16:10:07,834 - INFO - allow_different_variations_of_token_of_interest: False
# 2025-08-22 16:10:07,834 - INFO - token_of_interest: None
# 2025-08-22 16:10:07,834 - INFO - tokens_of_interest: None
# 2025-08-22 16:10:07,834 - INFO - token_of_interest_key: response
# 2025-08-22 16:10:07,834 - INFO - token_of_interest_class: None
# 2025-08-22 16:10:07,835 - INFO - token_of_interest_idx: None
# 2025-08-22 16:10:07,835 - INFO - token_of_interest_start_token: 0
# 2025-08-22 16:10:07,835 - INFO - end_special_tokens:
# 2025-08-22 16:10:07,835 - INFO - save_only_generated_tokens: True
# 2025-08-22 16:10:07,835 - INFO - load_matched_features: False
# 2025-08-22 16:10:07,835 - INFO - steering_method: shift_of_means
# 2025-08-22 16:10:07,835 - INFO - steering_alpha: 1
# 2025-08-22 16:10:07,835 - INFO - category_of_interest:
# 2025-08-22 16:10:07,835 - INFO - base_features_key: hidden_states
# 2025-08-22 16:10:07,835 - INFO - shift_vector_path:
# 2025-08-22 16:10:07,835 - INFO - shift_vector_key: steering_vector
# 2025-08-22 16:10:07,835 - INFO - start_prompt_token_idx_steering: 0
# 2025-08-22 16:10:07,835 - INFO - use_random_grounding_words: False
# 2025-08-22 16:10:07,835 - INFO - captioning_metrics: ['CIDEr']
# 2025-08-22 16:10:07,835 - INFO - predictions_token_of_interest: None
# 2025-08-22 16:10:07,835 - INFO - targets_token_of_interest: None
# 2025-08-22 16:10:07,835 - INFO - save_predictions: False
# 2025-08-22 16:10:07,835 - INFO - predictions_path: None
# 2025-08-22 16:10:07,835 - INFO - origin_model_analysis_path: None
# 2025-08-22 16:10:07,835 - INFO - origin_model_feature_path: None
# 2025-08-22 16:10:07,835 - INFO - dest_model_analysis_path: None
# 2025-08-22 16:10:07,835 - INFO - dest_model_feature_path: None
# 2025-08-22 16:10:07,835 - INFO - visualize_concepts: False
# 2025-08-22 16:10:07,835 - INFO - compute_recovery_metrics: False
# 2025-08-22 16:10:07,835 - INFO - compute_stat_shift_vectors: False
# 2025-08-22 16:10:07,835 - INFO - select_samples_from_ids: False
# 2025-08-22 16:10:07,835 - INFO - path_to_samples_ids: None
# 2025-08-22 16:10:07,835 - INFO - slice_prediction: True
# 2025-08-22 16:10:07,835 - INFO - post_process_hidden: False
# 2025-08-22 16:10:07,835 - INFO - concept: bicycle
# /mnt/abka03/.conda/envs/rsml3/lib/python3.9/site-packages/transformers/models/auto/modeling_auto.py:2199: FutureWarning: The class `AutoModelForVision2Seq` is deprecated and will be removed in v5.0. Please use `AutoModelForImageTextToText` instead.
#   warnings.warn(
# Loading checkpoint shards: 100%|██████████| 5/5 [00:02<00:00,  1.83it/s]
# The image processor of type `Qwen2VLImageProcessor` is now loaded as a fast processor by default, even if the model checkpoint was saved with a slow processor. This is a breaking change and may produce slightly different outputs. To continue using the slow processor, instantiate this class with `use_fast=False`. Note that this behavior will be extended to all models in a future release.
# You have video processor config saved in `preprocessor.json` file which is deprecated. Video processor configs should be saved in their own `video_preprocessor.json` file. You can rename the file or load and save the processor back which renames it automatically. Loading from `preprocessor.json` will be removed in v5.0.
# 2025-08-22 16:10:13,554 - INFO - Successfully loaded Qwen/Qwen2.5-VL-7B-Instruct, device: cuda
# 2025-08-22 16:10:13,555 - INFO - Apply save_hidden_states_sentence to hooked_modules: ['model.language_model.norm']
# 2025-08-22 16:10:13,556 - INFO - Successfully loaded image
# 2025-08-22 16:10:13,556 - INFO - Reading dataset: image of size: 120
# 2025-08-22 16:10:25,357 - INFO - Iteration: 99/120,  Estimated time left: 0.04 mins
# 2025-08-22 16:10:27,576 - INFO - Saving data to: /mnt/abka03/concept_extraction_result/rsml/gemma3n/MCoX/SNMF/mscoco/train/features/save_hidden_states_sentence_qwen2_patched_image_bicycle_token_of_interest_concept_generation_split_train.pth
# Reached maximum number of iterations (10), stopping.
#
# ✅ Script completed in 236s (~3 minutes)
# CompletedProcess(args=['scripts/run_feature_gen_cgdl.sh', 'Qwen/Qwen2.5-VL-7B-Instruct', '/mnt/abka03/xlvlm_data/coco_cc0_plus_cropped/train', '/mnt/abka03/concept_extraction_result/rsml/gemma3n/MCoX/SNMF/mscoco/train', '/mnt/abka03/huggingface/hub/hub'], returncode=0)

# %%
# Run the script with the concept as argument
subprocess.run(
    ["scripts/run_feature_decompose_cgdl.sh", hugging_face_path, model_card, train_output_dir],
    cwd='/mnt/abka03/Projects/xl-vlms', 
    check=True
)
# Out:
# === Running decomposition: snmf ===
# Processing file: save_hidden_states_sentence_qwen2_patched_image_airplane_token_of_interest_concept_generation_split_train.pth
#   - Interpreted concept: save hidden states sentence qwen2 patched image airplane token of interest concept generation split train
#   - Analyzing features...
# [nltk_data] Downloading package words to /home/abka03/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# 2025-08-22 16:10:31,669 - INFO - Arguments:
# 2025-08-22 16:10:31,669 - INFO - seed: 0
# 2025-08-22 16:10:31,669 - INFO - model_name_or_path: Qwen/Qwen2.5-VL-7B-Instruct
# 2025-08-22 16:10:31,669 - INFO - processor_name: None
# 2025-08-22 16:10:31,669 - INFO - local_files_only: False
# 2025-08-22 16:10:31,669 - INFO - cache_dir: None
# 2025-08-22 16:10:31,669 - INFO - prompt_template: llava
# 2025-08-22 16:10:31,669 - INFO - prompt: Describe the image in detail.
# 2025-08-22 16:10:31,669 - INFO - data_dir: data/
# 2025-08-22 16:10:31,669 - INFO - annotation_file: annotations.json
# 2025-08-22 16:10:31,669 - INFO - questions_file: annotations.json
# 2025-08-22 16:10:31,669 - INFO - answer_type_to_answer: None
# 2025-08-22 16:10:31,669 - INFO - split: train
# 2025-08-22 16:10:31,669 - INFO - dataset_size: -1
# 2025-08-22 16:10:31,669 - INFO - dataset_name: coco
# 2025-08-22 16:10:31,669 - INFO - batch_size: 1
# 2025-08-22 16:10:31,669 - INFO - hook_names: None
# 2025-08-22 16:10:31,669 - INFO - modules_to_hook: None
# 2025-08-22 16:10:31,669 - INFO - exact_match_modules_to_hook: False
# 2025-08-22 16:10:31,669 - INFO - hook_postprocessing_name: save_hidden_states
# 2025-08-22 16:10:31,669 - INFO - token_idx: None
# 2025-08-22 16:10:31,669 - INFO - token_start_end_idx: None
# 2025-08-22 16:10:31,669 - INFO - save_dir: /mnt/abka03/concept_extraction_result/rsml/gemma3n/MCoX/SNMF/mscoco/train/concept/intermediate_snmf
# 2025-08-22 16:10:31,669 - INFO - save_filename: individual_concept_save_hidden_states_sentence_qwen2_patched_image_airplane_token_of_interest_concept_generation_split_train_snmf
# 2025-08-22 16:10:31,669 - INFO - save_analysis: True
# 2025-08-22 16:10:31,669 - INFO - features_path: ['/mnt/abka03/concept_extraction_result/rsml/gemma3n/MCoX/SNMF/mscoco/train/features/save_hidden_states_sentence_qwen2_patched_image_airplane_token_of_interest_concept_generation_split_train.pth']
# 2025-08-22 16:10:31,669 - INFO - analysis_saving_path: results/analysis.pth
# 2025-08-22 16:10:31,669 - INFO - analysis_name: decompose_activations_text_grounding_image_grounding_snmf
# 2025-08-22 16:10:31,669 - INFO - feature_key: hidden_states
# 2025-08-22 16:10:31,669 - INFO - module_to_decompose: model.language_model.norm
# 2025-08-22 16:10:31,669 - INFO - decomposition_extract_pos: None
# 2025-08-22 16:10:31,669 - INFO - decomposition_method: snmf
# 2025-08-22 16:10:31,669 - INFO - num_concepts: [2]
# 2025-08-22 16:10:31,669 - INFO - dl_max_iter: 12000
# 2025-08-22 16:10:31,669 - INFO - num_grounded_text_tokens: 5
# 2025-08-22 16:10:31,669 - INFO - pre_num_top_tokens: 20
# 2025-08-22 16:10:31,670 - INFO - num_most_activating_samples: 3
# 2025-08-22 16:10:31,670 - INFO - generation_mode: False
# 2025-08-22 16:10:31,670 - INFO - max_new_tokens: 50
# 2025-08-22 16:10:31,670 - INFO - token_of_interest_num_samples: -1
# 2025-08-22 16:10:31,670 - INFO - select_token_of_interest_samples: False
# 2025-08-22 16:10:31,670 - INFO - allow_different_variations_of_token_of_interest: False
# 2025-08-22 16:10:31,670 - INFO - token_of_interest: None
# 2025-08-22 16:10:31,670 - INFO - tokens_of_interest: None
# 2025-08-22 16:10:31,670 - INFO - token_of_interest_key: response
# 2025-08-22 16:10:31,670 - INFO - token_of_interest_class: None
# 2025-08-22 16:10:31,670 - INFO - token_of_interest_idx: None
# 2025-08-22 16:10:31,670 - INFO - token_of_interest_start_token: 0
# 2025-08-22 16:10:31,670 - INFO - end_special_tokens:
# 2025-08-22 16:10:31,670 - INFO - save_only_generated_tokens: False
# 2025-08-22 16:10:31,670 - INFO - load_matched_features: False
# 2025-08-22 16:10:31,670 - INFO - steering_method: shift_of_means
# 2025-08-22 16:10:31,670 - INFO - steering_alpha: 1
# 2025-08-22 16:10:31,670 - INFO - category_of_interest:
# 2025-08-22 16:10:31,670 - INFO - base_features_key: hidden_states
# 2025-08-22 16:10:31,670 - INFO - shift_vector_path:
# 2025-08-22 16:10:31,670 - INFO - shift_vector_key: steering_vector
# 2025-08-22 16:10:31,670 - INFO - start_prompt_token_idx_steering: 0
# 2025-08-22 16:10:31,670 - INFO - use_random_grounding_words: False
# 2025-08-22 16:10:31,670 - INFO - captioning_metrics: ['CIDEr']
# 2025-08-22 16:10:31,670 - INFO - predictions_token_of_interest: None
# 2025-08-22 16:10:31,670 - INFO - targets_token_of_interest: None
# 2025-08-22 16:10:31,670 - INFO - save_predictions: False
# 2025-08-22 16:10:31,670 - INFO - predictions_path: None
# 2025-08-22 16:10:31,670 - INFO - origin_model_analysis_path: None
# 2025-08-22 16:10:31,670 - INFO - origin_model_feature_path: None
# 2025-08-22 16:10:31,670 - INFO - dest_model_analysis_path: None
# 2025-08-22 16:10:31,670 - INFO - dest_model_feature_path: None
# 2025-08-22 16:10:31,670 - INFO - visualize_concepts: False
# 2025-08-22 16:10:31,670 - INFO - compute_recovery_metrics: False
# 2025-08-22 16:10:31,670 - INFO - compute_stat_shift_vectors: False
# 2025-08-22 16:10:31,670 - INFO - select_samples_from_ids: False
# 2025-08-22 16:10:31,670 - INFO - path_to_samples_ids: None
# 2025-08-22 16:10:31,670 - INFO - slice_prediction: False
# 2025-08-22 16:10:31,670 - INFO - post_process_hidden: False
# 2025-08-22 16:10:31,670 - INFO - concept: None
# /mnt/abka03/.conda/envs/rsml3/lib/python3.9/site-packages/transformers/models/auto/modeling_auto.py:2199: FutureWarning: The class `AutoModelForVision2Seq` is deprecated and will be removed in v5.0. Please use `AutoModelForImageTextToText` instead.
#   warnings.warn(
# Loading checkpoint shards: 100%|██████████| 5/5 [00:02<00:00,  1.78it/s]
# The image processor of type `Qwen2VLImageProcessor` is now loaded as a fast processor by default, even if the model checkpoint was saved with a slow processor. This is a breaking change and may produce slightly different outputs. To continue using the slow processor, instantiate this class with `use_fast=False`. Note that this behavior will be extended to all models in a future release.
# You have video processor config saved in `preprocessor.json` file which is deprecated. Video processor configs should be saved in their own `video_preprocessor.json` file. You can rename the file or load and save the processor back which renames it automatically. Loading from `preprocessor.json` will be removed in v5.0.
# 2025-08-22 16:10:37,360 - INFO - Successfully loaded Qwen/Qwen2.5-VL-7B-Instruct, device: cpu
# 2025-08-22 16:10:37,372 - INFO - Loading data from /mnt/abka03/concept_extraction_result/rsml/gemma3n/MCoX/SNMF/mscoco/train/features/save_hidden_states_sentence_qwen2_patched_image_airplane_token_of_interest_concept_generation_split_train.pth.
#  keys: dict_keys(['image', 'model_predictions', 'hidden_states']).
#  Extracted features of shape torch.Size([120, 3584])
# Matrix stats:
# Min: -102.125 Max: 65.75
# NaNs: 0 Infs: 0
# Shape: (120, 3584) Rank: 120
# 2025-08-22 16:10:37,590 - INFO -
# Decomposition type snmf, Components/concepts shape: (2, 3584), Activations shape: (120, 2)
# 2025-08-22 16:10:37,716 - INFO - Concept 0 grounded words: ['airplane']
# 2025-08-22 16:10:37,716 - INFO - Concept 1 grounded words: []
# 2025-08-22 16:10:37,716 - INFO - Activations size: torch.Size([120, 2])
# 2025-08-22 16:10:37,716 - INFO - Image paths length: 120
# 2025-08-22 16:10:37,716 - INFO - Concept 0 image paths: ['airplane@/mnt/abka03/xlvlm_data/coco_cc0_plus_cropped/train/airplane/283163_patch_3.png', 'airplane@/mnt/abka03/xlvlm_data/coco_cc0_plus_cropped/train/airplane/52759_patch_3.png', 'airplane@/mnt/abka03/xlvlm_data/coco_cc0_plus_cropped/train/airplane/211969_patch_2.png']
# 2025-08-22 16:10:37,716 - INFO - Concept 1 image paths: ['UNK@/mnt/abka03/xlvlm_data/coco_cc0_plus_cropped/train/airplane/418325_patch_0.png', 'UNK@/mnt/abka03/xlvlm_data/coco_cc0_plus_cropped/train/airplane/376838_patch_2.png', 'UNK@/mnt/abka03/xlvlm_data/coco_cc0_plus_cropped/train/airplane/224802_patch_0.png']
# 2025-08-22 16:10:37,717 - INFO - Saving analysis results to: /mnt/abka03/concept_extraction_result/rsml/gemma3n/MCoX/SNMF/mscoco/train/concept/intermediate_snmf/decompose_activations_text_grounding_image_grounding_snmf_individual_concept_save_hidden_states_sentence_qwen2_patched_image_airplane_token_of_interest_concept_generation_split_train_snmf.pth
# Processing file: save_hidden_states_sentence_qwen2_patched_image_apple_token_of_interest_concept_generation_split_train.pth
#   - Interpreted concept: save hidden states sentence qwen2 patched image apple token of interest concept generation split train
#   - Analyzing features...
# [nltk_data] Downloading package words to /home/abka03/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# 2025-08-22 16:10:41,619 - INFO - Arguments:
# 2025-08-22 16:10:41,619 - INFO - seed: 0
# 2025-08-22 16:10:41,619 - INFO - model_name_or_path: Qwen/Qwen2.5-VL-7B-Instruct
# 2025-08-22 16:10:41,619 - INFO - processor_name: None
# 2025-08-22 16:10:41,619 - INFO - local_files_only: False
# 2025-08-22 16:10:41,619 - INFO - cache_dir: None
# 2025-08-22 16:10:41,619 - INFO - prompt_template: llava
# 2025-08-22 16:10:41,619 - INFO - prompt: Describe the image in detail.
# 2025-08-22 16:10:41,619 - INFO - data_dir: data/
# 2025-08-22 16:10:41,619 - INFO - annotation_file: annotations.json
# 2025-08-22 16:10:41,619 - INFO - questions_file: annotations.json
# 2025-08-22 16:10:41,619 - INFO - answer_type_to_answer: None
# 2025-08-22 16:10:41,619 - INFO - split: train
# 2025-08-22 16:10:41,619 - INFO - dataset_size: -1
# 2025-08-22 16:10:41,619 - INFO - dataset_name: coco
# 2025-08-22 16:10:41,619 - INFO - batch_size: 1
# 2025-08-22 16:10:41,619 - INFO - hook_names: None
# 2025-08-22 16:10:41,619 - INFO - modules_to_hook: None
# 2025-08-22 16:10:41,619 - INFO - exact_match_modules_to_hook: False
# 2025-08-22 16:10:41,619 - INFO - hook_postprocessing_name: save_hidden_states
# 2025-08-22 16:10:41,619 - INFO - token_idx: None
# 2025-08-22 16:10:41,619 - INFO - token_start_end_idx: None
# 2025-08-22 16:10:41,619 - INFO - save_dir: /mnt/abka03/concept_extraction_result/rsml/gemma3n/MCoX/SNMF/mscoco/train/concept/intermediate_snmf
# 2025-08-22 16:10:41,619 - INFO - save_filename: individual_concept_save_hidden_states_sentence_qwen2_patched_image_apple_token_of_interest_concept_generation_split_train_snmf
# 2025-08-22 16:10:41,619 - INFO - save_analysis: True
# 2025-08-22 16:10:41,619 - INFO - features_path: ['/mnt/abka03/concept_extraction_result/rsml/gemma3n/MCoX/SNMF/mscoco/train/features/save_hidden_states_sentence_qwen2_patched_image_apple_token_of_interest_concept_generation_split_train.pth']
# 2025-08-22 16:10:41,619 - INFO - analysis_saving_path: results/analysis.pth
# 2025-08-22 16:10:41,619 - INFO - analysis_name: decompose_activations_text_grounding_image_grounding_snmf
# 2025-08-22 16:10:41,619 - INFO - feature_key: hidden_states
# 2025-08-22 16:10:41,619 - INFO - module_to_decompose: model.language_model.norm
# 2025-08-22 16:10:41,619 - INFO - decomposition_extract_pos: None
# 2025-08-22 16:10:41,619 - INFO - decomposition_method: snmf
# 2025-08-22 16:10:41,619 - INFO - num_concepts: [2]
# 2025-08-22 16:10:41,619 - INFO - dl_max_iter: 12000
# 2025-08-22 16:10:41,619 - INFO - num_grounded_text_tokens: 5
# 2025-08-22 16:10:41,619 - INFO - pre_num_top_tokens: 20
# 2025-08-22 16:10:41,619 - INFO - num_most_activating_samples: 3
# 2025-08-22 16:10:41,619 - INFO - generation_mode: False
# 2025-08-22 16:10:41,619 - INFO - max_new_tokens: 50
# 2025-08-22 16:10:41,619 - INFO - token_of_interest_num_samples: -1
# 2025-08-22 16:10:41,619 - INFO - select_token_of_interest_samples: False
# 2025-08-22 16:10:41,620 - INFO - allow_different_variations_of_token_of_interest: False
# 2025-08-22 16:10:41,620 - INFO - token_of_interest: None
# 2025-08-22 16:10:41,620 - INFO - tokens_of_interest: None
# 2025-08-22 16:10:41,620 - INFO - token_of_interest_key: response
# 2025-08-22 16:10:41,620 - INFO - token_of_interest_class: None
# 2025-08-22 16:10:41,620 - INFO - token_of_interest_idx: None
# 2025-08-22 16:10:41,620 - INFO - token_of_interest_start_token: 0
# 2025-08-22 16:10:41,620 - INFO - end_special_tokens:
# 2025-08-22 16:10:41,620 - INFO - save_only_generated_tokens: False
# 2025-08-22 16:10:41,620 - INFO - load_matched_features: False
# 2025-08-22 16:10:41,620 - INFO - steering_method: shift_of_means
# 2025-08-22 16:10:41,620 - INFO - steering_alpha: 1
# 2025-08-22 16:10:41,620 - INFO - category_of_interest:
# 2025-08-22 16:10:41,620 - INFO - base_features_key: hidden_states
# 2025-08-22 16:10:41,620 - INFO - shift_vector_path:
# 2025-08-22 16:10:41,620 - INFO - shift_vector_key: steering_vector
# 2025-08-22 16:10:41,620 - INFO - start_prompt_token_idx_steering: 0
# 2025-08-22 16:10:41,620 - INFO - use_random_grounding_words: False
# 2025-08-22 16:10:41,620 - INFO - captioning_metrics: ['CIDEr']
# 2025-08-22 16:10:41,620 - INFO - predictions_token_of_interest: None
# 2025-08-22 16:10:41,620 - INFO - targets_token_of_interest: None
# 2025-08-22 16:10:41,620 - INFO - save_predictions: False
# 2025-08-22 16:10:41,620 - INFO - predictions_path: None
# 2025-08-22 16:10:41,620 - INFO - origin_model_analysis_path: None
# 2025-08-22 16:10:41,620 - INFO - origin_model_feature_path: None
# 2025-08-22 16:10:41,620 - INFO - dest_model_analysis_path: None
# 2025-08-22 16:10:41,620 - INFO - dest_model_feature_path: None
# 2025-08-22 16:10:41,620 - INFO - visualize_concepts: False
# 2025-08-22 16:10:41,620 - INFO - compute_recovery_metrics: False
# 2025-08-22 16:10:41,620 - INFO - compute_stat_shift_vectors: False
# 2025-08-22 16:10:41,620 - INFO - select_samples_from_ids: False
# 2025-08-22 16:10:41,620 - INFO - path_to_samples_ids: None
# 2025-08-22 16:10:41,620 - INFO - slice_prediction: False
# 2025-08-22 16:10:41,620 - INFO - post_process_hidden: False
# 2025-08-22 16:10:41,620 - INFO - concept: None
# /mnt/abka03/.conda/envs/rsml3/lib/python3.9/site-packages/transformers/models/auto/modeling_auto.py:2199: FutureWarning: The class `AutoModelForVision2Seq` is deprecated and will be removed in v5.0. Please use `AutoModelForImageTextToText` instead.
#   warnings.warn(
# Loading checkpoint shards: 100%|██████████| 5/5 [00:02<00:00,  1.79it/s]
# The image processor of type `Qwen2VLImageProcessor` is now loaded as a fast processor by default, even if the model checkpoint was saved with a slow processor. This is a breaking change and may produce slightly different outputs. To continue using the slow processor, instantiate this class with `use_fast=False`. Note that this behavior will be extended to all models in a future release.
# You have video processor config saved in `preprocessor.json` file which is deprecated. Video processor configs should be saved in their own `video_preprocessor.json` file. You can rename the file or load and save the processor back which renames it automatically. Loading from `preprocessor.json` will be removed in v5.0.
# 2025-08-22 16:10:47,356 - INFO - Successfully loaded Qwen/Qwen2.5-VL-7B-Instruct, device: cpu
# 2025-08-22 16:10:47,368 - INFO - Loading data from /mnt/abka03/concept_extraction_result/rsml/gemma3n/MCoX/SNMF/mscoco/train/features/save_hidden_states_sentence_qwen2_patched_image_apple_token_of_interest_concept_generation_split_train.pth.
#  keys: dict_keys(['image', 'model_predictions', 'hidden_states']).
#  Extracted features of shape torch.Size([120, 3584])
# Matrix stats:
# Min: -105.0625 Max: 66.4375
# NaNs: 0 Infs: 0
# Shape: (120, 3584) Rank: 120
# 2025-08-22 16:10:47,631 - INFO -
# Decomposition type snmf, Components/concepts shape: (2, 3584), Activations shape: (120, 2)
# 2025-08-22 16:10:47,753 - INFO - Concept 0 grounded words: ['apple']
# 2025-08-22 16:10:47,753 - INFO - Concept 1 grounded words: ['apple']
# 2025-08-22 16:10:47,753 - INFO - Activations size: torch.Size([120, 2])
# 2025-08-22 16:10:47,753 - INFO - Image paths length: 120
# 2025-08-22 16:10:47,754 - INFO - Concept 0 image paths: ['apple@/mnt/abka03/xlvlm_data/coco_cc0_plus_cropped/train/apple/104568_patch_2.png', 'apple@/mnt/abka03/xlvlm_data/coco_cc0_plus_cropped/train/apple/579201_patch_3.png', 'apple@/mnt/abka03/xlvlm_data/coco_cc0_plus_cropped/train/apple/392850_patch_1.png']
# 2025-08-22 16:10:47,754 - INFO - Concept 1 image paths: ['UNK@/mnt/abka03/xlvlm_data/coco_cc0_plus_cropped/train/apple/407566_patch_3.png', 'UNK@/mnt/abka03/xlvlm_data/coco_cc0_plus_cropped/train/apple/417834_patch_3.png', 'UNK@/mnt/abka03/xlvlm_data/coco_cc0_plus_cropped/train/apple/417834_patch_0.png']
# 2025-08-22 16:10:47,754 - INFO - Saving analysis results to: /mnt/abka03/concept_extraction_result/rsml/gemma3n/MCoX/SNMF/mscoco/train/concept/intermediate_snmf/decompose_activations_text_grounding_image_grounding_snmf_individual_concept_save_hidden_states_sentence_qwen2_patched_image_apple_token_of_interest_concept_generation_split_train_snmf.pth
# Processing file: save_hidden_states_sentence_qwen2_patched_image_backpack_token_of_interest_concept_generation_split_train.pth
#   - Interpreted concept: save hidden states sentence qwen2 patched image backpack token of interest concept generation split train
#   - Analyzing features...
# [nltk_data] Downloading package words to /home/abka03/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# 2025-08-22 16:10:51,613 - INFO - Arguments:
# 2025-08-22 16:10:51,613 - INFO - seed: 0
# 2025-08-22 16:10:51,613 - INFO - model_name_or_path: Qwen/Qwen2.5-VL-7B-Instruct
# 2025-08-22 16:10:51,613 - INFO - processor_name: None
# 2025-08-22 16:10:51,613 - INFO - local_files_only: False
# 2025-08-22 16:10:51,613 - INFO - cache_dir: None
# 2025-08-22 16:10:51,613 - INFO - prompt_template: llava
# 2025-08-22 16:10:51,613 - INFO - prompt: Describe the image in detail.
# 2025-08-22 16:10:51,613 - INFO - data_dir: data/
# 2025-08-22 16:10:51,613 - INFO - annotation_file: annotations.json
# 2025-08-22 16:10:51,613 - INFO - questions_file: annotations.json
# 2025-08-22 16:10:51,613 - INFO - answer_type_to_answer: None
# 2025-08-22 16:10:51,613 - INFO - split: train
# 2025-08-22 16:10:51,613 - INFO - dataset_size: -1
# 2025-08-22 16:10:51,613 - INFO - dataset_name: coco
# 2025-08-22 16:10:51,613 - INFO - batch_size: 1
# 2025-08-22 16:10:51,613 - INFO - hook_names: None
# 2025-08-22 16:10:51,613 - INFO - modules_to_hook: None
# 2025-08-22 16:10:51,613 - INFO - exact_match_modules_to_hook: False
# 2025-08-22 16:10:51,613 - INFO - hook_postprocessing_name: save_hidden_states
# 2025-08-22 16:10:51,613 - INFO - token_idx: None
# 2025-08-22 16:10:51,613 - INFO - token_start_end_idx: None
# 2025-08-22 16:10:51,613 - INFO - save_dir: /mnt/abka03/concept_extraction_result/rsml/gemma3n/MCoX/SNMF/mscoco/train/concept/intermediate_snmf
# 2025-08-22 16:10:51,613 - INFO - save_filename: individual_concept_save_hidden_states_sentence_qwen2_patched_image_backpack_token_of_interest_concept_generation_split_train_snmf
# 2025-08-22 16:10:51,613 - INFO - save_analysis: True
# 2025-08-22 16:10:51,613 - INFO - features_path: ['/mnt/abka03/concept_extraction_result/rsml/gemma3n/MCoX/SNMF/mscoco/train/features/save_hidden_states_sentence_qwen2_patched_image_backpack_token_of_interest_concept_generation_split_train.pth']
# 2025-08-22 16:10:51,613 - INFO - analysis_saving_path: results/analysis.pth
# 2025-08-22 16:10:51,613 - INFO - analysis_name: decompose_activations_text_grounding_image_grounding_snmf
# 2025-08-22 16:10:51,613 - INFO - feature_key: hidden_states
# 2025-08-22 16:10:51,613 - INFO - module_to_decompose: model.language_model.norm
# 2025-08-22 16:10:51,613 - INFO - decomposition_extract_pos: None
# 2025-08-22 16:10:51,613 - INFO - decomposition_method: snmf
# 2025-08-22 16:10:51,613 - INFO - num_concepts: [2]
# 2025-08-22 16:10:51,613 - INFO - dl_max_iter: 12000
# 2025-08-22 16:10:51,613 - INFO - num_grounded_text_tokens: 5
# 2025-08-22 16:10:51,613 - INFO - pre_num_top_tokens: 20
# 2025-08-22 16:10:51,613 - INFO - num_most_activating_samples: 3
# 2025-08-22 16:10:51,613 - INFO - generation_mode: False
# 2025-08-22 16:10:51,613 - INFO - max_new_tokens: 50
# 2025-08-22 16:10:51,613 - INFO - token_of_interest_num_samples: -1
# 2025-08-22 16:10:51,613 - INFO - select_token_of_interest_samples: False
# 2025-08-22 16:10:51,613 - INFO - allow_different_variations_of_token_of_interest: False
# 2025-08-22 16:10:51,613 - INFO - token_of_interest: None
# 2025-08-22 16:10:51,613 - INFO - tokens_of_interest: None
# 2025-08-22 16:10:51,613 - INFO - token_of_interest_key: response
# 2025-08-22 16:10:51,613 - INFO - token_of_interest_class: None
# 2025-08-22 16:10:51,613 - INFO - token_of_interest_idx: None
# 2025-08-22 16:10:51,614 - INFO - token_of_interest_start_token: 0
# 2025-08-22 16:10:51,614 - INFO - end_special_tokens:
# 2025-08-22 16:10:51,614 - INFO - save_only_generated_tokens: False
# 2025-08-22 16:10:51,614 - INFO - load_matched_features: False
# 2025-08-22 16:10:51,614 - INFO - steering_method: shift_of_means
# 2025-08-22 16:10:51,614 - INFO - steering_alpha: 1
# 2025-08-22 16:10:51,614 - INFO - category_of_interest:
# 2025-08-22 16:10:51,614 - INFO - base_features_key: hidden_states
# 2025-08-22 16:10:51,614 - INFO - shift_vector_path:
# 2025-08-22 16:10:51,614 - INFO - shift_vector_key: steering_vector
# 2025-08-22 16:10:51,614 - INFO - start_prompt_token_idx_steering: 0
# 2025-08-22 16:10:51,614 - INFO - use_random_grounding_words: False
# 2025-08-22 16:10:51,614 - INFO - captioning_metrics: ['CIDEr']
# 2025-08-22 16:10:51,614 - INFO - predictions_token_of_interest: None
# 2025-08-22 16:10:51,614 - INFO - targets_token_of_interest: None
# 2025-08-22 16:10:51,614 - INFO - save_predictions: False
# 2025-08-22 16:10:51,614 - INFO - predictions_path: None
# 2025-08-22 16:10:51,614 - INFO - origin_model_analysis_path: None
# 2025-08-22 16:10:51,614 - INFO - origin_model_feature_path: None
# 2025-08-22 16:10:51,614 - INFO - dest_model_analysis_path: None
# 2025-08-22 16:10:51,614 - INFO - dest_model_feature_path: None
# 2025-08-22 16:10:51,614 - INFO - visualize_concepts: False
# 2025-08-22 16:10:51,614 - INFO - compute_recovery_metrics: False
# 2025-08-22 16:10:51,614 - INFO - compute_stat_shift_vectors: False
# 2025-08-22 16:10:51,614 - INFO - select_samples_from_ids: False
# 2025-08-22 16:10:51,614 - INFO - path_to_samples_ids: None
# 2025-08-22 16:10:51,614 - INFO - slice_prediction: False
# 2025-08-22 16:10:51,614 - INFO - post_process_hidden: False
# 2025-08-22 16:10:51,614 - INFO - concept: None
# /mnt/abka03/.conda/envs/rsml3/lib/python3.9/site-packages/transformers/models/auto/modeling_auto.py:2199: FutureWarning: The class `AutoModelForVision2Seq` is deprecated and will be removed in v5.0. Please use `AutoModelForImageTextToText` instead.
#   warnings.warn(
# Loading checkpoint shards: 100%|██████████| 5/5 [00:02<00:00,  1.78it/s]
# The image processor of type `Qwen2VLImageProcessor` is now loaded as a fast processor by default, even if the model checkpoint was saved with a slow processor. This is a breaking change and may produce slightly different outputs. To continue using the slow processor, instantiate this class with `use_fast=False`. Note that this behavior will be extended to all models in a future release.
# You have video processor config saved in `preprocessor.json` file which is deprecated. Video processor configs should be saved in their own `video_preprocessor.json` file. You can rename the file or load and save the processor back which renames it automatically. Loading from `preprocessor.json` will be removed in v5.0.
# 2025-08-22 16:10:57,141 - INFO - Successfully loaded Qwen/Qwen2.5-VL-7B-Instruct, device: cpu
# 2025-08-22 16:10:57,153 - INFO - Loading data from /mnt/abka03/concept_extraction_result/rsml/gemma3n/MCoX/SNMF/mscoco/train/features/save_hidden_states_sentence_qwen2_patched_image_backpack_token_of_interest_concept_generation_split_train.pth.
#  keys: dict_keys(['image', 'model_predictions', 'hidden_states']).
#  Extracted features of shape torch.Size([120, 3584])
# Matrix stats:
# Min: -104.625 Max: 65.4375
# NaNs: 0 Infs: 0
# Shape: (120, 3584) Rank: 120
# 2025-08-22 16:10:57,403 - INFO -
# Decomposition type snmf, Components/concepts shape: (2, 3584), Activations shape: (120, 2)
# 2025-08-22 16:10:57,529 - INFO - Concept 0 grounded words: []
# 2025-08-22 16:10:57,529 - INFO - Concept 1 grounded words: ['pack', 'bag']
# 2025-08-22 16:10:57,529 - INFO - Activations size: torch.Size([120, 2])
# 2025-08-22 16:10:57,529 - INFO - Image paths length: 120
# 2025-08-22 16:10:57,529 - INFO - Concept 0 image paths: ['UNK@/mnt/abka03/xlvlm_data/coco_cc0_plus_cropped/train/backpack/295461_patch_0.png', 'UNK@/mnt/abka03/xlvlm_data/coco_cc0_plus_cropped/train/backpack/295461_patch_2.png', 'UNK@/mnt/abka03/xlvlm_data/coco_cc0_plus_cropped/train/backpack/334872_patch_2.png']
# 2025-08-22 16:10:57,529 - INFO - Concept 1 image paths: ['backpack@/mnt/abka03/xlvlm_data/coco_cc0_plus_cropped/train/backpack/21001_patch_3.png', 'backpack@/mnt/abka03/xlvlm_data/coco_cc0_plus_cropped/train/backpack/395259_patch_2.png', 'backpack@/mnt/abka03/xlvlm_data/coco_cc0_plus_cropped/train/backpack/4125_patch_3.png']
# 2025-08-22 16:10:57,530 - INFO - Saving analysis results to: /mnt/abka03/concept_extraction_result/rsml/gemma3n/MCoX/SNMF/mscoco/train/concept/intermediate_snmf/decompose_activations_text_grounding_image_grounding_snmf_individual_concept_save_hidden_states_sentence_qwen2_patched_image_backpack_token_of_interest_concept_generation_split_train_snmf.pth
# Processing file: save_hidden_states_sentence_qwen2_patched_image_banana_token_of_interest_concept_generation_split_train.pth
#   - Interpreted concept: save hidden states sentence qwen2 patched image banana token of interest concept generation split train
#   - Analyzing features...
# [nltk_data] Downloading package words to /home/abka03/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# 2025-08-22 16:11:01,433 - INFO - Arguments:
# 2025-08-22 16:11:01,433 - INFO - seed: 0
# 2025-08-22 16:11:01,433 - INFO - model_name_or_path: Qwen/Qwen2.5-VL-7B-Instruct
# 2025-08-22 16:11:01,433 - INFO - processor_name: None
# 2025-08-22 16:11:01,433 - INFO - local_files_only: False
# 2025-08-22 16:11:01,433 - INFO - cache_dir: None
# 2025-08-22 16:11:01,433 - INFO - prompt_template: llava
# 2025-08-22 16:11:01,433 - INFO - prompt: Describe the image in detail.
# 2025-08-22 16:11:01,433 - INFO - data_dir: data/
# 2025-08-22 16:11:01,433 - INFO - annotation_file: annotations.json
# 2025-08-22 16:11:01,433 - INFO - questions_file: annotations.json
# 2025-08-22 16:11:01,433 - INFO - answer_type_to_answer: None
# 2025-08-22 16:11:01,433 - INFO - split: train
# 2025-08-22 16:11:01,433 - INFO - dataset_size: -1
# 2025-08-22 16:11:01,433 - INFO - dataset_name: coco
# 2025-08-22 16:11:01,433 - INFO - batch_size: 1
# 2025-08-22 16:11:01,433 - INFO - hook_names: None
# 2025-08-22 16:11:01,433 - INFO - modules_to_hook: None
# 2025-08-22 16:11:01,433 - INFO - exact_match_modules_to_hook: False
# 2025-08-22 16:11:01,433 - INFO - hook_postprocessing_name: save_hidden_states
# 2025-08-22 16:11:01,433 - INFO - token_idx: None
# 2025-08-22 16:11:01,433 - INFO - token_start_end_idx: None
# 2025-08-22 16:11:01,434 - INFO - save_dir: /mnt/abka03/concept_extraction_result/rsml/gemma3n/MCoX/SNMF/mscoco/train/concept/intermediate_snmf
# 2025-08-22 16:11:01,434 - INFO - save_filename: individual_concept_save_hidden_states_sentence_qwen2_patched_image_banana_token_of_interest_concept_generation_split_train_snmf
# 2025-08-22 16:11:01,434 - INFO - save_analysis: True
# 2025-08-22 16:11:01,434 - INFO - features_path: ['/mnt/abka03/concept_extraction_result/rsml/gemma3n/MCoX/SNMF/mscoco/train/features/save_hidden_states_sentence_qwen2_patched_image_banana_token_of_interest_concept_generation_split_train.pth']
# 2025-08-22 16:11:01,434 - INFO - analysis_saving_path: results/analysis.pth
# 2025-08-22 16:11:01,434 - INFO - analysis_name: decompose_activations_text_grounding_image_grounding_snmf
# 2025-08-22 16:11:01,434 - INFO - feature_key: hidden_states
# 2025-08-22 16:11:01,434 - INFO - module_to_decompose: model.language_model.norm
# 2025-08-22 16:11:01,434 - INFO - decomposition_extract_pos: None
# 2025-08-22 16:11:01,434 - INFO - decomposition_method: snmf
# 2025-08-22 16:11:01,434 - INFO - num_concepts: [2]
# 2025-08-22 16:11:01,434 - INFO - dl_max_iter: 12000
# 2025-08-22 16:11:01,434 - INFO - num_grounded_text_tokens: 5
# 2025-08-22 16:11:01,434 - INFO - pre_num_top_tokens: 20
# 2025-08-22 16:11:01,434 - INFO - num_most_activating_samples: 3
# 2025-08-22 16:11:01,434 - INFO - generation_mode: False
# 2025-08-22 16:11:01,434 - INFO - max_new_tokens: 50
# 2025-08-22 16:11:01,434 - INFO - token_of_interest_num_samples: -1
# 2025-08-22 16:11:01,434 - INFO - select_token_of_interest_samples: False
# 2025-08-22 16:11:01,434 - INFO - allow_different_variations_of_token_of_interest: False
# 2025-08-22 16:11:01,434 - INFO - token_of_interest: None
# 2025-08-22 16:11:01,434 - INFO - tokens_of_interest: None
# 2025-08-22 16:11:01,434 - INFO - token_of_interest_key: response
# 2025-08-22 16:11:01,434 - INFO - token_of_interest_class: None
# 2025-08-22 16:11:01,434 - INFO - token_of_interest_idx: None
# 2025-08-22 16:11:01,434 - INFO - token_of_interest_start_token: 0
# 2025-08-22 16:11:01,434 - INFO - end_special_tokens:
# 2025-08-22 16:11:01,434 - INFO - save_only_generated_tokens: False
# 2025-08-22 16:11:01,434 - INFO - load_matched_features: False
# 2025-08-22 16:11:01,434 - INFO - steering_method: shift_of_means
# 2025-08-22 16:11:01,434 - INFO - steering_alpha: 1
# 2025-08-22 16:11:01,434 - INFO - category_of_interest:
# 2025-08-22 16:11:01,434 - INFO - base_features_key: hidden_states
# 2025-08-22 16:11:01,434 - INFO - shift_vector_path:
# 2025-08-22 16:11:01,434 - INFO - shift_vector_key: steering_vector
# 2025-08-22 16:11:01,434 - INFO - start_prompt_token_idx_steering: 0
# 2025-08-22 16:11:01,434 - INFO - use_random_grounding_words: False
# 2025-08-22 16:11:01,434 - INFO - captioning_metrics: ['CIDEr']
# 2025-08-22 16:11:01,434 - INFO - predictions_token_of_interest: None
# 2025-08-22 16:11:01,434 - INFO - targets_token_of_interest: None
# 2025-08-22 16:11:01,434 - INFO - save_predictions: False
# 2025-08-22 16:11:01,434 - INFO - predictions_path: None
# 2025-08-22 16:11:01,434 - INFO - origin_model_analysis_path: None
# 2025-08-22 16:11:01,434 - INFO - origin_model_feature_path: None
# 2025-08-22 16:11:01,434 - INFO - dest_model_analysis_path: None
# 2025-08-22 16:11:01,434 - INFO - dest_model_feature_path: None
# 2025-08-22 16:11:01,434 - INFO - visualize_concepts: False
# 2025-08-22 16:11:01,434 - INFO - compute_recovery_metrics: False
# 2025-08-22 16:11:01,434 - INFO - compute_stat_shift_vectors: False
# 2025-08-22 16:11:01,434 - INFO - select_samples_from_ids: False
# 2025-08-22 16:11:01,435 - INFO - path_to_samples_ids: None
# 2025-08-22 16:11:01,435 - INFO - slice_prediction: False
# 2025-08-22 16:11:01,435 - INFO - post_process_hidden: False
# 2025-08-22 16:11:01,435 - INFO - concept: None
# /mnt/abka03/.conda/envs/rsml3/lib/python3.9/site-packages/transformers/models/auto/modeling_auto.py:2199: FutureWarning: The class `AutoModelForVision2Seq` is deprecated and will be removed in v5.0. Please use `AutoModelForImageTextToText` instead.
#   warnings.warn(
# Loading checkpoint shards: 100%|██████████| 5/5 [00:02<00:00,  1.77it/s]
# The image processor of type `Qwen2VLImageProcessor` is now loaded as a fast processor by default, even if the model checkpoint was saved with a slow processor. This is a breaking change and may produce slightly different outputs. To continue using the slow processor, instantiate this class with `use_fast=False`. Note that this behavior will be extended to all models in a future release.
# You have video processor config saved in `preprocessor.json` file which is deprecated. Video processor configs should be saved in their own `video_preprocessor.json` file. You can rename the file or load and save the processor back which renames it automatically. Loading from `preprocessor.json` will be removed in v5.0.
# 2025-08-22 16:11:07,314 - INFO - Successfully loaded Qwen/Qwen2.5-VL-7B-Instruct, device: cpu
# 2025-08-22 16:11:07,326 - INFO - Loading data from /mnt/abka03/concept_extraction_result/rsml/gemma3n/MCoX/SNMF/mscoco/train/features/save_hidden_states_sentence_qwen2_patched_image_banana_token_of_interest_concept_generation_split_train.pth.
#  keys: dict_keys(['image', 'model_predictions', 'hidden_states']).
#  Extracted features of shape torch.Size([120, 3584])
# Matrix stats:
# Min: -103.375 Max: 62.375
# NaNs: 0 Infs: 0
# Shape: (120, 3584) Rank: 120
# 2025-08-22 16:11:07,561 - INFO -
# Decomposition type snmf, Components/concepts shape: (2, 3584), Activations shape: (120, 2)
# 2025-08-22 16:11:07,685 - INFO - Concept 0 grounded words: ['banana']
# 2025-08-22 16:11:07,686 - INFO - Concept 1 grounded words: []
# 2025-08-22 16:11:07,686 - INFO - Activations size: torch.Size([120, 2])
# 2025-08-22 16:11:07,686 - INFO - Image paths length: 120
# 2025-08-22 16:11:07,686 - INFO - Concept 0 image paths: ['banana@/mnt/abka03/xlvlm_data/coco_cc0_plus_cropped/train/banana/332311_patch_2.png', 'banana@/mnt/abka03/xlvlm_data/coco_cc0_plus_cropped/train/banana/435279_patch_3.png', 'banana@/mnt/abka03/xlvlm_data/coco_cc0_plus_cropped/train/banana/290370_patch_2.png']
# 2025-08-22 16:11:07,686 - INFO - Concept 1 image paths: ['UNK@/mnt/abka03/xlvlm_data/coco_cc0_plus_cropped/train/banana/369259_patch_2.png', 'UNK@/mnt/abka03/xlvlm_data/coco_cc0_plus_cropped/train/banana/181771_patch_0.png', 'UNK@/mnt/abka03/xlvlm_data/coco_cc0_plus_cropped/train/banana/369259_patch_3.png']
# 2025-08-22 16:11:07,686 - INFO - Saving analysis results to: /mnt/abka03/concept_extraction_result/rsml/gemma3n/MCoX/SNMF/mscoco/train/concept/intermediate_snmf/decompose_activations_text_grounding_image_grounding_snmf_individual_concept_save_hidden_states_sentence_qwen2_patched_image_banana_token_of_interest_concept_generation_split_train_snmf.pth
# Processing file: save_hidden_states_sentence_qwen2_patched_image_baseball_bat_token_of_interest_concept_generation_split_train.pth
#   - Interpreted concept: save hidden states sentence qwen2 patched image baseball bat token of interest concept generation split train
#   - Analyzing features...
# [nltk_data] Downloading package words to /home/abka03/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# 2025-08-22 16:11:11,534 - INFO - Arguments:
# 2025-08-22 16:11:11,534 - INFO - seed: 0
# 2025-08-22 16:11:11,534 - INFO - model_name_or_path: Qwen/Qwen2.5-VL-7B-Instruct
# 2025-08-22 16:11:11,534 - INFO - processor_name: None
# 2025-08-22 16:11:11,534 - INFO - local_files_only: False
# 2025-08-22 16:11:11,534 - INFO - cache_dir: None
# 2025-08-22 16:11:11,534 - INFO - prompt_template: llava
# 2025-08-22 16:11:11,534 - INFO - prompt: Describe the image in detail.
# 2025-08-22 16:11:11,534 - INFO - data_dir: data/
# 2025-08-22 16:11:11,534 - INFO - annotation_file: annotations.json
# 2025-08-22 16:11:11,534 - INFO - questions_file: annotations.json
# 2025-08-22 16:11:11,535 - INFO - answer_type_to_answer: None
# 2025-08-22 16:11:11,535 - INFO - split: train
# 2025-08-22 16:11:11,535 - INFO - dataset_size: -1
# 2025-08-22 16:11:11,535 - INFO - dataset_name: coco
# 2025-08-22 16:11:11,535 - INFO - batch_size: 1
# 2025-08-22 16:11:11,535 - INFO - hook_names: None
# 2025-08-22 16:11:11,535 - INFO - modules_to_hook: None
# 2025-08-22 16:11:11,535 - INFO - exact_match_modules_to_hook: False
# 2025-08-22 16:11:11,535 - INFO - hook_postprocessing_name: save_hidden_states
# 2025-08-22 16:11:11,535 - INFO - token_idx: None
# 2025-08-22 16:11:11,535 - INFO - token_start_end_idx: None
# 2025-08-22 16:11:11,535 - INFO - save_dir: /mnt/abka03/concept_extraction_result/rsml/gemma3n/MCoX/SNMF/mscoco/train/concept/intermediate_snmf
# 2025-08-22 16:11:11,535 - INFO - save_filename: individual_concept_save_hidden_states_sentence_qwen2_patched_image_baseball_bat_token_of_interest_concept_generation_split_train_snmf
# 2025-08-22 16:11:11,535 - INFO - save_analysis: True
# 2025-08-22 16:11:11,535 - INFO - features_path: ['/mnt/abka03/concept_extraction_result/rsml/gemma3n/MCoX/SNMF/mscoco/train/features/save_hidden_states_sentence_qwen2_patched_image_baseball_bat_token_of_interest_concept_generation_split_train.pth']
# 2025-08-22 16:11:11,535 - INFO - analysis_saving_path: results/analysis.pth
# 2025-08-22 16:11:11,535 - INFO - analysis_name: decompose_activations_text_grounding_image_grounding_snmf
# 2025-08-22 16:11:11,535 - INFO - feature_key: hidden_states
# 2025-08-22 16:11:11,535 - INFO - module_to_decompose: model.language_model.norm
# 2025-08-22 16:11:11,535 - INFO - decomposition_extract_pos: None
# 2025-08-22 16:11:11,535 - INFO - decomposition_method: snmf
# 2025-08-22 16:11:11,535 - INFO - num_concepts: [2]
# 2025-08-22 16:11:11,535 - INFO - dl_max_iter: 12000
# 2025-08-22 16:11:11,535 - INFO - num_grounded_text_tokens: 5
# 2025-08-22 16:11:11,535 - INFO - pre_num_top_tokens: 20
# 2025-08-22 16:11:11,535 - INFO - num_most_activating_samples: 3
# 2025-08-22 16:11:11,535 - INFO - generation_mode: False
# 2025-08-22 16:11:11,535 - INFO - max_new_tokens: 50
# 2025-08-22 16:11:11,535 - INFO - token_of_interest_num_samples: -1
# 2025-08-22 16:11:11,535 - INFO - select_token_of_interest_samples: False
# 2025-08-22 16:11:11,535 - INFO - allow_different_variations_of_token_of_interest: False
# 2025-08-22 16:11:11,535 - INFO - token_of_interest: None
# 2025-08-22 16:11:11,535 - INFO - tokens_of_interest: None
# 2025-08-22 16:11:11,535 - INFO - token_of_interest_key: response
# 2025-08-22 16:11:11,535 - INFO - token_of_interest_class: None
# 2025-08-22 16:11:11,535 - INFO - token_of_interest_idx: None
# 2025-08-22 16:11:11,535 - INFO - token_of_interest_start_token: 0
# 2025-08-22 16:11:11,535 - INFO - end_special_tokens:
# 2025-08-22 16:11:11,535 - INFO - save_only_generated_tokens: False
# 2025-08-22 16:11:11,535 - INFO - load_matched_features: False
# 2025-08-22 16:11:11,535 - INFO - steering_method: shift_of_means
# 2025-08-22 16:11:11,535 - INFO - steering_alpha: 1
# 2025-08-22 16:11:11,535 - INFO - category_of_interest:
# 2025-08-22 16:11:11,535 - INFO - base_features_key: hidden_states
# 2025-08-22 16:11:11,535 - INFO - shift_vector_path:
# 2025-08-22 16:11:11,535 - INFO - shift_vector_key: steering_vector
# 2025-08-22 16:11:11,535 - INFO - start_prompt_token_idx_steering: 0
# 2025-08-22 16:11:11,535 - INFO - use_random_grounding_words: False
# 2025-08-22 16:11:11,535 - INFO - captioning_metrics: ['CIDEr']
# 2025-08-22 16:11:11,536 - INFO - predictions_token_of_interest: None
# 2025-08-22 16:11:11,536 - INFO - targets_token_of_interest: None
# 2025-08-22 16:11:11,536 - INFO - save_predictions: False
# 2025-08-22 16:11:11,536 - INFO - predictions_path: None
# 2025-08-22 16:11:11,536 - INFO - origin_model_analysis_path: None
# 2025-08-22 16:11:11,536 - INFO - origin_model_feature_path: None
# 2025-08-22 16:11:11,536 - INFO - dest_model_analysis_path: None
# 2025-08-22 16:11:11,536 - INFO - dest_model_feature_path: None
# 2025-08-22 16:11:11,536 - INFO - visualize_concepts: False
# 2025-08-22 16:11:11,536 - INFO - compute_recovery_metrics: False
# 2025-08-22 16:11:11,536 - INFO - compute_stat_shift_vectors: False
# 2025-08-22 16:11:11,536 - INFO - select_samples_from_ids: False
# 2025-08-22 16:11:11,536 - INFO - path_to_samples_ids: None
# 2025-08-22 16:11:11,536 - INFO - slice_prediction: False
# 2025-08-22 16:11:11,536 - INFO - post_process_hidden: False
# 2025-08-22 16:11:11,536 - INFO - concept: None
# /mnt/abka03/.conda/envs/rsml3/lib/python3.9/site-packages/transformers/models/auto/modeling_auto.py:2199: FutureWarning: The class `AutoModelForVision2Seq` is deprecated and will be removed in v5.0. Please use `AutoModelForImageTextToText` instead.
#   warnings.warn(
# Loading checkpoint shards: 100%|██████████| 5/5 [00:02<00:00,  1.77it/s]
# The image processor of type `Qwen2VLImageProcessor` is now loaded as a fast processor by default, even if the model checkpoint was saved with a slow processor. This is a breaking change and may produce slightly different outputs. To continue using the slow processor, instantiate this class with `use_fast=False`. Note that this behavior will be extended to all models in a future release.
# You have video processor config saved in `preprocessor.json` file which is deprecated. Video processor configs should be saved in their own `video_preprocessor.json` file. You can rename the file or load and save the processor back which renames it automatically. Loading from `preprocessor.json` will be removed in v5.0.
# 2025-08-22 16:11:17,205 - INFO - Successfully loaded Qwen/Qwen2.5-VL-7B-Instruct, device: cpu
# 2025-08-22 16:11:17,218 - INFO - Loading data from /mnt/abka03/concept_extraction_result/rsml/gemma3n/MCoX/SNMF/mscoco/train/features/save_hidden_states_sentence_qwen2_patched_image_baseball_bat_token_of_interest_concept_generation_split_train.pth.
#  keys: dict_keys(['image', 'model_predictions', 'hidden_states']).
#  Extracted features of shape torch.Size([120, 3584])
# Matrix stats:
# Min: -100.625 Max: 67.0
# NaNs: 0 Infs: 0
# Shape: (120, 3584) Rank: 120
# 2025-08-22 16:11:17,445 - INFO -
# Decomposition type snmf, Components/concepts shape: (2, 3584), Activations shape: (120, 2)
# 2025-08-22 16:11:17,575 - INFO - Concept 0 grounded words: []
# 2025-08-22 16:11:17,575 - INFO - Concept 1 grounded words: ['bat', 'baseball']
# 2025-08-22 16:11:17,575 - INFO - Activations size: torch.Size([120, 2])
# 2025-08-22 16:11:17,575 - INFO - Image paths length: 120
# 2025-08-22 16:11:17,575 - INFO - Concept 0 image paths: ['UNK@/mnt/abka03/xlvlm_data/coco_cc0_plus_cropped/train/baseball_bat/337038_patch_3.png', 'UNK@/mnt/abka03/xlvlm_data/coco_cc0_plus_cropped/train/baseball_bat/456725_patch_1.png', 'UNK@/mnt/abka03/xlvlm_data/coco_cc0_plus_cropped/train/baseball_bat/89741_patch_0.png']
# 2025-08-22 16:11:17,575 - INFO - Concept 1 image paths: ['baseball_bat@/mnt/abka03/xlvlm_data/coco_cc0_plus_cropped/train/baseball_bat/518224_patch_1.png', 'baseball_bat@/mnt/abka03/xlvlm_data/coco_cc0_plus_cropped/train/baseball_bat/303650_patch_3.png', 'baseball_bat@/mnt/abka03/xlvlm_data/coco_cc0_plus_cropped/train/baseball_bat/553046_patch_3.png']
# 2025-08-22 16:11:17,575 - INFO - Saving analysis results to: /mnt/abka03/concept_extraction_result/rsml/gemma3n/MCoX/SNMF/mscoco/train/concept/intermediate_snmf/decompose_activations_text_grounding_image_grounding_snmf_individual_concept_save_hidden_states_sentence_qwen2_patched_image_baseball_bat_token_of_interest_concept_generation_split_train_snmf.pth
# Processing file: save_hidden_states_sentence_qwen2_patched_image_baseball_glove_token_of_interest_concept_generation_split_train.pth
#   - Interpreted concept: save hidden states sentence qwen2 patched image baseball glove token of interest concept generation split train
#   - Analyzing features...
# [nltk_data] Downloading package words to /home/abka03/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# 2025-08-22 16:11:21,482 - INFO - Arguments:
# 2025-08-22 16:11:21,482 - INFO - seed: 0
# 2025-08-22 16:11:21,482 - INFO - model_name_or_path: Qwen/Qwen2.5-VL-7B-Instruct
# 2025-08-22 16:11:21,482 - INFO - processor_name: None
# 2025-08-22 16:11:21,482 - INFO - local_files_only: False
# 2025-08-22 16:11:21,482 - INFO - cache_dir: None
# 2025-08-22 16:11:21,482 - INFO - prompt_template: llava
# 2025-08-22 16:11:21,482 - INFO - prompt: Describe the image in detail.
# 2025-08-22 16:11:21,482 - INFO - data_dir: data/
# 2025-08-22 16:11:21,482 - INFO - annotation_file: annotations.json
# 2025-08-22 16:11:21,482 - INFO - questions_file: annotations.json
# 2025-08-22 16:11:21,482 - INFO - answer_type_to_answer: None
# 2025-08-22 16:11:21,482 - INFO - split: train
# 2025-08-22 16:11:21,482 - INFO - dataset_size: -1
# 2025-08-22 16:11:21,482 - INFO - dataset_name: coco
# 2025-08-22 16:11:21,482 - INFO - batch_size: 1
# 2025-08-22 16:11:21,482 - INFO - hook_names: None
# 2025-08-22 16:11:21,482 - INFO - modules_to_hook: None
# 2025-08-22 16:11:21,482 - INFO - exact_match_modules_to_hook: False
# 2025-08-22 16:11:21,482 - INFO - hook_postprocessing_name: save_hidden_states
# 2025-08-22 16:11:21,482 - INFO - token_idx: None
# 2025-08-22 16:11:21,482 - INFO - token_start_end_idx: None
# 2025-08-22 16:11:21,482 - INFO - save_dir: /mnt/abka03/concept_extraction_result/rsml/gemma3n/MCoX/SNMF/mscoco/train/concept/intermediate_snmf
# 2025-08-22 16:11:21,482 - INFO - save_filename: individual_concept_save_hidden_states_sentence_qwen2_patched_image_baseball_glove_token_of_interest_concept_generation_split_train_snmf
# 2025-08-22 16:11:21,482 - INFO - save_analysis: True
# 2025-08-22 16:11:21,482 - INFO - features_path: ['/mnt/abka03/concept_extraction_result/rsml/gemma3n/MCoX/SNMF/mscoco/train/features/save_hidden_states_sentence_qwen2_patched_image_baseball_glove_token_of_interest_concept_generation_split_train.pth']
# 2025-08-22 16:11:21,482 - INFO - analysis_saving_path: results/analysis.pth
# 2025-08-22 16:11:21,482 - INFO - analysis_name: decompose_activations_text_grounding_image_grounding_snmf
# 2025-08-22 16:11:21,482 - INFO - feature_key: hidden_states
# 2025-08-22 16:11:21,483 - INFO - module_to_decompose: model.language_model.norm
# 2025-08-22 16:11:21,483 - INFO - decomposition_extract_pos: None
# 2025-08-22 16:11:21,483 - INFO - decomposition_method: snmf
# 2025-08-22 16:11:21,483 - INFO - num_concepts: [2]
# 2025-08-22 16:11:21,483 - INFO - dl_max_iter: 12000
# 2025-08-22 16:11:21,483 - INFO - num_grounded_text_tokens: 5
# 2025-08-22 16:11:21,483 - INFO - pre_num_top_tokens: 20
# 2025-08-22 16:11:21,483 - INFO - num_most_activating_samples: 3
# 2025-08-22 16:11:21,483 - INFO - generation_mode: False
# 2025-08-22 16:11:21,483 - INFO - max_new_tokens: 50
# 2025-08-22 16:11:21,483 - INFO - token_of_interest_num_samples: -1
# 2025-08-22 16:11:21,483 - INFO - select_token_of_interest_samples: False
# 2025-08-22 16:11:21,483 - INFO - allow_different_variations_of_token_of_interest: False
# 2025-08-22 16:11:21,483 - INFO - token_of_interest: None
# 2025-08-22 16:11:21,483 - INFO - tokens_of_interest: None
# 2025-08-22 16:11:21,483 - INFO - token_of_interest_key: response
# 2025-08-22 16:11:21,483 - INFO - token_of_interest_class: None
# 2025-08-22 16:11:21,483 - INFO - token_of_interest_idx: None
# 2025-08-22 16:11:21,483 - INFO - token_of_interest_start_token: 0
# 2025-08-22 16:11:21,483 - INFO - end_special_tokens:
# 2025-08-22 16:11:21,483 - INFO - save_only_generated_tokens: False
# 2025-08-22 16:11:21,483 - INFO - load_matched_features: False
# 2025-08-22 16:11:21,483 - INFO - steering_method: shift_of_means
# 2025-08-22 16:11:21,483 - INFO - steering_alpha: 1
# 2025-08-22 16:11:21,483 - INFO - category_of_interest:
# 2025-08-22 16:11:21,483 - INFO - base_features_key: hidden_states
# 2025-08-22 16:11:21,483 - INFO - shift_vector_path:
# 2025-08-22 16:11:21,483 - INFO - shift_vector_key: steering_vector
# 2025-08-22 16:11:21,483 - INFO - start_prompt_token_idx_steering: 0
# 2025-08-22 16:11:21,483 - INFO - use_random_grounding_words: False
# 2025-08-22 16:11:21,483 - INFO - captioning_metrics: ['CIDEr']
# 2025-08-22 16:11:21,483 - INFO - predictions_token_of_interest: None
# 2025-08-22 16:11:21,483 - INFO - targets_token_of_interest: None
# 2025-08-22 16:11:21,483 - INFO - save_predictions: False
# 2025-08-22 16:11:21,483 - INFO - predictions_path: None
# 2025-08-22 16:11:21,483 - INFO - origin_model_analysis_path: None
# 2025-08-22 16:11:21,483 - INFO - origin_model_feature_path: None
# 2025-08-22 16:11:21,483 - INFO - dest_model_analysis_path: None
# 2025-08-22 16:11:21,483 - INFO - dest_model_feature_path: None
# 2025-08-22 16:11:21,483 - INFO - visualize_concepts: False
# 2025-08-22 16:11:21,483 - INFO - compute_recovery_metrics: False
# 2025-08-22 16:11:21,483 - INFO - compute_stat_shift_vectors: False
# 2025-08-22 16:11:21,483 - INFO - select_samples_from_ids: False
# 2025-08-22 16:11:21,483 - INFO - path_to_samples_ids: None
# 2025-08-22 16:11:21,483 - INFO - slice_prediction: False
# 2025-08-22 16:11:21,483 - INFO - post_process_hidden: False
# 2025-08-22 16:11:21,483 - INFO - concept: None
# /mnt/abka03/.conda/envs/rsml3/lib/python3.9/site-packages/transformers/models/auto/modeling_auto.py:2199: FutureWarning: The class `AutoModelForVision2Seq` is deprecated and will be removed in v5.0. Please use `AutoModelForImageTextToText` instead.
#   warnings.warn(
# Loading checkpoint shards: 100%|██████████| 5/5 [00:02<00:00,  1.78it/s]
# ...
# 2025-08-22 16:12:01,594 - INFO - local_files_only: False
# 2025-08-22 16:12:01,594 - INFO - cache_dir: None
# 2025-08-22 16:12:01,594 - INFO - prompt_template: llava
# 2025-08-22 16:12:01,594 - INFO - prompt: Describe the image in detail.
# 2025-08-22 16:12:01,594 - INFO - data_dir: data/
# 2025-08-22 16:12:01,594 - INFO - annotation_file: annotations.json
# 2025-08-22 16:12:01,594 - INFO - questions_file: annotations.json
# 2025-08-22 16:12:01,594 - INFO - answer_type_to_answer: None
# 2025-08-22 16:12:01,594 - INFO - split: train
# 2025-08-22 16:12:01,594 - INFO - dataset_size: -1
# 2025-08-22 16:12:01,594 - INFO - dataset_name: coco
# 2025-08-22 16:12:01,594 - INFO - batch_size: 1
# 2025-08-22 16:12:01,594 - INFO - hook_names: None
# 2025-08-22 16:12:01,594 - INFO - modules_to_hook: None
# 2025-08-22 16:12:01,594 - INFO - exact_match_modules_to_hook: False
# 2025-08-22 16:12:01,594 - INFO - hook_postprocessing_name: save_hidden_states
# 2025-08-22 16:12:01,594 - INFO - token_idx: None
# 2025-08-22 16:12:01,594 - INFO - token_start_end_idx: None
# 2025-08-22 16:12:01,594 - INFO - save_dir: /mnt/abka03/concept_extraction_result/rsml/gemma3n/MCoX/SNMF/mscoco/train/concept/intermediate_snmf
# 2025-08-22 16:12:01,594 - INFO - save_filename: individual_concept_save_hidden_states_sentence_qwen2_patched_image_bicycle_token_of_interest_concept_generation_split_train_snmf
# 2025-08-22 16:12:01,594 - INFO - save_analysis: True
# 2025-08-22 16:12:01,594 - INFO - features_path: ['/mnt/abka03/concept_extraction_result/rsml/gemma3n/MCoX/SNMF/mscoco/train/features/save_hidden_states_sentence_qwen2_patched_image_bicycle_token_of_interest_concept_generation_split_train.pth']
# 2025-08-22 16:12:01,594 - INFO - analysis_saving_path: results/analysis.pth
# 2025-08-22 16:12:01,594 - INFO - analysis_name: decompose_activations_text_grounding_image_grounding_snmf
# 2025-08-22 16:12:01,594 - INFO - feature_key: hidden_states
# 2025-08-22 16:12:01,594 - INFO - module_to_decompose: model.language_model.norm
# 2025-08-22 16:12:01,594 - INFO - decomposition_extract_pos: None
# 2025-08-22 16:12:01,594 - INFO - decomposition_method: snmf
# 2025-08-22 16:12:01,594 - INFO - num_concepts: [2]
# 2025-08-22 16:12:01,594 - INFO - dl_max_iter: 12000
# 2025-08-22 16:12:01,594 - INFO - num_grounded_text_tokens: 5
# 2025-08-22 16:12:01,594 - INFO - pre_num_top_tokens: 20
# 2025-08-22 16:12:01,594 - INFO - num_most_activating_samples: 3
# 2025-08-22 16:12:01,594 - INFO - generation_mode: False
# 2025-08-22 16:12:01,594 - INFO - max_new_tokens: 50
# 2025-08-22 16:12:01,594 - INFO - token_of_interest_num_samples: -1
# 2025-08-22 16:12:01,594 - INFO - select_token_of_interest_samples: False
# 2025-08-22 16:12:01,594 - INFO - allow_different_variations_of_token_of_interest: False
# 2025-08-22 16:12:01,594 - INFO - token_of_interest: None
# 2025-08-22 16:12:01,594 - INFO - tokens_of_interest: None
# 2025-08-22 16:12:01,594 - INFO - token_of_interest_key: response
# 2025-08-22 16:12:01,594 - INFO - token_of_interest_class: None
# 2025-08-22 16:12:01,594 - INFO - token_of_interest_idx: None
# 2025-08-22 16:12:01,594 - INFO - token_of_interest_start_token: 0
# 2025-08-22 16:12:01,594 - INFO - end_special_tokens:
# 2025-08-22 16:12:01,594 - INFO - save_only_generated_tokens: False
# 2025-08-22 16:12:01,594 - INFO - load_matched_features: False
# 2025-08-22 16:12:01,594 - INFO - steering_method: shift_of_means
# 2025-08-22 16:12:01,594 - INFO - steering_alpha: 1
# 2025-08-22 16:12:01,595 - INFO - category_of_interest:
# 2025-08-22 16:12:01,595 - INFO - base_features_key: hidden_states
# 2025-08-22 16:12:01,595 - INFO - shift_vector_path:
# 2025-08-22 16:12:01,595 - INFO - shift_vector_key: steering_vector
# 2025-08-22 16:12:01,595 - INFO - start_prompt_token_idx_steering: 0
# 2025-08-22 16:12:01,595 - INFO - use_random_grounding_words: False
# 2025-08-22 16:12:01,595 - INFO - captioning_metrics: ['CIDEr']
# 2025-08-22 16:12:01,595 - INFO - predictions_token_of_interest: None
# 2025-08-22 16:12:01,595 - INFO - targets_token_of_interest: None
# 2025-08-22 16:12:01,595 - INFO - save_predictions: False
# 2025-08-22 16:12:01,595 - INFO - predictions_path: None
# 2025-08-22 16:12:01,595 - INFO - origin_model_analysis_path: None
# 2025-08-22 16:12:01,595 - INFO - origin_model_feature_path: None
# 2025-08-22 16:12:01,595 - INFO - dest_model_analysis_path: None
# 2025-08-22 16:12:01,595 - INFO - dest_model_feature_path: None
# 2025-08-22 16:12:01,595 - INFO - visualize_concepts: False
# 2025-08-22 16:12:01,595 - INFO - compute_recovery_metrics: False
# 2025-08-22 16:12:01,595 - INFO - compute_stat_shift_vectors: False
# 2025-08-22 16:12:01,595 - INFO - select_samples_from_ids: False
# 2025-08-22 16:12:01,595 - INFO - path_to_samples_ids: None
# 2025-08-22 16:12:01,595 - INFO - slice_prediction: False
# 2025-08-22 16:12:01,595 - INFO - post_process_hidden: False
# 2025-08-22 16:12:01,595 - INFO - concept: None
# /mnt/abka03/.conda/envs/rsml3/lib/python3.9/site-packages/transformers/models/auto/modeling_auto.py:2199: FutureWarning: The class `AutoModelForVision2Seq` is deprecated and will be removed in v5.0. Please use `AutoModelForImageTextToText` instead.
#   warnings.warn(
# Loading checkpoint shards: 100%|██████████| 5/5 [00:02<00:00,  1.78it/s]
# The image processor of type `Qwen2VLImageProcessor` is now loaded as a fast processor by default, even if the model checkpoint was saved with a slow processor. This is a breaking change and may produce slightly different outputs. To continue using the slow processor, instantiate this class with `use_fast=False`. Note that this behavior will be extended to all models in a future release.
# You have video processor config saved in `preprocessor.json` file which is deprecated. Video processor configs should be saved in their own `video_preprocessor.json` file. You can rename the file or load and save the processor back which renames it automatically. Loading from `preprocessor.json` will be removed in v5.0.
# 2025-08-22 16:12:07,292 - INFO - Successfully loaded Qwen/Qwen2.5-VL-7B-Instruct, device: cpu
# 2025-08-22 16:12:07,305 - INFO - Loading data from /mnt/abka03/concept_extraction_result/rsml/gemma3n/MCoX/SNMF/mscoco/train/features/save_hidden_states_sentence_qwen2_patched_image_bicycle_token_of_interest_concept_generation_split_train.pth.
#  keys: dict_keys(['image', 'model_predictions', 'hidden_states']).
#  Extracted features of shape torch.Size([120, 3584])
# Matrix stats:
# Min: -100.5625 Max: 66.6875
# NaNs: 0 Infs: 0
# Shape: (120, 3584) Rank: 120
# 2025-08-22 16:12:07,503 - INFO -
# Decomposition type snmf, Components/concepts shape: (2, 3584), Activations shape: (120, 2)
# 2025-08-22 16:12:07,626 - INFO - Concept 0 grounded words: []
# 2025-08-22 16:12:07,626 - INFO - Concept 1 grounded words: ['bicycle']
# 2025-08-22 16:12:07,626 - INFO - Activations size: torch.Size([120, 2])
# 2025-08-22 16:12:07,626 - INFO - Image paths length: 120
# 2025-08-22 16:12:07,627 - INFO - Concept 0 image paths: ['UNK@/mnt/abka03/xlvlm_data/coco_cc0_plus_cropped/train/bicycle/304694_patch_0.png', 'UNK@/mnt/abka03/xlvlm_data/coco_cc0_plus_cropped/train/bicycle/518685_patch_0.png', 'UNK@/mnt/abka03/xlvlm_data/coco_cc0_plus_cropped/train/bicycle/57879_patch_0.png']
# 2025-08-22 16:12:07,627 - INFO - Concept 1 image paths: ['bicycle@/mnt/abka03/xlvlm_data/coco_cc0_plus_cropped/train/bicycle/84540_patch_2.png', 'bicycle@/mnt/abka03/xlvlm_data/coco_cc0_plus_cropped/train/bicycle/84540_patch_3.png', 'bicycle@/mnt/abka03/xlvlm_data/coco_cc0_plus_cropped/train/bicycle/246833_patch_2.png']
# 2025-08-22 16:12:07,627 - INFO - Saving analysis results to: /mnt/abka03/concept_extraction_result/rsml/gemma3n/MCoX/SNMF/mscoco/train/concept/intermediate_snmf/decompose_activations_text_grounding_image_grounding_snmf_individual_concept_save_hidden_states_sentence_qwen2_patched_image_bicycle_token_of_interest_concept_generation_split_train_snmf.pth
#   - Combining concepts for snmf...
# Saved combined data to: /mnt/abka03/concept_extraction_result/rsml/gemma3n/MCoX/SNMF/mscoco/train/concept/combined_concept_snmf_raw.pth
# Saved combined data to: /mnt/abka03/concept_extraction_result/rsml/gemma3n/MCoX/SNMF/mscoco/train/concept/combined_concept_snmf_gl.pth
#   - Cleaning up intermediate files...
#   - Regrounding concepts with snmf using normalization: gl
# [nltk_data] Downloading package words to /home/abka03/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# 2025-08-22 16:12:21,389 - INFO - Arguments:
# 2025-08-22 16:12:21,389 - INFO - seed: 0
# 2025-08-22 16:12:21,389 - INFO - model_name_or_path: Qwen/Qwen2.5-VL-7B-Instruct
# 2025-08-22 16:12:21,389 - INFO - processor_name: None
# 2025-08-22 16:12:21,389 - INFO - local_files_only: False
# 2025-08-22 16:12:21,389 - INFO - cache_dir: None
# 2025-08-22 16:12:21,389 - INFO - prompt_template: llava
# 2025-08-22 16:12:21,389 - INFO - prompt: Describe the image in detail.
# 2025-08-22 16:12:21,389 - INFO - data_dir: data/
# 2025-08-22 16:12:21,389 - INFO - annotation_file: annotations.json
# 2025-08-22 16:12:21,389 - INFO - questions_file: annotations.json
# 2025-08-22 16:12:21,389 - INFO - answer_type_to_answer: None
# 2025-08-22 16:12:21,389 - INFO - split: train
# 2025-08-22 16:12:21,389 - INFO - dataset_size: -1
# 2025-08-22 16:12:21,390 - INFO - dataset_name: coco
# 2025-08-22 16:12:21,390 - INFO - batch_size: 1
# 2025-08-22 16:12:21,390 - INFO - hook_names: None
# 2025-08-22 16:12:21,390 - INFO - modules_to_hook: None
# 2025-08-22 16:12:21,390 - INFO - exact_match_modules_to_hook: False
# 2025-08-22 16:12:21,390 - INFO - hook_postprocessing_name: save_hidden_states
# 2025-08-22 16:12:21,390 - INFO - token_idx: None
# 2025-08-22 16:12:21,390 - INFO - token_start_end_idx: None
# 2025-08-22 16:12:21,390 - INFO - save_dir: /mnt/abka03/concept_extraction_result/rsml/gemma3n/MCoX/SNMF/mscoco/train/concept
# 2025-08-22 16:12:21,390 - INFO - save_filename: combined_concept_snmf_gl_regrounded
# 2025-08-22 16:12:21,390 - INFO - save_analysis: True
# 2025-08-22 16:12:21,390 - INFO - features_path: None
# 2025-08-22 16:12:21,390 - INFO - analysis_saving_path: /mnt/abka03/concept_extraction_result/rsml/gemma3n/MCoX/SNMF/mscoco/train/concept/combined_concept_snmf_raw.pth
# 2025-08-22 16:12:21,390 - INFO - analysis_name: redefine_activations_text_grounding_snmf
# 2025-08-22 16:12:21,390 - INFO - feature_key: hidden_states
# 2025-08-22 16:12:21,390 - INFO - module_to_decompose: model.language_model.norm
# 2025-08-22 16:12:21,390 - INFO - decomposition_extract_pos: None
# 2025-08-22 16:12:21,390 - INFO - decomposition_method: snmf
# 2025-08-22 16:12:21,390 - INFO - num_concepts: None
# 2025-08-22 16:12:21,390 - INFO - dl_max_iter: 12000
# 2025-08-22 16:12:21,390 - INFO - num_grounded_text_tokens: 5
# 2025-08-22 16:12:21,390 - INFO - pre_num_top_tokens: 20
# 2025-08-22 16:12:21,390 - INFO - num_most_activating_samples: 3
# 2025-08-22 16:12:21,390 - INFO - generation_mode: False
# 2025-08-22 16:12:21,390 - INFO - max_new_tokens: 50
# 2025-08-22 16:12:21,390 - INFO - token_of_interest_num_samples: -1
# 2025-08-22 16:12:21,390 - INFO - select_token_of_interest_samples: False
# 2025-08-22 16:12:21,390 - INFO - allow_different_variations_of_token_of_interest: False
# 2025-08-22 16:12:21,390 - INFO - token_of_interest: None
# 2025-08-22 16:12:21,390 - INFO - tokens_of_interest: None
# 2025-08-22 16:12:21,390 - INFO - token_of_interest_key: response
# 2025-08-22 16:12:21,390 - INFO - token_of_interest_class: None
# 2025-08-22 16:12:21,390 - INFO - token_of_interest_idx: None
# 2025-08-22 16:12:21,390 - INFO - token_of_interest_start_token: 0
# 2025-08-22 16:12:21,390 - INFO - end_special_tokens:
# 2025-08-22 16:12:21,390 - INFO - save_only_generated_tokens: False
# 2025-08-22 16:12:21,390 - INFO - load_matched_features: True
# 2025-08-22 16:12:21,390 - INFO - steering_method: shift_of_means
# 2025-08-22 16:12:21,390 - INFO - steering_alpha: 1
# 2025-08-22 16:12:21,390 - INFO - category_of_interest:
# 2025-08-22 16:12:21,390 - INFO - base_features_key: hidden_states
# 2025-08-22 16:12:21,390 - INFO - shift_vector_path:
# 2025-08-22 16:12:21,390 - INFO - shift_vector_key: steering_vector
# 2025-08-22 16:12:21,390 - INFO - start_prompt_token_idx_steering: 0
# 2025-08-22 16:12:21,390 - INFO - use_random_grounding_words: False
# 2025-08-22 16:12:21,390 - INFO - captioning_metrics: ['CIDEr']
# 2025-08-22 16:12:21,390 - INFO - predictions_token_of_interest: None
# 2025-08-22 16:12:21,390 - INFO - targets_token_of_interest: None
# 2025-08-22 16:12:21,390 - INFO - save_predictions: False
# 2025-08-22 16:12:21,390 - INFO - predictions_path: None
# 2025-08-22 16:12:21,390 - INFO - origin_model_analysis_path: None
# 2025-08-22 16:12:21,390 - INFO - origin_model_feature_path: None
# 2025-08-22 16:12:21,391 - INFO - dest_model_analysis_path: None
# 2025-08-22 16:12:21,391 - INFO - dest_model_feature_path: None
# 2025-08-22 16:12:21,391 - INFO - visualize_concepts: False
# 2025-08-22 16:12:21,391 - INFO - compute_recovery_metrics: False
# 2025-08-22 16:12:21,391 - INFO - compute_stat_shift_vectors: False
# 2025-08-22 16:12:21,391 - INFO - select_samples_from_ids: False
# 2025-08-22 16:12:21,391 - INFO - path_to_samples_ids: None
# 2025-08-22 16:12:21,391 - INFO - slice_prediction: False
# 2025-08-22 16:12:21,391 - INFO - post_process_hidden: False
# 2025-08-22 16:12:21,391 - INFO - concept: None
# /mnt/abka03/.conda/envs/rsml3/lib/python3.9/site-packages/transformers/models/auto/modeling_auto.py:2199: FutureWarning: The class `AutoModelForVision2Seq` is deprecated and will be removed in v5.0. Please use `AutoModelForImageTextToText` instead.
#   warnings.warn(
# Loading checkpoint shards: 100%|██████████| 5/5 [00:02<00:00,  1.78it/s]
# The image processor of type `Qwen2VLImageProcessor` is now loaded as a fast processor by default, even if the model checkpoint was saved with a slow processor. This is a breaking change and may produce slightly different outputs. To continue using the slow processor, instantiate this class with `use_fast=False`. Note that this behavior will be extended to all models in a future release.
# You have video processor config saved in `preprocessor.json` file which is deprecated. Video processor configs should be saved in their own `video_preprocessor.json` file. You can rename the file or load and save the processor back which renames it automatically. Loading from `preprocessor.json` will be removed in v5.0.
# 2025-08-22 16:12:27,036 - INFO - Successfully loaded Qwen/Qwen2.5-VL-7B-Instruct, device: cpu
# 2025-08-22 16:12:27,038 - INFO - Loading data from /mnt/abka03/concept_extraction_result/rsml/gemma3n/MCoX/SNMF/mscoco/train/concept/combined_concept_snmf_raw.pth.
#  Data size: 10, keys: dict_keys(['concepts', 'activations', 'decomposition_method', 'text_grounding', 'image_grounding_paths', 'analysis_model'])
# 2025-08-22 16:12:27,039 - INFO -
# Decomposition type snmf, Components/concepts shape: torch.Size([10, 3584]), Activations shape: 10
# 2025-08-22 16:12:27,291 - INFO - Concept 0 grounded words: ['bicycle']
# 2025-08-22 16:12:27,291 - INFO - Concept 1 grounded words: ['bearer']
# 2025-08-22 16:12:27,291 - INFO - Concept 2 grounded words: ['banana']
# 2025-08-22 16:12:27,291 - INFO - Concept 3 grounded words: ['airplane']
# 2025-08-22 16:12:27,291 - INFO - Concept 4 grounded words: ['bag', 'pack']
# 2025-08-22 16:12:27,291 - INFO - Concept 5 grounded words: ['apple']
# 2025-08-22 16:12:27,291 - INFO - Concept 6 grounded words: ['bed']
# 2025-08-22 16:12:27,291 - INFO - Concept 7 grounded words: ['baseball', 'glove']
# 2025-08-22 16:12:27,291 - INFO - Concept 8 grounded words: ['bench']
# 2025-08-22 16:12:27,292 - INFO - Concept 9 grounded words: ['bat', 'baseball']
# 2025-08-22 16:12:27,292 - INFO - Saving analysis results to: /mnt/abka03/concept_extraction_result/rsml/gemma3n/MCoX/SNMF/mscoco/train/concept/redefine_activations_text_grounding_snmf_combined_concept_snmf_gl_regrounded.pth
# === Completed decomposition: snmf ===
#
# All steps completed successfully.
# Total execution time: 0h 2m 0s
# CompletedProcess(args=['scripts/run_feature_decompose_cgdl.sh', '/mnt/abka03/huggingface/hub/hub', 'Qwen/Qwen2.5-VL-7B-Instruct', '/mnt/abka03/concept_extraction_result/rsml/gemma3n/MCoX/SNMF/mscoco/train'], returncode=0)

# %% [markdown]
# ## Visualize concept set

# %%
font_size = 50
tex_grounding_loc = 0.2

# %% [markdown]
# ## Local Explantion

# %%
# project the image feature to concepts
#import analysis.feature_decomposition as analysis_decomposition


import torch.nn.functional as F
results_filename = f"{concept_train_dir}/combined_concept_snmf_raw.pth" # Path to the results file for concept embeddings
#results_filename = "/mnt/abka03/concept_extraction/CAV/concept_grounding_zca.pth"# Path to the results file for concept embeddings
concept_data = torch.load(results_filename)
analysis_model = concept_data["analysis_model"]
grounding_words = concept_data["text_grounding"]

feat_matrix = feat_matrix.float()
projections = feat_matrix @ concept_data["concepts"].T
#projections =  projections / projections.max()
#print(projections.shape)
#can you apply cosign distance
projections = F.cosine_similarity(feat_matrix.unsqueeze(1), concept_data["concepts"].float().unsqueeze(0), dim=-1)
projections = (projections - projections.min()) / (projections.max() - projections.min())

# Normalize feature matrix (feat_matrix) and concept vectors
#feat_matrix = F.normalize(feat_matrix.float(), p=2, dim=1)  # (N, D)
#concepts = F.normalize(concept_data["concepts"].float(), p=2, dim=1)  # (K, D)

# Cosine similarity scaled to [-500, 500]
#projections = (feat_matrix @ concepts.T)
import numpy as np

def find_top_n_powerful_projection(data, n):
    """
    Finds the top n elements for each row along with their indices.

    Parameters:
    - data: List of lists or 2D numpy array.
    - n: Number of top values to find.

    Returns:
    - A list of lists, where each sublist contains tuples of (index, value) 
      representing the top n elements and their indices for the corresponding row.
    """
    # Ensure the input is a numpy array
    data = np.array(data)
    
    # Get the top n indices and values for each row
    top_n_indices = [np.argsort(row)[-n:][::-1] for row in data]
    top_n_pairs = [[(idx, row[idx]) for idx in idxs] for row, idxs in zip(data, top_n_indices)]
    
    return top_n_pairs

n = 4  #mumber of concept to discover 
top_powerful_indexes = find_top_n_powerful_projection(projections, n)

def remap_prjection_image_text(top_powerful_indexes, test_image_path, image_concept_path, phrase_concept_path, text_concept_path):
    if len(top_powerful_indexes) != len(test_image_path):
        raise ValueError("The projection list and image list of test data not have equal number.")
    
    print("Image concept path:",len(test_image_path))
    final_result = {}
    for each_image_path, concept_indexs in zip(test_image_path, top_powerful_indexes, ):
        final_result[each_image_path[0]] = {'vis_concepts':[(image_concept_path[i[0]], i[1]) for i in concept_indexs], 'phrase_concept': [phrase_concept_path[i[0]] for i in concept_indexs],  'text_concept': [( text_concept_path[i[0]],i[1]) for i in concept_indexs]}

    return final_result


image_grounding_paths = concept_data["image_grounding_paths"]
phrase_grounding_paths = concept_data['image_grounding_paths']
text_grounding_paths = concept_data["text_grounding"]
test_data_remapped = remap_prjection_image_text(top_powerful_indexes, test_image_file_name, image_grounding_paths, phrase_grounding_paths, text_grounding_paths)



def load_image(file_path):
    ext = os.path.splitext(file_path)[-1].lower()
    if ext == ".dcm":
        pass
        
    elif ext in [".jpeg", ".jpg", ".png"]:
        image = Image.open(file_path)
        return np.array(image)
    else:
        raise ValueError(f"Unsupported file format: {ext}")


def load_image_as_rgb(filepath):
    """
    Load an image (DICOM, PNG, JPG) and return its RGB data as a NumPy array.

    Args:
        filepath (str): Path to the image file.

    Returns:
        np.ndarray: RGB data as a NumPy array.
    """
    # Check file extension
    file_ext = filepath.split(".")[-1].lower()

    if file_ext in ["png", "jpg", "jpeg"]:
        # For PNG or JPG, use Pillow
        image = Image.open(filepath).convert("RGB")  # Ensure it's RGB
        return np.array(image).astype(np.uint8)

    else:
        raise ValueError(f"Unsupported file format: {file_ext}")


import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

def visualize_local_explantion(concept_idx, concept_text, image_paths):
    concept_names_scores = concept_text[concept_idx]
    paths = image_paths[concept_idx][0]
    importance = image_paths[concept_idx][1]
    num_imgs = len(paths)
    images = []
    concept_list = []

    for path in paths:
        concept, path = path.split("@")
        concept_list.append(concept.lower())
        cur_img = load_image(path)
        cur_img = np.array(Image.fromarray(cur_img).resize([256, 256]))
        images.append(cur_img)

    unique_concepts = sorted(set(concept_list))
    projection_score = concept_names_scores[1].item()
    print("Projection score:", projection_score)   
    # Increase figure height to fit projection score bar
    fig = plt.figure(figsize=(num_imgs * 2.5 + 3, 5.5))  # Height increased

    # Title row: unique concepts
    #fig.suptitle(', '.join(unique_concepts), fontsize=35, x=0.5, y=0.95)

    # Image layout
    gap = 0.01
    image_width = (0.8 - (num_imgs - 1) * gap) / num_imgs

    for i in range(num_imgs):
        left = tex_grounding_loc + i * (image_width + gap)
        ax = fig.add_axes([left, 0.25, image_width, 0.6])  # Adjusted y-position
        ax.imshow(images[i])
        ax.axis('off')

    # Add concept ID and names on the left
    #label_text = f"Concept {concept_idx}:\n" + "\n".join(concept_names_scores[0]) 
    #label_text = f"h{to_superscript('l')}(û{to_subscript(concept_idx)}):\n" + "\n".join(concept_names_scores[0])
    label_text = f"\n".join(concept_names_scores[0])
    fig.text(0.01, 0.5, label_text, va='center', ha='left', fontsize=font_size)

    # Add projection score bar (horizontal, centered on 0)
    ax_bar = fig.add_axes([tex_grounding_loc, 0.1, 0.75, 0.05])  # [left, bottom, width, height]
    ax_bar.barh([0], [projection_score], height=0.5, color='red')
    ax_bar.set_xlim([0, 1])
    ax_bar.set_yticks([])
    ax_bar.set_xticks([0, 1])
    ax_bar.set_xticklabels(['0', '1'], fontsize=font_size)
    ax_bar.axvline(0, color='black', linewidth=1)  # center line
    ax_bar.set_title('Projection Score', fontsize=font_size, loc='left')

    # Add value to the right of the bar
    #fig.text(0.88, 0.11, f"{round(projection_score)}", va='center', ha='left', fontsize=font_size)
    
    #plt.savefig(f"/mnt/abka03/Projects/xl-vlms/plots/mcox/local_explanation/grounding_{concept_idx}.svg", format='svg')
    plt.show()


    

def local_explantion(a_test_image,test_data_remapped):
    
# Provide the file path to the image
    image_path = a_test_image.split("@")[1]

    # Read and display the image
    img = load_image_as_rgb(image_path)
    fig = plt.figure(figsize=(8, 8))
    plt.imshow(img, cmap="gray")
    plt.axis('off')  # Optional: Turn off the axis
    plt.show()
    key = a_test_image
    text_concepts = test_data_remapped[key]
    for i in range(n):
         visualize_local_explantion(i, text_concepts['text_concept'], text_concepts['vis_concepts'] )
# Out:
# Image concept path: 1

# %%
#explain one noun phrase
phrase_number = 0
a_test_phrase_with_image = test_image_file_name[phrase_number][0]
print("Phrase at image:", a_test_phrase_with_image)
local_explantion(a_test_phrase_with_image, test_data_remapped)
# Out:
# Phrase at image: bear@/mnt/abka03/xlvlm_data/coco_cc0_plus/val/bear/573391.jpg
# Projection score: 1.0
# Projection score: 0.5415676236152649
# Projection score: 0.47163820266723633
# Projection score: 0.45406630635261536

# %% [markdown]
# ## Explain text with images in vlm.
# ### We have the image concepts
#
# ### First get the embedding for a text

# %%
# Get the feature for one image 
concept_name = "bed"


# !cd ../ && python src/save_features.py \
    --model_name $"{model_card}" \
    --dataset_name "text" \
    --data_dir $"{concept_name}" \
    --hook_name  "save_hidden_states_noun_phrase" \
    --modules_to_hook "model.language_model.norm" \
    --save_dir $"{val_output_dir}" \
    --save_filename "qwen2_5_text" \
    --generation_mode \
    --save_only_generated_tokens \
    --slice_prediction \
    --prompt_template "cgdl" \
    --exact_match_modules_to_hook \
    --cache_dir "/mnt/abka03/xl-vlms/cache"
# Out:
# 14304.56s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# [nltk_data] Downloading package words to /home/abka03/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# 2025-08-22 16:22:05,134 - INFO - Loading model: Qwen/Qwen2.5-VL-7B-Instruct
# 2025-08-22 16:22:05,134 - INFO - Arguments:
# 2025-08-22 16:22:05,134 - INFO - seed: 0
# 2025-08-22 16:22:05,134 - INFO - model_name_or_path: Qwen/Qwen2.5-VL-7B-Instruct
# 2025-08-22 16:22:05,134 - INFO - processor_name: None
# 2025-08-22 16:22:05,134 - INFO - local_files_only: False
# 2025-08-22 16:22:05,134 - INFO - cache_dir: /mnt/abka03/xl-vlms/cache
# 2025-08-22 16:22:05,134 - INFO - prompt_template: cgdl
# 2025-08-22 16:22:05,134 - INFO - prompt: Describe the image in detail.
# 2025-08-22 16:22:05,134 - INFO - data_dir: bed
# 2025-08-22 16:22:05,134 - INFO - annotation_file: annotations.json
# 2025-08-22 16:22:05,134 - INFO - questions_file: annotations.json
# 2025-08-22 16:22:05,134 - INFO - answer_type_to_answer: None
# 2025-08-22 16:22:05,134 - INFO - split: train
# 2025-08-22 16:22:05,134 - INFO - dataset_size: -1
# 2025-08-22 16:22:05,134 - INFO - dataset_name: text
# 2025-08-22 16:22:05,134 - INFO - batch_size: 1
# 2025-08-22 16:22:05,134 - INFO - hook_names: ['save_hidden_states_noun_phrase']
# 2025-08-22 16:22:05,134 - INFO - modules_to_hook: [['model.language_model.norm']]
# 2025-08-22 16:22:05,134 - INFO - exact_match_modules_to_hook: True
# 2025-08-22 16:22:05,134 - INFO - hook_postprocessing_name: save_hidden_states
# 2025-08-22 16:22:05,134 - INFO - token_idx: None
# 2025-08-22 16:22:05,134 - INFO - token_start_end_idx: None
# 2025-08-22 16:22:05,134 - INFO - save_dir: /mnt/abka03/concept_extraction_result/rsml/gemma3n/MCoX/SNMF/mscoco/val
# 2025-08-22 16:22:05,134 - INFO - save_filename: qwen2_5_text
# 2025-08-22 16:22:05,134 - INFO - save_analysis: True
# 2025-08-22 16:22:05,134 - INFO - features_path: None
# 2025-08-22 16:22:05,135 - INFO - analysis_saving_path: results/analysis.pth
# 2025-08-22 16:22:05,135 - INFO - analysis_name: decompose_activations
# 2025-08-22 16:22:05,135 - INFO - feature_key: hidden_states
# 2025-08-22 16:22:05,135 - INFO - module_to_decompose: None
# 2025-08-22 16:22:05,135 - INFO - decomposition_extract_pos: None
# 2025-08-22 16:22:05,135 - INFO - decomposition_method: None
# 2025-08-22 16:22:05,135 - INFO - num_concepts: None
# 2025-08-22 16:22:05,135 - INFO - dl_max_iter: 12000
# 2025-08-22 16:22:05,135 - INFO - num_grounded_text_tokens: 5
# 2025-08-22 16:22:05,135 - INFO - pre_num_top_tokens: 20
# 2025-08-22 16:22:05,135 - INFO - num_most_activating_samples: 3
# 2025-08-22 16:22:05,135 - INFO - generation_mode: True
# 2025-08-22 16:22:05,135 - INFO - max_new_tokens: 50
# 2025-08-22 16:22:05,135 - INFO - token_of_interest_num_samples: -1
# 2025-08-22 16:22:05,135 - INFO - select_token_of_interest_samples: False
# 2025-08-22 16:22:05,135 - INFO - allow_different_variations_of_token_of_interest: False
# 2025-08-22 16:22:05,135 - INFO - token_of_interest: None
# 2025-08-22 16:22:05,135 - INFO - tokens_of_interest: None
# 2025-08-22 16:22:05,135 - INFO - token_of_interest_key: response
# 2025-08-22 16:22:05,135 - INFO - token_of_interest_class: None
# 2025-08-22 16:22:05,135 - INFO - token_of_interest_idx: None
# 2025-08-22 16:22:05,135 - INFO - token_of_interest_start_token: 0
# 2025-08-22 16:22:05,135 - INFO - end_special_tokens:
# 2025-08-22 16:22:05,135 - INFO - save_only_generated_tokens: True
# 2025-08-22 16:22:05,135 - INFO - load_matched_features: False
# 2025-08-22 16:22:05,135 - INFO - steering_method: shift_of_means
# 2025-08-22 16:22:05,135 - INFO - steering_alpha: 1
# 2025-08-22 16:22:05,135 - INFO - category_of_interest:
# 2025-08-22 16:22:05,135 - INFO - base_features_key: hidden_states
# 2025-08-22 16:22:05,135 - INFO - shift_vector_path:
# 2025-08-22 16:22:05,135 - INFO - shift_vector_key: steering_vector
# 2025-08-22 16:22:05,135 - INFO - start_prompt_token_idx_steering: 0
# 2025-08-22 16:22:05,135 - INFO - use_random_grounding_words: False
# 2025-08-22 16:22:05,135 - INFO - captioning_metrics: ['CIDEr']
# 2025-08-22 16:22:05,135 - INFO - predictions_token_of_interest: None
# 2025-08-22 16:22:05,135 - INFO - targets_token_of_interest: None
# 2025-08-22 16:22:05,135 - INFO - save_predictions: False
# 2025-08-22 16:22:05,135 - INFO - predictions_path: None
# 2025-08-22 16:22:05,135 - INFO - origin_model_analysis_path: None
# 2025-08-22 16:22:05,135 - INFO - origin_model_feature_path: None
# 2025-08-22 16:22:05,136 - INFO - dest_model_analysis_path: None
# 2025-08-22 16:22:05,136 - INFO - dest_model_feature_path: None
# 2025-08-22 16:22:05,136 - INFO - visualize_concepts: False
# 2025-08-22 16:22:05,136 - INFO - compute_recovery_metrics: False
# 2025-08-22 16:22:05,136 - INFO - compute_stat_shift_vectors: False
# 2025-08-22 16:22:05,136 - INFO - select_samples_from_ids: False
# 2025-08-22 16:22:05,136 - INFO - path_to_samples_ids: None
# 2025-08-22 16:22:05,136 - INFO - slice_prediction: True
# 2025-08-22 16:22:05,136 - INFO - post_process_hidden: False
# 2025-08-22 16:22:05,136 - INFO - concept: None
# /mnt/abka03/.conda/envs/rsml3/lib/python3.9/site-packages/transformers/models/auto/modeling_auto.py:2199: FutureWarning: The class `AutoModelForVision2Seq` is deprecated and will be removed in v5.0. Please use `AutoModelForImageTextToText` instead.
#   warnings.warn(
# Loading checkpoint shards: 100%|██████████████████| 5/5 [00:02<00:00,  1.81it/s]
# The image processor of type `Qwen2VLImageProcessor` is now loaded as a fast processor by default, even if the model checkpoint was saved with a slow processor. This is a breaking change and may produce slightly different outputs. To continue using the slow processor, instantiate this class with `use_fast=False`. Note that this behavior will be extended to all models in a future release.
# You have video processor config saved in `preprocessor.json` file which is deprecated. Video processor configs should be saved in their own `video_preprocessor.json` file. You can rename the file or load and save the processor back which renames it automatically. Loading from `preprocessor.json` will be removed in v5.0.
# 2025-08-22 16:22:10,699 - INFO - Successfully loaded Qwen/Qwen2.5-VL-7B-Instruct, device: cuda
# 2025-08-22 16:22:10,700 - INFO - Apply save_hidden_states_noun_phrase to hooked_modules: ['model.language_model.norm']
# 2025-08-22 16:22:10,700 - INFO - Successfully loaded text
# 2025-08-22 16:22:10,700 - INFO - Reading dataset: text of size: 1
# 2025-08-22 16:22:11,350 - INFO - Saving data to: /mnt/abka03/concept_extraction_result/rsml/gemma3n/MCoX/SNMF/mscoco/val/features/save_hidden_states_noun_phrase_qwen2_5_text.pth

# %%
text_feature_path = f"{val_output_dir}/features/save_hidden_states_noun_phrase_qwen2_5_text.pth"
output = torch.load(text_feature_path)
#print(output)
absolute_features = output["hidden_states"]
print(output["model_predictions"])
# Out:
# [["'cat'"]]

# %%
# Project the text in to the concept and explain
from analysis.feature_decomposition import get_feature_matrix
script_path = "/mnt/abka03/Projects/xl-vlms/src"
if script_path not in sys.path:
    sys.path.append(script_path)


module_name = 'model.language_model.norm'
token_idx = None
output = torch.load(text_feature_path)
absolute_features = output["hidden_states"]
feat_matrix = get_feature_matrix(
            absolute_features,
            module_name=module_name,
            token_idx=token_idx,
        )


analysis_model = concept_data["analysis_model"]
grounding_words = concept_data["text_grounding"]
feat_matrix = feat_matrix.float()
#projections = feat_matrix @ concept_data["concepts"].T
#projections = projections / projections.max() 

projections = F.cosine_similarity(feat_matrix.unsqueeze(1), concept_data["concepts"].float().unsqueeze(0), dim=-1)
projections = (projections - projections.min()) / (projections.max() - projections.min()) 

top_powerful_indexes = find_top_n_powerful_projection(projections, n)
test_text = output['model_predictions']
def remap_prjection_text(top_powerful_indexes, test_text, image_concept_path,  text_concept_path):
    if len(top_powerful_indexes) != len(test_text):
        raise ValueError("The projection list and image list of test data not have equal number.")
    

    final_result = {}
    for each_image_path, concept_indexs in zip(test_text, top_powerful_indexes):
        final_result[each_image_path[0]] = {'vis_concepts':[(image_concept_path[i[0]], i[1]) for i in concept_indexs],  'text_concept': [( text_concept_path[i[0]],i[1]) for i in concept_indexs]}

    return final_result


text_grounding_paths = concept_data["text_grounding"]
test_data_remapped_text = remap_prjection_text(top_powerful_indexes, test_text , image_grounding_paths, text_grounding_paths)




def  visualize_grounding_text(concept_idx, concept_text, image_paths):
    concept_names_scores = concept_text[concept_idx]
    paths = image_paths[concept_idx][0]
    importance = image_paths[concept_idx][1]
    num_imgs = len(paths)
    images = []
    concept_list = []

    for path in paths:
        concept, path = path.split("@")
        concept_list.append(concept.lower())
        cur_img = load_image(path)
        cur_img = np.array(Image.fromarray(cur_img).resize([256, 256]))
        images.append(cur_img)

    unique_concepts = sorted(set(concept_list))
    projection_score = concept_names_scores[1].item()

    # Increase figure height to fit projection score bar
    fig = plt.figure(figsize=(num_imgs * 2.5 + 3, 5.5))  # Height increased

    # Title row: unique concepts
    #fig.suptitle(', '.join(unique_concepts), fontsize=35, x=0.5, y=0.95)

    # Image layout
    gap = 0.01
    image_width = (0.8 - (num_imgs - 1) * gap) / num_imgs

    for i in range(num_imgs):
        left = tex_grounding_loc + i * (image_width + gap)
        ax = fig.add_axes([left, 0.25, image_width, 0.6])  # Adjusted y-position
        ax.imshow(images[i])
        ax.axis('off')

    # Add concept ID and names on the left
    label_text = f""''.join(concept_names_scores[0])
    fig.text(0.01, 0.5, label_text, va='center', ha='left', fontsize=font_size)

    # Add projection score bar (horizontal, centered on 0)
    ax_bar = fig.add_axes([0.2, 0.1, 0.75, 0.05])  # [left, bottom, width, height]
    ax_bar.barh([0], [projection_score], height=0.5, color='red')
    ax_bar.set_xlim([0, 1])
    ax_bar.set_yticks([])
    ax_bar.set_xticks([0, 1])
    ax_bar.set_xticklabels(['0', '1'], fontsize=font_size)
    ax_bar.axvline(0, color='black', linewidth=1)  # center line
    ax_bar.set_title('Projection Score', fontsize=font_size, loc='left')

    # Add value to the right of the bar
    #fig.text(0.88, 0.11, f"{round(projection_score)}", va='center', ha='left', fontsize=40)
    #plt.savefig(f"/mnt/abka03/Projects/xl-vlms/plots/mcox/local_explanation/grounding.svg", format='svg')

    plt.show()

n=4
def local_explantion_text(a_test_image,test_data_remapped):
    
    text_concepts = test_data_remapped[a_test_image]
    for i in range(n):
         visualize_grounding_text(i, text_concepts['text_concept'], text_concepts['vis_concepts'] )
test_text = output['model_predictions']
print("All text:", test_text)
#explain one noun phrase
phrase_number = 0
a_test_phrase_with_image = test_text[phrase_number][0]
print("Phrase at image:", a_test_phrase_with_image)
local_explantion_text(a_test_phrase_with_image, test_data_remapped_text )
# Out:
# All text: [["'cat'"]]
# Phrase at image: 'cat'
