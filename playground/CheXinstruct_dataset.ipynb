# %%
file = '/home/kadir/xl-vlms/data/data.json'
import json

# Load the JSON file
with open(file, 'r') as file:
    data = json.load(file)

# Sort the keys alphabetically (or define your custom order)
sorted_keys = sorted(data.keys())  # Replace this with your desired order if needed

# Print the keys in the sorted order
for key in sorted_keys:
    print(key)
# Out:
# Binary Disease Classification
# Findings Generation
# Findings Summarization
# Fine-Grained Reasoning
# Multiple Disease Identification
# Phrase Grounding
# Single Disease Identification
# Temporal Classification
# View Classification
# Visual Question Answering
# info

# %%
data["Single Disease Identification"]
# Out:
# [{'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient64785/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 0,
#   'option_0': 'no finding',
#   'option_1': 'pneumothorax',
#   'option_2': 'cardiomegaly',
#   'option_3': 'consolidation',
#   'slice': 'no finding'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient64874/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 2,
#   'option_0': 'pneumonia',
#   'option_1': 'fracture',
#   'option_2': 'no finding',
#   'option_3': 'consolidation',
#   'slice': 'no finding'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient64981/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 0,
#   'option_0': 'no finding',
#   'option_1': 'support devices',
#   'option_2': 'consolidation',
#   'option_3': 'lung opacity',
#   'slice': 'no finding'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient64978/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 0,
#   'option_0': 'no finding',
#   'option_1': 'atelectasis',
#   'option_2': 'fracture',
#   'option_3': 'pneumothorax',
#   'slice': 'no finding'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient64808/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 2,
#   'option_0': 'support devices',
#   'option_1': 'atelectasis',
#   'option_2': 'no finding',
#   'option_3': 'enlarged cardiomediastinum',
#   'slice': 'no finding'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient64811/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 3,
#   'option_0': 'consolidation',
#   'option_1': 'fracture',
#   'option_2': 'atelectasis',
#   'option_3': 'no finding',
#   'slice': 'no finding'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient65050/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 3,
#   'option_0': 'edema',
#   'option_1': 'enlarged cardiomediastinum',
#   'option_2': 'lung lesion',
#   'option_3': 'no finding',
#   'slice': 'no finding'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient65002/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 2,
#   'option_0': 'support devices',
#   'option_1': 'pneumonia',
#   'option_2': 'no finding',
#   'option_3': 'atelectasis',
#   'slice': 'no finding'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient64989/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 2,
#   'option_0': 'enlarged cardiomediastinum',
#   'option_1': 'consolidation',
#   'option_2': 'no finding',
#   'option_3': 'pleural effusion',
#   'slice': 'no finding'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient64957/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 3,
#   'option_0': 'support devices',
#   'option_1': 'fracture',
#   'option_2': 'lung opacity',
#   'option_3': 'no finding',
#   'slice': 'no finding'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient64788/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 2,
#   'option_0': 'edema',
#   'option_1': 'lung opacity',
#   'option_2': 'no finding',
#   'option_3': 'atelectasis',
#   'slice': 'no finding'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient64846/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 0,
#   'option_0': 'no finding',
#   'option_1': 'atelectasis',
#   'option_2': 'lung opacity',
#   'option_3': 'pneumothorax',
#   'slice': 'no finding'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient64925/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 2,
#   'option_0': 'cardiomegaly',
#   'option_1': 'edema',
#   'option_2': 'no finding',
#   'option_3': 'pleural effusion',
#   'slice': 'no finding'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient64905/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 0,
#   'option_0': 'no finding',
#   'option_1': 'support devices',
#   'option_2': 'cardiomegaly',
#   'option_3': 'pneumonia',
#   'slice': 'no finding'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient64933/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 3,
#   'option_0': 'pleural effusion',
#   'option_1': 'atelectasis',
#   'option_2': 'edema',
#   'option_3': 'no finding',
#   'slice': 'no finding'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient65049/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 2,
#   'option_0': 'atelectasis',
#   'option_1': 'consolidation',
#   'option_2': 'enlarged cardiomediastinum',
#   'option_3': 'fracture',
#   'slice': 'enlarged cardiomediastinum'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient64936/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 1,
#   'option_0': 'edema',
#   'option_1': 'enlarged cardiomediastinum',
#   'option_2': 'fracture',
#   'option_3': 'pneumonia',
#   'slice': 'enlarged cardiomediastinum'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient64743/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 2,
#   'option_0': 'fracture',
#   'option_1': 'lung lesion',
#   'option_2': 'enlarged cardiomediastinum',
#   'option_3': 'pneumothorax',
#   'slice': 'enlarged cardiomediastinum'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient65144/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 2,
#   'option_0': 'pleural effusion',
#   'option_1': 'lung lesion',
#   'option_2': 'enlarged cardiomediastinum',
#   'option_3': 'pneumothorax',
#   'slice': 'enlarged cardiomediastinum'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient65046/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 3,
#   'option_0': 'pneumothorax',
#   'option_1': 'consolidation',
#   'option_2': 'no finding',
#   'option_3': 'enlarged cardiomediastinum',
#   'slice': 'enlarged cardiomediastinum'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient64951/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 2,
#   'option_0': 'fracture',
#   'option_1': 'lung opacity',
#   'option_2': 'enlarged cardiomediastinum',
#   'option_3': 'edema',
#   'slice': 'enlarged cardiomediastinum'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient65014/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 2,
#   'option_0': 'atelectasis',
#   'option_1': 'no finding',
#   'option_2': 'enlarged cardiomediastinum',
#   'option_3': 'fracture',
#   'slice': 'enlarged cardiomediastinum'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient64916/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 2,
#   'option_0': 'consolidation',
#   'option_1': 'lung lesion',
#   'option_2': 'enlarged cardiomediastinum',
#   'option_3': 'fracture',
#   'slice': 'enlarged cardiomediastinum'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient65118/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 3,
#   'option_0': 'lung lesion',
#   'option_1': 'support devices',
#   'option_2': 'consolidation',
#   'option_3': 'enlarged cardiomediastinum',
#   'slice': 'enlarged cardiomediastinum'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient64802/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 2,
#   'option_0': 'fracture',
#   'option_1': 'edema',
#   'option_2': 'enlarged cardiomediastinum',
#   'option_3': 'atelectasis',
#   'slice': 'enlarged cardiomediastinum'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient64885/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 0,
#   'option_0': 'enlarged cardiomediastinum',
#   'option_1': 'fracture',
#   'option_2': 'pneumonia',
#   'option_3': 'no finding',
#   'slice': 'enlarged cardiomediastinum'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient64827/study1/view2_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 0,
#   'option_0': 'enlarged cardiomediastinum',
#   'option_1': 'consolidation',
#   'option_2': 'pneumothorax',
#   'option_3': 'no finding',
#   'slice': 'enlarged cardiomediastinum'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient64838/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 1,
#   'option_0': 'pneumothorax',
#   'option_1': 'enlarged cardiomediastinum',
#   'option_2': 'atelectasis',
#   'option_3': 'pleural effusion',
#   'slice': 'enlarged cardiomediastinum'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient65087/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 1,
#   'option_0': 'pneumonia',
#   'option_1': 'enlarged cardiomediastinum',
#   'option_2': 'fracture',
#   'option_3': 'support devices',
#   'slice': 'enlarged cardiomediastinum'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient65169/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 2,
#   'option_0': 'lung lesion',
#   'option_1': 'no finding',
#   'option_2': 'enlarged cardiomediastinum',
#   'option_3': 'pneumonia',
#   'slice': 'enlarged cardiomediastinum'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient64991/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 2,
#   'option_0': 'no finding',
#   'option_1': 'pneumonia',
#   'option_2': 'cardiomegaly',
#   'option_3': 'pneumothorax',
#   'slice': 'cardiomegaly'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient64908/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 2,
#   'option_0': 'lung lesion',
#   'option_1': 'pneumothorax',
#   'option_2': 'cardiomegaly',
#   'option_3': 'fracture',
#   'slice': 'cardiomegaly'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient65034/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 2,
#   'option_0': 'pneumothorax',
#   'option_1': 'pneumonia',
#   'option_2': 'cardiomegaly',
#   'option_3': 'lung lesion',
#   'slice': 'cardiomegaly'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient64741/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 0,
#   'option_0': 'cardiomegaly',
#   'option_1': 'atelectasis',
#   'option_2': 'edema',
#   'option_3': 'consolidation',
#   'slice': 'cardiomegaly'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient64807/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 3,
#   'option_0': 'pneumonia',
#   'option_1': 'pneumothorax',
#   'option_2': 'support devices',
#   'option_3': 'cardiomegaly',
#   'slice': 'cardiomegaly'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient64961/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 1,
#   'option_0': 'no finding',
#   'option_1': 'cardiomegaly',
#   'option_2': 'edema',
#   'option_3': 'consolidation',
#   'slice': 'cardiomegaly'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient65113/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 1,
#   'option_0': 'pneumonia',
#   'option_1': 'cardiomegaly',
#   'option_2': 'lung lesion',
#   'option_3': 'pleural effusion',
#   'slice': 'cardiomegaly'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient65091/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 1,
#   'option_0': 'pleural effusion',
#   'option_1': 'cardiomegaly',
#   'option_2': 'consolidation',
#   'option_3': 'fracture',
#   'slice': 'cardiomegaly'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient65126/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 2,
#   'option_0': 'lung lesion',
#   'option_1': 'no finding',
#   'option_2': 'cardiomegaly',
#   'option_3': 'pleural effusion',
#   'slice': 'cardiomegaly'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient65161/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 0,
#   'option_0': 'cardiomegaly',
#   'option_1': 'pneumothorax',
#   'option_2': 'pneumonia',
#   'option_3': 'no finding',
#   'slice': 'cardiomegaly'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient64866/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 2,
#   'option_0': 'consolidation',
#   'option_1': 'pneumonia',
#   'option_2': 'cardiomegaly',
#   'option_3': 'atelectasis',
#   'slice': 'cardiomegaly'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient65112/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 3,
#   'option_0': 'consolidation',
#   'option_1': 'fracture',
#   'option_2': 'pneumonia',
#   'option_3': 'cardiomegaly',
#   'slice': 'cardiomegaly'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient64838/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 3,
#   'option_0': 'pneumothorax',
#   'option_1': 'pleural effusion',
#   'option_2': 'consolidation',
#   'option_3': 'cardiomegaly',
#   'slice': 'cardiomegaly'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient64793/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 1,
#   'option_0': 'no finding',
#   'option_1': 'cardiomegaly',
#   'option_2': 'lung lesion',
#   'option_3': 'consolidation',
#   'slice': 'cardiomegaly'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient64970/study1/view2_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 3,
#   'option_0': 'consolidation',
#   'option_1': 'pneumonia',
#   'option_2': 'lung lesion',
#   'option_3': 'cardiomegaly',
#   'slice': 'cardiomegaly'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient65075/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 1,
#   'option_0': 'lung lesion',
#   'option_1': 'lung opacity',
#   'option_2': 'fracture',
#   'option_3': 'pneumonia',
#   'slice': 'lung opacity'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient64790/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 2,
#   'option_0': 'cardiomegaly',
#   'option_1': 'pleural effusion',
#   'option_2': 'lung opacity',
#   'option_3': 'atelectasis',
#   'slice': 'lung opacity'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient65226/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 0,
#   'option_0': 'lung opacity',
#   'option_1': 'atelectasis',
#   'option_2': 'pneumothorax',
#   'option_3': 'no finding',
#   'slice': 'lung opacity'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient65157/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 2,
#   'option_0': 'consolidation',
#   'option_1': 'fracture',
#   'option_2': 'lung opacity',
#   'option_3': 'pneumothorax',
#   'slice': 'lung opacity'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient65116/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 0,
#   'option_0': 'lung opacity',
#   'option_1': 'pneumonia',
#   'option_2': 'no finding',
#   'option_3': 'pneumothorax',
#   'slice': 'lung opacity'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient65131/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 3,
#   'option_0': 'lung lesion',
#   'option_1': 'fracture',
#   'option_2': 'pneumothorax',
#   'option_3': 'lung opacity',
#   'slice': 'lung opacity'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient64973/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 3,
#   'option_0': 'pneumonia',
#   'option_1': 'pneumothorax',
#   'option_2': 'cardiomegaly',
#   'option_3': 'lung opacity',
#   'slice': 'lung opacity'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient65034/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 2,
#   'option_0': 'atelectasis',
#   'option_1': 'edema',
#   'option_2': 'lung opacity',
#   'option_3': 'pneumonia',
#   'slice': 'lung opacity'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient65100/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 3,
#   'option_0': 'edema',
#   'option_1': 'consolidation',
#   'option_2': 'pneumonia',
#   'option_3': 'lung opacity',
#   'slice': 'lung opacity'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient65101/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 0,
#   'option_0': 'lung opacity',
#   'option_1': 'consolidation',
#   'option_2': 'pneumothorax',
#   'option_3': 'pleural effusion',
#   'slice': 'lung opacity'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient65124/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 1,
#   'option_0': 'no finding',
#   'option_1': 'lung opacity',
#   'option_2': 'fracture',
#   'option_3': 'consolidation',
#   'slice': 'lung opacity'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient64771/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 3,
#   'option_0': 'atelectasis',
#   'option_1': 'cardiomegaly',
#   'option_2': 'fracture',
#   'option_3': 'lung opacity',
#   'slice': 'lung opacity'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient64828/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 0,
#   'option_0': 'lung opacity',
#   'option_1': 'cardiomegaly',
#   'option_2': 'pleural effusion',
#   'option_3': 'atelectasis',
#   'slice': 'lung opacity'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient65145/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 3,
#   'option_0': 'pneumothorax',
#   'option_1': 'consolidation',
#   'option_2': 'atelectasis',
#   'option_3': 'lung opacity',
#   'slice': 'lung opacity'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient64752/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 0,
#   'option_0': 'lung opacity',
#   'option_1': 'consolidation',
#   'option_2': 'no finding',
#   'option_3': 'pneumonia',
#   'slice': 'lung opacity'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient65020/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 0,
#   'option_0': 'lung lesion',
#   'option_1': 'enlarged cardiomediastinum',
#   'option_2': 'fracture',
#   'option_3': 'pneumothorax',
#   'slice': 'lung lesion'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient65115/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 2,
#   'option_0': 'enlarged cardiomediastinum',
#   'option_1': 'no finding',
#   'option_2': 'lung lesion',
#   'option_3': 'edema',
#   'slice': 'lung lesion'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient64791/study1/view2_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 1,
#   'option_0': 'enlarged cardiomediastinum',
#   'option_1': 'lung lesion',
#   'option_2': 'fracture',
#   'option_3': 'pneumonia',
#   'slice': 'lung lesion'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient64747/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 1,
#   'option_0': 'edema',
#   'option_1': 'lung lesion',
#   'option_2': 'enlarged cardiomediastinum',
#   'option_3': 'fracture',
#   'slice': 'lung lesion'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient64752/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 2,
#   'option_0': 'fracture',
#   'option_1': 'pneumothorax',
#   'option_2': 'lung lesion',
#   'option_3': 'no finding',
#   'slice': 'lung lesion'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient64878/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 0,
#   'option_0': 'lung lesion',
#   'option_1': 'pneumonia',
#   'option_2': 'cardiomegaly',
#   'option_3': 'fracture',
#   'slice': 'lung lesion'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient65154/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 0,
#   'option_0': 'lung lesion',
#   'option_1': 'pneumothorax',
#   'option_2': 'pneumonia',
#   'option_3': 'fracture',
#   'slice': 'lung lesion'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient64791/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 1,
#   'option_0': 'support devices',
#   'option_1': 'lung lesion',
#   'option_2': 'edema',
#   'option_3': 'pleural effusion',
#   'slice': 'lung lesion'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient64745/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 0,
#   'option_0': 'lung lesion',
#   'option_1': 'pneumonia',
#   'option_2': 'consolidation',
#   'option_3': 'fracture',
#   'slice': 'lung lesion'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient64833/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 3,
#   'option_0': 'consolidation',
#   'option_1': 'lung lesion',
#   'option_2': 'no finding',
#   'option_3': 'edema',
#   'slice': 'edema'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient65207/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 3,
#   'option_0': 'lung lesion',
#   'option_1': 'cardiomegaly',
#   'option_2': 'no finding',
#   'option_3': 'edema',
#   'slice': 'edema'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient64873/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 3,
#   'option_0': 'lung lesion',
#   'option_1': 'fracture',
#   'option_2': 'pneumothorax',
#   'option_3': 'edema',
#   'slice': 'edema'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient65176/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 3,
#   'option_0': 'pneumothorax',
#   'option_1': 'fracture',
#   'option_2': 'no finding',
#   'option_3': 'edema',
#   'slice': 'edema'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient65208/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 2,
#   'option_0': 'lung lesion',
#   'option_1': 'no finding',
#   'option_2': 'edema',
#   'option_3': 'pleural effusion',
#   'slice': 'edema'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient64772/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 3,
#   'option_0': 'lung lesion',
#   'option_1': 'atelectasis',
#   'option_2': 'support devices',
#   'option_3': 'edema',
#   'slice': 'edema'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient64827/study1/view2_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 1,
#   'option_0': 'pneumonia',
#   'option_1': 'edema',
#   'option_2': 'pleural effusion',
#   'option_3': 'pneumothorax',
#   'slice': 'edema'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient64963/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 3,
#   'option_0': 'no finding',
#   'option_1': 'pneumonia',
#   'option_2': 'lung lesion',
#   'option_3': 'edema',
#   'slice': 'edema'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient64817/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 1,
#   'option_0': 'consolidation',
#   'option_1': 'edema',
#   'option_2': 'pneumonia',
#   'option_3': 'lung lesion',
#   'slice': 'edema'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient64826/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 1,
#   'option_0': 'pleural effusion',
#   'option_1': 'edema',
#   'option_2': 'fracture',
#   'option_3': 'pneumonia',
#   'slice': 'edema'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient64900/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 0,
#   'option_0': 'edema',
#   'option_1': 'atelectasis',
#   'option_2': 'fracture',
#   'option_3': 'consolidation',
#   'slice': 'edema'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient65202/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 2,
#   'option_0': 'cardiomegaly',
#   'option_1': 'no finding',
#   'option_2': 'edema',
#   'option_3': 'lung lesion',
#   'slice': 'edema'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient65086/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 0,
#   'option_0': 'edema',
#   'option_1': 'fracture',
#   'option_2': 'lung lesion',
#   'option_3': 'cardiomegaly',
#   'slice': 'edema'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient65226/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 3,
#   'option_0': 'lung lesion',
#   'option_1': 'consolidation',
#   'option_2': 'no finding',
#   'option_3': 'edema',
#   'slice': 'edema'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient64841/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 2,
#   'option_0': 'pneumothorax',
#   'option_1': 'no finding',
#   'option_2': 'edema',
#   'option_3': 'pleural effusion',
#   'slice': 'edema'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient64944/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 1,
#   'option_0': 'cardiomegaly',
#   'option_1': 'consolidation',
#   'option_2': 'lung lesion',
#   'option_3': 'no finding',
#   'slice': 'consolidation'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient65151/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 3,
#   'option_0': 'fracture',
#   'option_1': 'cardiomegaly',
#   'option_2': 'no finding',
#   'option_3': 'consolidation',
#   'slice': 'consolidation'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient65053/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 3,
#   'option_0': 'atelectasis',
#   'option_1': 'pneumothorax',
#   'option_2': 'lung lesion',
#   'option_3': 'consolidation',
#   'slice': 'consolidation'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient65169/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 3,
#   'option_0': 'fracture',
#   'option_1': 'lung lesion',
#   'option_2': 'edema',
#   'option_3': 'consolidation',
#   'slice': 'consolidation'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient64865/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 1,
#   'option_0': 'cardiomegaly',
#   'option_1': 'consolidation',
#   'option_2': 'edema',
#   'option_3': 'enlarged cardiomediastinum',
#   'slice': 'consolidation'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient64761/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 3,
#   'option_0': 'edema',
#   'option_1': 'fracture',
#   'option_2': 'pneumothorax',
#   'option_3': 'consolidation',
#   'slice': 'consolidation'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient65045/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 0,
#   'option_0': 'consolidation',
#   'option_1': 'fracture',
#   'option_2': 'lung lesion',
#   'option_3': 'atelectasis',
#   'slice': 'consolidation'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient64842/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 1,
#   'option_0': 'lung lesion',
#   'option_1': 'consolidation',
#   'option_2': 'no finding',
#   'option_3': 'support devices',
#   'slice': 'consolidation'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient64965/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 2,
#   'option_0': 'pneumothorax',
#   'option_1': 'edema',
#   'option_2': 'consolidation',
#   'option_3': 'lung lesion',
#   'slice': 'consolidation'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient65089/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 2,
#   'option_0': 'edema',
#   'option_1': 'fracture',
#   'option_2': 'consolidation',
#   'option_3': 'pneumonia',
#   'slice': 'consolidation'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient65115/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 3,
#   'option_0': 'pleural effusion',
#   'option_1': 'enlarged cardiomediastinum',
#   'option_2': 'no finding',
#   'option_3': 'consolidation',
#   'slice': 'consolidation'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient65040/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 2,
#   'option_0': 'pneumonia',
#   'option_1': 'no finding',
#   'option_2': 'consolidation',
#   'option_3': 'edema',
#   'slice': 'consolidation'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient64982/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 1,
#   'option_0': 'lung lesion',
#   'option_1': 'consolidation',
#   'option_2': 'cardiomegaly',
#   'option_3': 'edema',
#   'slice': 'consolidation'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient64747/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 3,
#   'option_0': 'cardiomegaly',
#   'option_1': 'atelectasis',
#   'option_2': 'pneumonia',
#   'option_3': 'consolidation',
#   'slice': 'consolidation'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient65147/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 0,
#   'option_0': 'consolidation',
#   'option_1': 'atelectasis',
#   'option_2': 'pleural effusion',
#   'option_3': 'cardiomegaly',
#   'slice': 'consolidation'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient65147/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 1,
#   'option_0': 'pneumothorax',
#   'option_1': 'pneumonia',
#   'option_2': 'pleural effusion',
#   'option_3': 'atelectasis',
#   'slice': 'pneumonia'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient65053/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 2,
#   'option_0': 'fracture',
#   'option_1': 'atelectasis',
#   'option_2': 'pneumonia',
#   'option_3': 'lung lesion',
#   'slice': 'pneumonia'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient64865/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 3,
#   'option_0': 'fracture',
#   'option_1': 'enlarged cardiomediastinum',
#   'option_2': 'edema',
#   'option_3': 'pneumonia',
#   'slice': 'pneumonia'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient65105/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 2,
#   'option_0': 'pneumothorax',
#   'option_1': 'support devices',
#   'option_2': 'pneumonia',
#   'option_3': 'cardiomegaly',
#   'slice': 'pneumonia'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient65115/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 1,
#   'option_0': 'pleural effusion',
#   'option_1': 'pneumonia',
#   'option_2': 'enlarged cardiomediastinum',
#   'option_3': 'pneumothorax',
#   'slice': 'pneumonia'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient65101/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 0,
#   'option_0': 'pneumonia',
#   'option_1': 'edema',
#   'option_2': 'no finding',
#   'option_3': 'pleural effusion',
#   'slice': 'pneumonia'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient64944/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 1,
#   'option_0': 'pneumothorax',
#   'option_1': 'pneumonia',
#   'option_2': 'lung lesion',
#   'option_3': 'edema',
#   'slice': 'pneumonia'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient65204/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 2,
#   'option_0': 'support devices',
#   'option_1': 'atelectasis',
#   'option_2': 'pneumonia',
#   'option_3': 'pleural effusion',
#   'slice': 'pneumonia'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient64761/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 0,
#   'option_0': 'pneumonia',
#   'option_1': 'lung lesion',
#   'option_2': 'pneumothorax',
#   'option_3': 'edema',
#   'slice': 'pneumonia'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient65045/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 2,
#   'option_0': 'pneumothorax',
#   'option_1': 'no finding',
#   'option_2': 'pneumonia',
#   'option_3': 'lung lesion',
#   'slice': 'pneumonia'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient64982/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 3,
#   'option_0': 'lung lesion',
#   'option_1': 'no finding',
#   'option_2': 'enlarged cardiomediastinum',
#   'option_3': 'pneumonia',
#   'slice': 'pneumonia'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient65078/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 0,
#   'option_0': 'atelectasis',
#   'option_1': 'pneumonia',
#   'option_2': 'lung lesion',
#   'option_3': 'no finding',
#   'slice': 'atelectasis'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient65085/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 1,
#   'option_0': 'consolidation',
#   'option_1': 'atelectasis',
#   'option_2': 'cardiomegaly',
#   'option_3': 'pneumonia',
#   'slice': 'atelectasis'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient64852/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 2,
#   'option_0': 'edema',
#   'option_1': 'lung lesion',
#   'option_2': 'atelectasis',
#   'option_3': 'pneumonia',
#   'slice': 'atelectasis'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient65044/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 2,
#   'option_0': 'cardiomegaly',
#   'option_1': 'pneumonia',
#   'option_2': 'atelectasis',
#   'option_3': 'edema',
#   'slice': 'atelectasis'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient64983/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 2,
#   'option_0': 'pneumonia',
#   'option_1': 'consolidation',
#   'option_2': 'atelectasis',
#   'option_3': 'edema',
#   'slice': 'atelectasis'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient65057/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 1,
#   'option_0': 'no finding',
#   'option_1': 'atelectasis',
#   'option_2': 'edema',
#   'option_3': 'cardiomegaly',
#   'slice': 'atelectasis'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient64998/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 1,
#   'option_0': 'pneumothorax',
#   'option_1': 'atelectasis',
#   'option_2': 'cardiomegaly',
#   'option_3': 'no finding',
#   'slice': 'atelectasis'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient65022/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 1,
#   'option_0': 'consolidation',
#   'option_1': 'atelectasis',
#   'option_2': 'pleural effusion',
#   'option_3': 'cardiomegaly',
#   'slice': 'atelectasis'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient64961/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 1,
#   'option_0': 'fracture',
#   'option_1': 'atelectasis',
#   'option_2': 'consolidation',
#   'option_3': 'pleural effusion',
#   'slice': 'atelectasis'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient65189/study1/view2_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 0,
#   'option_0': 'atelectasis',
#   'option_1': 'pleural effusion',
#   'option_2': 'fracture',
#   'option_3': 'pneumonia',
#   'slice': 'atelectasis'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient64975/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 1,
#   'option_0': 'fracture',
#   'option_1': 'atelectasis',
#   'option_2': 'enlarged cardiomediastinum',
#   'option_3': 'pneumonia',
#   'slice': 'atelectasis'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient64842/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 3,
#   'option_0': 'lung lesion',
#   'option_1': 'edema',
#   'option_2': 'pneumothorax',
#   'option_3': 'atelectasis',
#   'slice': 'atelectasis'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient65031/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 2,
#   'option_0': 'support devices',
#   'option_1': 'edema',
#   'option_2': 'atelectasis',
#   'option_3': 'enlarged cardiomediastinum',
#   'slice': 'atelectasis'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient65225/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 2,
#   'option_0': 'support devices',
#   'option_1': 'enlarged cardiomediastinum',
#   'option_2': 'atelectasis',
#   'option_3': 'pneumothorax',
#   'slice': 'atelectasis'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'CheXpert-Public',
#   'image_path': 'data/chexpert-public/test/patient65156/study1/view1_frontal.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 3,
#   'option_0': 'no finding',
#   'option_1': 'pneumonia',
#   'option_2': 'pneumothorax',
#   'option_3': 'atelectasis',
#   'slice': 'atelectasis'},
#  {'task_name': 'Single Disease Identification',
# ...
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 1,
#   'option_0': 'pneumothorax',
#   'option_1': 'consolidation',
#   'option_2': 'atelectasis',
#   'option_3': 'edema',
#   'slice': 'consolidation'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'MIMIC-CXR',
#   'image_path': 'data/mimic-cxr/files/p16/p16853729/s51121202/d0b136c5-f0844e8c-66112b7b-2c23ee98-5d07fb5c.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 3,
#   'option_0': 'consolidation',
#   'option_1': 'pneumonia',
#   'option_2': 'pleural effusion',
#   'option_3': 'enlarged cardiomediastinum',
#   'slice': 'enlarged cardiomediastinum'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'MIMIC-CXR',
#   'image_path': 'data/mimic-cxr/files/p13/p13067703/s51140369/a9fa9dcf-791d8328-1f38b677-e6d7a2aa-56b111e5.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 2,
#   'option_0': 'lung opacity',
#   'option_1': 'pneumonia',
#   'option_2': 'enlarged cardiomediastinum',
#   'option_3': 'lung lesion',
#   'slice': 'enlarged cardiomediastinum'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'MIMIC-CXR',
#   'image_path': 'data/mimic-cxr/files/p13/p13450581/s51153135/842c80c2-40a8d117-9d30e18e-4548b4b6-99f871ed.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 2,
#   'option_0': 'enlarged cardiomediastinum',
#   'option_1': 'no finding',
#   'option_2': 'lung lesion',
#   'option_3': 'atelectasis',
#   'slice': 'lung lesion'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'MIMIC-CXR',
#   'image_path': 'data/mimic-cxr/files/p11/p11413236/s51161513/2e0c4b42-d1ef618d-2b25304c-1b6ef8a5-29e7671d.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 1,
#   'option_0': 'edema',
#   'option_1': 'consolidation',
#   'option_2': 'enlarged cardiomediastinum',
#   'option_3': 'support devices',
#   'slice': 'consolidation'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'MIMIC-CXR',
#   'image_path': 'data/mimic-cxr/files/p12/p12952223/s51183783/8753dd62-80681aa9-11dcf353-7d254056-7c7675c7.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 1,
#   'option_0': 'consolidation',
#   'option_1': 'pneumothorax',
#   'option_2': 'fracture',
#   'option_3': 'no finding',
#   'slice': 'pneumothorax'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'MIMIC-CXR',
#   'image_path': 'data/mimic-cxr/files/p17/p17340686/s51203739/e023c3e4-39101fc9-0c1d4cb4-1566e997-0080096e.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 3,
#   'option_0': 'fracture',
#   'option_1': 'cardiomegaly',
#   'option_2': 'pneumonia',
#   'option_3': 'consolidation',
#   'slice': 'consolidation'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'MIMIC-CXR',
#   'image_path': 'data/mimic-cxr/files/p14/p14449498/s51210366/dd3a86eb-069878c6-f4880473-9cc83b95-17983197.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 1,
#   'option_0': 'consolidation',
#   'option_1': 'lung lesion',
#   'option_2': 'pneumonia',
#   'option_3': 'support devices',
#   'slice': 'lung lesion'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'MIMIC-CXR',
#   'image_path': 'data/mimic-cxr/files/p12/p12702423/s51244261/17ff7369-20912497-3b539b61-9c4ace20-7dc7fa12.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 3,
#   'option_0': 'pneumonia',
#   'option_1': 'edema',
#   'option_2': 'fracture',
#   'option_3': 'consolidation',
#   'slice': 'consolidation'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'MIMIC-CXR',
#   'image_path': 'data/mimic-cxr/files/p17/p17337033/s51304693/3b8fc3bd-66391218-68c48776-0cbde359-ec4f0e4d.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 3,
#   'option_0': 'support devices',
#   'option_1': 'lung opacity',
#   'option_2': 'pneumonia',
#   'option_3': 'enlarged cardiomediastinum',
#   'slice': 'enlarged cardiomediastinum'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'MIMIC-CXR',
#   'image_path': 'data/mimic-cxr/files/p19/p19213022/s51320163/4977b9cb-187b6611-2a2cd5ec-75b12655-890f56b5.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 2,
#   'option_0': 'pleural effusion',
#   'option_1': 'atelectasis',
#   'option_2': 'fracture',
#   'option_3': 'pneumonia',
#   'slice': 'fracture'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'MIMIC-CXR',
#   'image_path': 'data/mimic-cxr/files/p11/p11934114/s51328698/f9a68aca-c5a51654-80b6c990-e35e78ae-63dcc3b2.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 2,
#   'option_0': 'support devices',
#   'option_1': 'enlarged cardiomediastinum',
#   'option_2': 'lung lesion',
#   'option_3': 'no finding',
#   'slice': 'lung lesion'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'MIMIC-CXR',
#   'image_path': 'data/mimic-cxr/files/p14/p14387068/s51346944/f376a6b6-0447ef09-f99ba585-ac93baaf-321b89a9.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 3,
#   'option_0': 'no finding',
#   'option_1': 'enlarged cardiomediastinum',
#   'option_2': 'lung opacity',
#   'option_3': 'consolidation',
#   'slice': 'consolidation'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'MIMIC-CXR',
#   'image_path': 'data/mimic-cxr/files/p14/p14387068/s51435896/dba61a64-de733cca-c91730b7-7870dfef-c173ffd9.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 2,
#   'option_0': 'enlarged cardiomediastinum',
#   'option_1': 'pneumonia',
#   'option_2': 'pneumothorax',
#   'option_3': 'lung opacity',
#   'slice': 'pneumothorax'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'MIMIC-CXR',
#   'image_path': 'data/mimic-cxr/files/p10/p10885696/s51545557/b83a98a1-69ae5692-5fc5b2eb-140a525a-abf289ab.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 0,
#   'option_0': 'enlarged cardiomediastinum',
#   'option_1': 'pneumonia',
#   'option_2': 'consolidation',
#   'option_3': 'lung opacity',
#   'slice': 'enlarged cardiomediastinum'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'MIMIC-CXR',
#   'image_path': 'data/mimic-cxr/files/p17/p17163861/s51599732/7af50fb4-7220f1e6-2f232aa7-bdbbc51c-18f1c512.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 1,
#   'option_0': 'edema',
#   'option_1': 'pneumothorax',
#   'option_2': 'cardiomegaly',
#   'option_3': 'lung opacity',
#   'slice': 'pneumothorax'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'MIMIC-CXR',
#   'image_path': 'data/mimic-cxr/files/p12/p12410066/s51727838/9d674775-c0b3be98-7ed72cdd-47852026-4ca978b4.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 3,
#   'option_0': 'fracture',
#   'option_1': 'support devices',
#   'option_2': 'pneumothorax',
#   'option_3': 'enlarged cardiomediastinum',
#   'slice': 'enlarged cardiomediastinum'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'MIMIC-CXR',
#   'image_path': 'data/mimic-cxr/files/p14/p14722763/s51766355/8d2b343d-5f569dbe-d6ced9ab-01862237-a2d8520c.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 1,
#   'option_0': 'pneumonia',
#   'option_1': 'enlarged cardiomediastinum',
#   'option_2': 'support devices',
#   'option_3': 'cardiomegaly',
#   'slice': 'enlarged cardiomediastinum'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'MIMIC-CXR',
#   'image_path': 'data/mimic-cxr/files/p11/p11569093/s52011372/5f961326-0ccce927-f726948a-19e43255-88306b58.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 2,
#   'option_0': 'atelectasis',
#   'option_1': 'no finding',
#   'option_2': 'pneumothorax',
#   'option_3': 'consolidation',
#   'slice': 'pneumothorax'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'MIMIC-CXR',
#   'image_path': 'data/mimic-cxr/files/p15/p15370732/s52202145/cfc3effc-853804f4-6aaf7cfd-374d7078-6e586d77.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 1,
#   'option_0': 'pleural effusion',
#   'option_1': 'pneumothorax',
#   'option_2': 'enlarged cardiomediastinum',
#   'option_3': 'lung lesion',
#   'slice': 'pneumothorax'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'MIMIC-CXR',
#   'image_path': 'data/mimic-cxr/files/p16/p16957952/s52307593/f44cd0b1-41c1556c-8cb1b4db-632a0833-ed413255.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 2,
#   'option_0': 'enlarged cardiomediastinum',
#   'option_1': 'consolidation',
#   'option_2': 'fracture',
#   'option_3': 'pneumonia',
#   'slice': 'fracture'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'MIMIC-CXR',
#   'image_path': 'data/mimic-cxr/files/p17/p17112432/s52349735/7e7b19ac-d29aedbe-10d9f138-4037688a-57615f21.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 1,
#   'option_0': 'pneumonia',
#   'option_1': 'fracture',
#   'option_2': 'consolidation',
#   'option_3': 'lung lesion',
#   'slice': 'fracture'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'MIMIC-CXR',
#   'image_path': 'data/mimic-cxr/files/p19/p19182863/s52374902/155e0867-6925a927-7f73fa2f-6e5438bb-dc6ae8fc.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 1,
#   'option_0': 'pneumonia',
#   'option_1': 'pneumothorax',
#   'option_2': 'no finding',
#   'option_3': 'cardiomegaly',
#   'slice': 'pneumothorax'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'MIMIC-CXR',
#   'image_path': 'data/mimic-cxr/files/p12/p12736592/s52442135/ca418dad-d4092480-3bf56e1f-9b920db8-8b8361de.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 3,
#   'option_0': 'edema',
#   'option_1': 'atelectasis',
#   'option_2': 'no finding',
#   'option_3': 'pneumothorax',
#   'slice': 'pneumothorax'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'MIMIC-CXR',
#   'image_path': 'data/mimic-cxr/files/p11/p11474065/s52522246/dd86cc8c-ae1e2c39-3bc3e62b-b15de0ae-652648de.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 3,
#   'option_0': 'edema',
#   'option_1': 'lung lesion',
#   'option_2': 'no finding',
#   'option_3': 'pneumothorax',
#   'slice': 'pneumothorax'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'MIMIC-CXR',
#   'image_path': 'data/mimic-cxr/files/p16/p16360107/s52598379/4f4218c0-7e3de34f-abade5db-964b2d47-addcc964.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 2,
#   'option_0': 'enlarged cardiomediastinum',
#   'option_1': 'cardiomegaly',
#   'option_2': 'fracture',
#   'option_3': 'support devices',
#   'slice': 'fracture'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'MIMIC-CXR',
#   'image_path': 'data/mimic-cxr/files/p12/p12124741/s52680361/415af9ca-d0b69fbe-b3b8dfa6-271f3f0f-5592cc53.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 2,
#   'option_0': 'enlarged cardiomediastinum',
#   'option_1': 'edema',
#   'option_2': 'lung lesion',
#   'option_3': 'consolidation',
#   'slice': 'lung lesion'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'MIMIC-CXR',
#   'image_path': 'data/mimic-cxr/files/p13/p13866940/s52775752/91aa37d1-c2d7d819-bea91a37-602f27c2-ab6984ae.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 2,
#   'option_0': 'atelectasis',
#   'option_1': 'consolidation',
#   'option_2': 'fracture',
#   'option_3': 'no finding',
#   'slice': 'fracture'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'MIMIC-CXR',
#   'image_path': 'data/mimic-cxr/files/p16/p16622813/s53002522/901ff9da-8c7918cf-2c1642f7-2db14f83-c386dfe5.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 3,
#   'option_0': 'lung lesion',
#   'option_1': 'no finding',
#   'option_2': 'consolidation',
#   'option_3': 'fracture',
#   'slice': 'fracture'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'MIMIC-CXR',
#   'image_path': 'data/mimic-cxr/files/p11/p11879886/s53021526/27a4f085-5eaad330-a1153870-3ec2cd19-20a604cd.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 3,
#   'option_0': 'atelectasis',
#   'option_1': 'no finding',
#   'option_2': 'pneumonia',
#   'option_3': 'lung lesion',
#   'slice': 'lung lesion'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'MIMIC-CXR',
#   'image_path': 'data/mimic-cxr/files/p12/p12702423/s53164365/25449c50-88b4c67a-5aab7423-4c477c4b-843d4f4c.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 0,
#   'option_0': 'lung lesion',
#   'option_1': 'no finding',
#   'option_2': 'pneumonia',
#   'option_3': 'enlarged cardiomediastinum',
#   'slice': 'lung lesion'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'MIMIC-CXR',
#   'image_path': 'data/mimic-cxr/files/p18/p18487334/s53377112/1d5931ea-ae06916c-5082d79e-ce203e51-6581ddc9.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 3,
#   'option_0': 'support devices',
#   'option_1': 'enlarged cardiomediastinum',
#   'option_2': 'cardiomegaly',
#   'option_3': 'fracture',
#   'slice': 'fracture'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'MIMIC-CXR',
#   'image_path': 'data/mimic-cxr/files/p10/p10268877/s53452091/e35d7c70-3f278882-4f133ee9-184f4d7e-fa32a4d7.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 0,
#   'option_0': 'fracture',
#   'option_1': 'enlarged cardiomediastinum',
#   'option_2': 'no finding',
#   'option_3': 'cardiomegaly',
#   'slice': 'fracture'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'MIMIC-CXR',
#   'image_path': 'data/mimic-cxr/files/p19/p19800337/s53459280/be1ddefb-9327567f-aef38bd8-e918043d-91c40219.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 2,
#   'option_0': 'atelectasis',
#   'option_1': 'edema',
#   'option_2': 'lung lesion',
#   'option_3': 'enlarged cardiomediastinum',
#   'slice': 'lung lesion'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'MIMIC-CXR',
#   'image_path': 'data/mimic-cxr/files/p13/p13352405/s53475803/fc9d24b9-ab585ce7-32abcbae-b223b872-d70b72cf.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 1,
#   'option_0': 'enlarged cardiomediastinum',
#   'option_1': 'fracture',
#   'option_2': 'pneumothorax',
#   'option_3': 'no finding',
#   'slice': 'fracture'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'MIMIC-CXR',
#   'image_path': 'data/mimic-cxr/files/p16/p16334516/s53602937/4e978740-b97d9a2c-f97c4610-4dd52d72-5cb121ef.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 1,
#   'option_0': 'pleural effusion',
#   'option_1': 'lung lesion',
#   'option_2': 'enlarged cardiomediastinum',
#   'option_3': 'atelectasis',
#   'slice': 'lung lesion'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'MIMIC-CXR',
#   'image_path': 'data/mimic-cxr/files/p19/p19844485/s53788698/e9f8beb8-4ee1436c-72c497d0-1bc5a42c-e9cfb483.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 0,
#   'option_0': 'lung lesion',
#   'option_1': 'edema',
#   'option_2': 'pneumonia',
#   'option_3': 'atelectasis',
#   'slice': 'lung lesion'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'MIMIC-CXR',
#   'image_path': 'data/mimic-cxr/files/p12/p12702423/s54038403/e4c886d4-4409c92a-132f068d-876bd033-0e8fd448.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 0,
#   'option_0': 'lung lesion',
#   'option_1': 'edema',
#   'option_2': 'atelectasis',
#   'option_3': 'no finding',
#   'slice': 'lung lesion'},
#  {'task_name': 'Single Disease Identification',
#   'data_source': 'MIMIC-CXR',
#   'image_path': 'data/mimic-cxr/files/p17/p17763117/s54066754/2562051f-7aa8f63a-d00bafea-ddf082c6-838ba1fd.jpg',
#   'question': 'Which finding is in this chest X-ray?',
#   'answer': 2,
#   'option_0': 'support devices',
#   'option_1': 'fracture',
#   'option_2': 'lung lesion',
#   'option_3': 'lung opacity',
#   'slice': 'lung lesion'}]
